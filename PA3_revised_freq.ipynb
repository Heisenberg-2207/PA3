# %%
import numpy as np
from tqdm import tqdm
import gym
import math
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
env = gym.make('Taxi-v3')
num_actions = env.action_space
num_obs = env.observation_space
R, G, B, Y = env.unwrapped.locs
R, G, B, Y = list(R), list(G), list(B), list(Y)
env.reset()
# Out:
# (1, {'prob': 1.0, 'action_mask': array([1, 0, 1, 0, 1, 0], dtype=int8)})

# %%
def get_state(state):
    row, col, pass_id, dest_id = env.unwrapped.decode(state)
    state = np.asarray([row,col,pass_id,dest_id])
    return state

print(get_state(123)[0:2])
print(R,G,B,Y)
# Out:
# [1 1]
# [0, 0] [0, 4] [4, 0] [4, 3]

# %%
curr_state = get_state(env.s)
print("Taxi at",curr_state[0:2])
next_state, reward, done, _, _ = env.step(4)
row, col, pass_id, dest_id = env.unwrapped.decode(next_state)
# Out:
# Taxi at [0 0]
# c:\Users\anike\AppData\Local\Programs\Python\Python312\Lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):

# %%
# Set the number of episodes and maximum number of steps per episode
EPS = 10000
MAX_STEPS = 500
EXP = 1
# Set the learning rate, discount factor, and exploration rate
ALPHA = 0.15
GAMMA = 0.99
exploration_rate = 1.0
MIN_EXP = 0.01
EXP_DECAY = 0.01

# %%
def choose_action(state,qs,eps):
    #print(np.shape(q))
    length = np.shape(qs)[1]
    if not qs[state].any():
        return random.randint(0,length-1)
    action = np.argmax(qs[state])
    
    if np.random.rand() < eps:
        action = np.random.randint(0,length-1)
        return action
    return action   

def choose_action_option(state,qs):
    action = np.argmax(qs[state])
    return action

# %%
# Options where policy is greedy wrt the corresponding q Value function
def Red(q_r,state,eps):
    optdone = False
    optact = choose_action(state,q_r,eps)
    state = get_state(state)
    if state[0] == R[0] and state[1] == R[1]:
        optdone = True
    return optact,optdone

def Green(q_g,state,eps):
    optdone = False
    optact = choose_action(state,q_g,eps)
    state = get_state(state)
    if state[0] == G[0] and state[1] == G[1]:
        optdone = True
    return optact,optdone
    
def Yellow(q_y,state,eps):
    optdone = False
    optact = choose_action(state,q_y,eps)
    state = get_state(state)
    if state[0] == Y[0] and state[1] == Y[1]:
        optdone = True
    return optact,optdone 

def Blue(q_b,state,eps):
    optdone = False
    optact = choose_action(state,q_b,eps)
    state = get_state(state)
    if state[0] == B[0] and state[1] == B[1]:
        optdone = True
    return optact,optdone

# %% [markdown]
# SMDP

# %%
class SMDP:
    def __init__(self):
        self.avg_reward = []
        self.total_reward = []
        self.q = np.zeros((500,10))
        self.q_r = np.zeros((500,4))
        self.q_b = np.zeros((500,4))
        self.q_g = np.zeros((500,4))
        self.q_y = np.zeros((500,4))
        self.q_f = np.zeros((500,10))
        self.q_r_f = np.zeros((500,4))
        self.q_b_f = np.zeros((500,4))
        self.q_g_f = np.zeros((500,4))
        self.q_y_f = np.zeros((500,4))

    def Qlearn(self):
        epsilon = 0.1
        for episode in range(5000):
            running = 0
            state, _ = env.reset()
            done = False
            ep_reward = 0
            steps = 0
            while not done :
                steps += 1
                action = choose_action(state,self.q,epsilon)
                if action < 6:
                    next_state, reward, done, _, _ = env.step(action)
                    ep_reward+= reward
                    self.q[state,action] = self.q[state, action] + ALPHA * (reward + GAMMA * np.max(self.q[next_state, :])- self.q[state, action])
                    self.q_f[state,action] += 1
                    state = next_state
                reward_bar = 0
                if action > 5 :
                    count = 0
                    optdone = False
                    current_state = state
                    while (optdone == False) :
                        if action == 6:
                            optact, optdone = Red(self.q_r,state,epsilon) 
                            next_state, reward, done, _, _ = env.step(optact)
                            self.q_r[state,optact] = self.q_r[state, optact] + ALPHA * (reward + GAMMA * np.max(self.q_r[next_state, :])- self.q_r[state, optact])
                            self.q_r_f[state,optact] += 1
                        if action == 7:
                            optact, optdone = Green(self.q_g,state,epsilon)
                            next_state, reward, done, _, _ = env.step(optact)
                            self.q_g[state,optact] = self.q_g[state, optact] + ALPHA * (reward + GAMMA * np.max(self.q_g[next_state, :])- self.q_g[state, optact])
                            self.q_g_f[state,optact] += 1
                        if action == 8:
                            optact, optdone = Blue(self.q_b,state,epsilon)
                            next_state, reward, done, _, _ = env.step(optact)
                            self.q_b[state,optact] = self.q_b[state, optact] + ALPHA * (reward + GAMMA * np.max(self.q_b[next_state, :])- self.q_b[state, optact])
                            self.q_b_f[state,optact] += 1
                        if action == 9:
                            optact, optdone = Yellow(self.q_y,state,epsilon)
                            next_state, reward, done, _, _ = env.step(optact)
                            self.q_y[state,optact] = self.q_y[state, optact] + ALPHA * (reward + GAMMA * np.max(self.q_y[next_state])- self.q_y[state, optact])
                            self.q_y_f[state,optact] += 1
                        reward_bar =  reward_bar + (GAMMA**count)*reward
                        ep_reward += reward
                        count += 1
                        if optdone == True:
                            self.q[current_state, action] += ALPHA * (reward_bar - self.q[current_state, action] + (GAMMA**count) * np.max(self.q[next_state, :]))
                        state = next_state
                if epsilon > 0.01:
                    epsilon = epsilon*np.exp(-0.01)
            running = 0.35 * ep_reward + (1 - 0.35) * running
            self.avg_reward.append(running)
            self.total_reward.append(ep_reward)
            print(f"Episode {episode + 1}: Total Reward = {ep_reward}")
        return self.avg_reward, self.total_reward
    
    def plot(self):
        plt.plot(self.avg_reward,label="Moving Average")
        plt.grid()
        plt.plot(self.total_reward,label="Total Rewards",alpha=1, color='orange')
        plt.xlabel('Episode')
        plt.ylabel('Averaged Episodic Returns')
        plt.title("Averaged Episodic Returns")
        plt.legend()
        plt.savefig('SMDP.png')
        plt.show()

    def render_run(self):
        special_env = gym.make('Taxi-v3',render_mode='human')
        done = False
        eps = 0.01
        state, _ = special_env.reset()
        while not done:
            action = choose_action(state,self.q,eps)
            next_state, reward, done, _, _ = special_env.step(action)
            if done:
                break

    def plot_Q(self):
        ACTIONS = {0: "South",1: "Up",2: "East",3: "West",4: "Pick",5: "Drop",6: "Red",7: "Green",8: "Blue", 9: "Yellow"}
        # decode each state 
        # ((taxi_row * 5 + taxi_col) * 5 + passenger_location) * 4 + destination
        action = np.argmax(self.q,axis=1)
        action_f = np.argmax(self.q_f,axis=1)

        dest_r = action[::4]
        dest_g = action[1::4]
        dest_b = action[2::4]
        dest_y = action[3::4]

        dest_r_f = action_f[::4]
        dest_g_f = action_f[1::4]
        dest_b_f = action_f[2::4]
        dest_y_f = action_f[3::4]

        loc_r_r = dest_r[::5]
        loc_r_g = dest_g[::5]
        loc_r_b = dest_b[::5]
        loc_r_y = dest_y[::5]

        loc_r_r_f = dest_r_f[::5]
        loc_r_g_f = dest_g_f[::5]
        loc_r_b_f = dest_b_f[::5]
        loc_r_y_f = dest_y_f[::5]

        loc_g_r = dest_r[1::5]
        loc_g_g = dest_g[1::5]
        loc_g_b = dest_b[1::5]
        loc_g_y = dest_y[1::5]

        loc_g_r_f = dest_r_f[1::5]
        loc_g_g_f = dest_g_f[1::5]
        loc_g_b_f = dest_b_f[1::5]
        loc_g_y_f = dest_y_f[1::5]

        loc_b_r = dest_r[2::5]
        loc_b_g = dest_g[2::5]
        loc_b_b = dest_b[2::5]
        loc_b_y = dest_y[2::5]

        loc_b_r_f = dest_r_f[2::5]
        loc_b_g_f = dest_g_f[2::5]
        loc_b_b_f = dest_b_f[2::5]
        loc_b_y_f = dest_y_f[2::5]

        loc_y_r = dest_r[3::5]
        loc_y_g = dest_g[3::5]
        loc_y_b = dest_b[3::5]
        loc_y_y = dest_y[3::5]

        loc_y_r_f = dest_r_f[3::5]
        loc_y_g_f = dest_g_f[3::5]
        loc_y_b_f = dest_b_f[3::5]
        loc_y_y_f = dest_y_f[3::5]

    # Create a 5x5 grid for grid and frequncy
        grid = np.reshape(loc_r_g, (5, 5))
        freq = np.reshape(loc_r_g_f, (5, 5))

    # Display the grid with numbers
        plt.imshow(freq, cmap='viridis', interpolation='nearest')
        for i in range(5):
            for j in range(5):
                text = ACTIONS[grid[i, j]]
                plt.text(j, i, text, ha='center', va='center', color='black')

    # Add labels and title
        plt.colorbar()
        plt.xlabel('Column')
        plt.ylabel('Row')
        plt.show()

# %% [markdown]
# Working

# %%
smdp = SMDP()
smdp.Qlearn()
smdp.plot()
# Out:
# Episode 1: Total Reward = -6371
# Episode 2: Total Reward = -7347
# Episode 3: Total Reward = -1244
# Episode 4: Total Reward = -5230
# Episode 5: Total Reward = -2113
# Episode 6: Total Reward = -1305
# Episode 7: Total Reward = -5608
# Episode 8: Total Reward = -4108
# Episode 9: Total Reward = -5261
# Episode 10: Total Reward = -1256
# Episode 11: Total Reward = -4271
# Episode 12: Total Reward = -4997
# Episode 13: Total Reward = -1920
# Episode 14: Total Reward = -2858
# Episode 15: Total Reward = -2487
# Episode 16: Total Reward = -2494
# Episode 17: Total Reward = -4723
# Episode 18: Total Reward = -798
# Episode 19: Total Reward = -3766
# Episode 20: Total Reward = -3444
# Episode 21: Total Reward = -771
# Episode 22: Total Reward = -1481
# Episode 23: Total Reward = -995
# Episode 24: Total Reward = -648
# Episode 25: Total Reward = -1908
# Episode 26: Total Reward = -1729
# Episode 27: Total Reward = -2767
# Episode 28: Total Reward = -6092
# Episode 29: Total Reward = -1123
# Episode 30: Total Reward = -3198
# Episode 31: Total Reward = -655
# Episode 32: Total Reward = -3744
# Episode 33: Total Reward = -2656
# Episode 34: Total Reward = -1923
# Episode 35: Total Reward = -1111
# Episode 36: Total Reward = -498
# Episode 37: Total Reward = -3133
# Episode 38: Total Reward = -371
# Episode 39: Total Reward = -206
# Episode 40: Total Reward = -1303
# Episode 41: Total Reward = -308
# Episode 42: Total Reward = -982
# Episode 43: Total Reward = -1407
# Episode 44: Total Reward = -443
# Episode 45: Total Reward = -596
# Episode 46: Total Reward = -3102
# Episode 47: Total Reward = -920
# Episode 48: Total Reward = -600
# Episode 49: Total Reward = -750
# Episode 50: Total Reward = -985
# Episode 51: Total Reward = -1044
# Episode 52: Total Reward = -908
# Episode 53: Total Reward = -1131
# Episode 54: Total Reward = -2302
# Episode 55: Total Reward = -2550
# Episode 56: Total Reward = -1179
# Episode 57: Total Reward = -584
# Episode 58: Total Reward = -384
# Episode 59: Total Reward = -1138
# Episode 60: Total Reward = -457
# Episode 61: Total Reward = -1974
# Episode 62: Total Reward = -40
# Episode 63: Total Reward = -123
# Episode 64: Total Reward = -550
# Episode 65: Total Reward = -432
# Episode 66: Total Reward = -567
# Episode 67: Total Reward = -499
# Episode 68: Total Reward = -824
# Episode 69: Total Reward = -498
# Episode 70: Total Reward = -856
# Episode 71: Total Reward = -964
# Episode 72: Total Reward = -1075
# Episode 73: Total Reward = -680
# Episode 74: Total Reward = -796
# Episode 75: Total Reward = -1714
# Episode 76: Total Reward = -331
# Episode 77: Total Reward = -156
# Episode 78: Total Reward = -1039
# Episode 79: Total Reward = -452
# Episode 80: Total Reward = -99
# Episode 81: Total Reward = -306
# Episode 82: Total Reward = -632
# Episode 83: Total Reward = -513
# Episode 84: Total Reward = -324
# Episode 85: Total Reward = -111
# Episode 86: Total Reward = -441
# Episode 87: Total Reward = -381
# Episode 88: Total Reward = -589
# Episode 89: Total Reward = -413
# Episode 90: Total Reward = -276
# Episode 91: Total Reward = -479
# Episode 92: Total Reward = -35
# Episode 93: Total Reward = -86
# Episode 94: Total Reward = -913
# Episode 95: Total Reward = -156
# Episode 96: Total Reward = -299
# Episode 97: Total Reward = -282
# Episode 98: Total Reward = -695
# Episode 99: Total Reward = -187
# Episode 100: Total Reward = -1029
# Episode 101: Total Reward = -311
# Episode 102: Total Reward = -359
# Episode 103: Total Reward = -586
# Episode 104: Total Reward = -124
# Episode 105: Total Reward = -38
# Episode 106: Total Reward = -670
# Episode 107: Total Reward = -285
# Episode 108: Total Reward = -915
# Episode 109: Total Reward = 5
# Episode 110: Total Reward = -429
# Episode 111: Total Reward = -190
# Episode 112: Total Reward = -645
# Episode 113: Total Reward = -303
# Episode 114: Total Reward = -539
# Episode 115: Total Reward = -581
# Episode 116: Total Reward = -578
# Episode 117: Total Reward = -468
# Episode 118: Total Reward = -30
# Episode 119: Total Reward = -73
# Episode 120: Total Reward = -442
# Episode 121: Total Reward = -400
# Episode 122: Total Reward = -168
# Episode 123: Total Reward = -4
# Episode 124: Total Reward = -206
# Episode 125: Total Reward = -87
# Episode 126: Total Reward = -365
# Episode 127: Total Reward = 0
# Episode 128: Total Reward = -349
# Episode 129: Total Reward = -368
# Episode 130: Total Reward = -238
# Episode 131: Total Reward = -21
# Episode 132: Total Reward = -479
# Episode 133: Total Reward = -188
# Episode 134: Total Reward = -77
# Episode 135: Total Reward = -56
# Episode 136: Total Reward = -682
# Episode 137: Total Reward = -178
# Episode 138: Total Reward = -418
# Episode 139: Total Reward = 11
# Episode 140: Total Reward = -791
# Episode 141: Total Reward = -499
# Episode 142: Total Reward = -127
# Episode 143: Total Reward = -560
# Episode 144: Total Reward = -201
# Episode 145: Total Reward = -273
# Episode 146: Total Reward = -617
# Episode 147: Total Reward = -261
# Episode 148: Total Reward = -104
# Episode 149: Total Reward = -135
# Episode 150: Total Reward = -409
# Episode 151: Total Reward = -448
# Episode 152: Total Reward = 3
# Episode 153: Total Reward = -73
# Episode 154: Total Reward = -121
# Episode 155: Total Reward = -59
# Episode 156: Total Reward = -124
# Episode 157: Total Reward = -535
# Episode 158: Total Reward = -245
# Episode 159: Total Reward = -24
# Episode 160: Total Reward = -214
# Episode 161: Total Reward = -115
# Episode 162: Total Reward = -306
# Episode 163: Total Reward = -183
# Episode 164: Total Reward = -122
# Episode 165: Total Reward = -63
# Episode 166: Total Reward = -89
# Episode 167: Total Reward = -467
# Episode 168: Total Reward = -161
# Episode 169: Total Reward = -200
# Episode 170: Total Reward = -158
# Episode 171: Total Reward = -43
# Episode 172: Total Reward = 12
# Episode 173: Total Reward = -228
# Episode 174: Total Reward = -244
# Episode 175: Total Reward = -207
# Episode 176: Total Reward = -35
# Episode 177: Total Reward = -33
# Episode 178: Total Reward = -118
# Episode 179: Total Reward = -267
# Episode 180: Total Reward = -102
# Episode 181: Total Reward = -330
# Episode 182: Total Reward = -536
# Episode 183: Total Reward = 1
# Episode 184: Total Reward = -117
# Episode 185: Total Reward = -297
# Episode 186: Total Reward = -310
# Episode 187: Total Reward = -155
# Episode 188: Total Reward = -19
# Episode 189: Total Reward = -317
# Episode 190: Total Reward = -244
# Episode 191: Total Reward = -464
# Episode 192: Total Reward = -175
# Episode 193: Total Reward = -83
# Episode 194: Total Reward = -12
# Episode 195: Total Reward = -214
# Episode 196: Total Reward = -340
# Episode 197: Total Reward = -68
# Episode 198: Total Reward = -394
# Episode 199: Total Reward = -394
# Episode 200: Total Reward = 2
# Episode 201: Total Reward = -322
# Episode 202: Total Reward = -604
# Episode 203: Total Reward = -396
# Episode 204: Total Reward = -51
# Episode 205: Total Reward = -54
# Episode 206: Total Reward = 0
# Episode 207: Total Reward = 14
# Episode 208: Total Reward = -245
# Episode 209: Total Reward = -483
# Episode 210: Total Reward = -252
# Episode 211: Total Reward = -6
# Episode 212: Total Reward = -189
# Episode 213: Total Reward = -51
# Episode 214: Total Reward = -93
# Episode 215: Total Reward = -340
# Episode 216: Total Reward = -100
# Episode 217: Total Reward = -227
# Episode 218: Total Reward = -394
# Episode 219: Total Reward = -293
# Episode 220: Total Reward = -269
# Episode 221: Total Reward = -185
# Episode 222: Total Reward = -386
# Episode 223: Total Reward = -33
# Episode 224: Total Reward = -178
# Episode 225: Total Reward = -11
# Episode 226: Total Reward = -58
# Episode 227: Total Reward = -125
# Episode 228: Total Reward = -486
# Episode 229: Total Reward = -77
# Episode 230: Total Reward = -41
# Episode 231: Total Reward = -103
# Episode 232: Total Reward = -62
# Episode 233: Total Reward = -73
# Episode 234: Total Reward = -17
# Episode 235: Total Reward = -55
# Episode 236: Total Reward = -482
# Episode 237: Total Reward = -95
# Episode 238: Total Reward = -210
# Episode 239: Total Reward = -66
# Episode 240: Total Reward = 9
# Episode 241: Total Reward = -235
# Episode 242: Total Reward = -172
# Episode 243: Total Reward = -88
# Episode 244: Total Reward = -93
# Episode 245: Total Reward = -247
# Episode 246: Total Reward = -86
# Episode 247: Total Reward = -73
# Episode 248: Total Reward = 13
# Episode 249: Total Reward = -157
# Episode 250: Total Reward = -20
# Episode 251: Total Reward = -791
# Episode 252: Total Reward = -6
# Episode 253: Total Reward = 13
# Episode 254: Total Reward = -240
# Episode 255: Total Reward = -760
# Episode 256: Total Reward = -401
# Episode 257: Total Reward = 14
# Episode 258: Total Reward = -9
# Episode 259: Total Reward = -360
# Episode 260: Total Reward = 12
# Episode 261: Total Reward = -86
# Episode 262: Total Reward = -4
# Episode 263: Total Reward = -162
# Episode 264: Total Reward = -125
# Episode 265: Total Reward = -105
# Episode 266: Total Reward = -257
# Episode 267: Total Reward = -234
# Episode 268: Total Reward = -114
# Episode 269: Total Reward = -58
# Episode 270: Total Reward = -17
# Episode 271: Total Reward = -2
# Episode 272: Total Reward = -16
# Episode 273: Total Reward = -179
# Episode 274: Total Reward = -35
# Episode 275: Total Reward = -321
# Episode 276: Total Reward = -58
# Episode 277: Total Reward = -212
# Episode 278: Total Reward = -84
# Episode 279: Total Reward = -5
# Episode 280: Total Reward = -195
# Episode 281: Total Reward = -134
# Episode 282: Total Reward = -80
# Episode 283: Total Reward = -659
# Episode 284: Total Reward = -34
# Episode 285: Total Reward = 10
# Episode 286: Total Reward = -58
# Episode 287: Total Reward = -191
# Episode 288: Total Reward = -175
# Episode 289: Total Reward = -4
# Episode 290: Total Reward = 1
# Episode 291: Total Reward = -242
# Episode 292: Total Reward = 15
# Episode 293: Total Reward = 9
# Episode 294: Total Reward = -49
# Episode 295: Total Reward = -139
# Episode 296: Total Reward = -91
# Episode 297: Total Reward = 11
# Episode 298: Total Reward = -17
# Episode 299: Total Reward = -257
# Episode 300: Total Reward = -138
# Episode 301: Total Reward = 0
# Episode 302: Total Reward = -30
# Episode 303: Total Reward = -248
# Episode 304: Total Reward = -21
# Episode 305: Total Reward = -12
# Episode 306: Total Reward = -53
# Episode 307: Total Reward = -9
# Episode 308: Total Reward = -264
# Episode 309: Total Reward = -230
# Episode 310: Total Reward = -80
# Episode 311: Total Reward = -36
# Episode 312: Total Reward = -56
# Episode 313: Total Reward = 7
# Episode 314: Total Reward = -261
# Episode 315: Total Reward = -110
# Episode 316: Total Reward = -30
# Episode 317: Total Reward = -254
# Episode 318: Total Reward = -77
# Episode 319: Total Reward = -116
# Episode 320: Total Reward = -80
# Episode 321: Total Reward = 9
# Episode 322: Total Reward = 12
# Episode 323: Total Reward = -119
# Episode 324: Total Reward = 5
# Episode 325: Total Reward = -73
# Episode 326: Total Reward = 1
# Episode 327: Total Reward = -81
# Episode 328: Total Reward = -242
# Episode 329: Total Reward = -430
# Episode 330: Total Reward = -17
# Episode 331: Total Reward = 8
# Episode 332: Total Reward = -29
# Episode 333: Total Reward = -121
# Episode 334: Total Reward = -286
# Episode 335: Total Reward = 1
# Episode 336: Total Reward = -79
# Episode 337: Total Reward = -108
# Episode 338: Total Reward = 7
# Episode 339: Total Reward = -31
# Episode 340: Total Reward = -110
# Episode 341: Total Reward = -123
# Episode 342: Total Reward = -19
# Episode 343: Total Reward = -213
# Episode 344: Total Reward = 12
# Episode 345: Total Reward = -109
# Episode 346: Total Reward = -17
# Episode 347: Total Reward = -293
# Episode 348: Total Reward = -202
# Episode 349: Total Reward = 12
# Episode 350: Total Reward = 15
# Episode 351: Total Reward = -6
# Episode 352: Total Reward = -181
# Episode 353: Total Reward = 10
# Episode 354: Total Reward = -224
# Episode 355: Total Reward = -47
# Episode 356: Total Reward = 13
# Episode 357: Total Reward = -115
# Episode 358: Total Reward = -175
# Episode 359: Total Reward = -276
# Episode 360: Total Reward = -167
# Episode 361: Total Reward = -15
# Episode 362: Total Reward = -97
# Episode 363: Total Reward = -270
# Episode 364: Total Reward = -13
# Episode 365: Total Reward = 5
# Episode 366: Total Reward = 12
# Episode 367: Total Reward = 12
# Episode 368: Total Reward = -284
# Episode 369: Total Reward = -81
# Episode 370: Total Reward = -240
# Episode 371: Total Reward = 2
# Episode 372: Total Reward = -16
# Episode 373: Total Reward = -76
# Episode 374: Total Reward = -257
# Episode 375: Total Reward = -281
# Episode 376: Total Reward = 7
# Episode 377: Total Reward = -51
# Episode 378: Total Reward = 11
# Episode 379: Total Reward = -15
# Episode 380: Total Reward = -48
# Episode 381: Total Reward = -169
# Episode 382: Total Reward = -12
# Episode 383: Total Reward = -8
# Episode 384: Total Reward = 2
# Episode 385: Total Reward = 12
# Episode 386: Total Reward = 4
# Episode 387: Total Reward = -199
# Episode 388: Total Reward = -26
# Episode 389: Total Reward = 0
# Episode 390: Total Reward = -376
# Episode 391: Total Reward = -72
# Episode 392: Total Reward = -222
# Episode 393: Total Reward = 10
# Episode 394: Total Reward = -56
# Episode 395: Total Reward = 12
# Episode 396: Total Reward = -112
# Episode 397: Total Reward = 9
# Episode 398: Total Reward = -10
# Episode 399: Total Reward = -9
# Episode 400: Total Reward = -33
# Episode 401: Total Reward = -155
# Episode 402: Total Reward = 12
# Episode 403: Total Reward = -36
# Episode 404: Total Reward = -126
# Episode 405: Total Reward = -24
# Episode 406: Total Reward = -52
# Episode 407: Total Reward = 14
# Episode 408: Total Reward = -7
# Episode 409: Total Reward = 7
# Episode 410: Total Reward = -131
# Episode 411: Total Reward = -2
# Episode 412: Total Reward = -113
# Episode 413: Total Reward = -54
# Episode 414: Total Reward = -79
# Episode 415: Total Reward = -115
# Episode 416: Total Reward = -600
# Episode 417: Total Reward = -5
# Episode 418: Total Reward = -86
# Episode 419: Total Reward = -133
# Episode 420: Total Reward = -223
# Episode 421: Total Reward = 12
# Episode 422: Total Reward = -55
# Episode 423: Total Reward = 12
# Episode 424: Total Reward = -39
# Episode 425: Total Reward = 11
# Episode 426: Total Reward = 10
# Episode 427: Total Reward = -60
# Episode 428: Total Reward = -86
# Episode 429: Total Reward = 12
# Episode 430: Total Reward = -28
# Episode 431: Total Reward = 9
# Episode 432: Total Reward = -30
# Episode 433: Total Reward = -18
# Episode 434: Total Reward = -108
# Episode 435: Total Reward = -79
# Episode 436: Total Reward = 15
# Episode 437: Total Reward = -38
# Episode 438: Total Reward = 10
# Episode 439: Total Reward = -13
# Episode 440: Total Reward = -12
# Episode 441: Total Reward = -44
# Episode 442: Total Reward = 3
# Episode 443: Total Reward = 9
# Episode 444: Total Reward = -125
# Episode 445: Total Reward = 9
# Episode 446: Total Reward = -62
# Episode 447: Total Reward = -41
# Episode 448: Total Reward = -132
# Episode 449: Total Reward = -19
# Episode 450: Total Reward = -63
# Episode 451: Total Reward = -229
# Episode 452: Total Reward = -15
# Episode 453: Total Reward = -43
# Episode 454: Total Reward = -29
# Episode 455: Total Reward = 1
# Episode 456: Total Reward = 10
# Episode 457: Total Reward = -167
# Episode 458: Total Reward = 9
# Episode 459: Total Reward = 9
# Episode 460: Total Reward = 12
# Episode 461: Total Reward = -92
# Episode 462: Total Reward = -52
# Episode 463: Total Reward = 8
# Episode 464: Total Reward = -48
# Episode 465: Total Reward = 14
# Episode 466: Total Reward = -193
# Episode 467: Total Reward = 10
# Episode 468: Total Reward = -186
# Episode 469: Total Reward = -26
# Episode 470: Total Reward = 11
# Episode 471: Total Reward = -231
# Episode 472: Total Reward = 7
# Episode 473: Total Reward = -25
# Episode 474: Total Reward = -126
# Episode 475: Total Reward = 13
# Episode 476: Total Reward = 9
# Episode 477: Total Reward = -105
# Episode 478: Total Reward = 2
# Episode 479: Total Reward = 6
# Episode 480: Total Reward = -228
# Episode 481: Total Reward = 3
# Episode 482: Total Reward = -134
# Episode 483: Total Reward = -39
# Episode 484: Total Reward = -288
# Episode 485: Total Reward = -42
# Episode 486: Total Reward = 11
# Episode 487: Total Reward = -213
# Episode 488: Total Reward = -21
# Episode 489: Total Reward = -42
# Episode 490: Total Reward = -1
# Episode 491: Total Reward = 4
# Episode 492: Total Reward = -126
# Episode 493: Total Reward = -150
# Episode 494: Total Reward = -292
# Episode 495: Total Reward = 11
# Episode 496: Total Reward = 8
# Episode 497: Total Reward = 11
# Episode 498: Total Reward = 14
# Episode 499: Total Reward = 6
# Episode 500: Total Reward = -15
# Episode 501: Total Reward = -35
# Episode 502: Total Reward = -13
# Episode 503: Total Reward = 11
# Episode 504: Total Reward = 12
# Episode 505: Total Reward = -81
# Episode 506: Total Reward = 14
# Episode 507: Total Reward = 11
# Episode 508: Total Reward = -91
# Episode 509: Total Reward = -278
# Episode 510: Total Reward = 9
# Episode 511: Total Reward = 12
# Episode 512: Total Reward = -74
# Episode 513: Total Reward = -16
# Episode 514: Total Reward = 10
# Episode 515: Total Reward = 5
# Episode 516: Total Reward = 14
# Episode 517: Total Reward = 10
# Episode 518: Total Reward = -1
# Episode 519: Total Reward = -149
# Episode 520: Total Reward = -21
# Episode 521: Total Reward = -207
# Episode 522: Total Reward = 8
# Episode 523: Total Reward = -35
# Episode 524: Total Reward = -98
# Episode 525: Total Reward = -204
# Episode 526: Total Reward = -34
# Episode 527: Total Reward = -132
# Episode 528: Total Reward = -226
# Episode 529: Total Reward = 11
# Episode 530: Total Reward = 7
# Episode 531: Total Reward = 13
# Episode 532: Total Reward = 10
# Episode 533: Total Reward = 0
# Episode 534: Total Reward = 10
# Episode 535: Total Reward = -7
# Episode 536: Total Reward = 12
# Episode 537: Total Reward = 3
# Episode 538: Total Reward = 9
# Episode 539: Total Reward = 14
# Episode 540: Total Reward = -56
# Episode 541: Total Reward = 9
# Episode 542: Total Reward = -231
# Episode 543: Total Reward = -313
# Episode 544: Total Reward = -3
# Episode 545: Total Reward = -39
# Episode 546: Total Reward = -26
# Episode 547: Total Reward = -48
# Episode 548: Total Reward = -156
# Episode 549: Total Reward = -30
# Episode 550: Total Reward = 14
# Episode 551: Total Reward = -15
# Episode 552: Total Reward = -8
# Episode 553: Total Reward = -11
# Episode 554: Total Reward = 8
# Episode 555: Total Reward = -20
# Episode 556: Total Reward = 8
# Episode 557: Total Reward = 13
# Episode 558: Total Reward = 4
# Episode 559: Total Reward = -2
# Episode 560: Total Reward = 12
# Episode 561: Total Reward = -119
# Episode 562: Total Reward = -1
# Episode 563: Total Reward = 6
# Episode 564: Total Reward = 11
# Episode 565: Total Reward = -10
# Episode 566: Total Reward = -47
# Episode 567: Total Reward = -16
# Episode 568: Total Reward = -2
# Episode 569: Total Reward = 7
# Episode 570: Total Reward = -73
# Episode 571: Total Reward = -16
# Episode 572: Total Reward = -21
# Episode 573: Total Reward = 6
# Episode 574: Total Reward = -31
# Episode 575: Total Reward = 3
# Episode 576: Total Reward = 6
# Episode 577: Total Reward = 15
# Episode 578: Total Reward = -49
# Episode 579: Total Reward = -72
# Episode 580: Total Reward = 11
# Episode 581: Total Reward = -85
# Episode 582: Total Reward = 8
# Episode 583: Total Reward = 7
# Episode 584: Total Reward = 11
# Episode 585: Total Reward = -22
# Episode 586: Total Reward = 10
# Episode 587: Total Reward = -14
# Episode 588: Total Reward = 10
# Episode 589: Total Reward = 7
# Episode 590: Total Reward = 10
# Episode 591: Total Reward = -90
# Episode 592: Total Reward = -6
# Episode 593: Total Reward = -96
# Episode 594: Total Reward = -2
# Episode 595: Total Reward = 12
# Episode 596: Total Reward = -626
# Episode 597: Total Reward = 4
# Episode 598: Total Reward = -152
# Episode 599: Total Reward = 11
# Episode 600: Total Reward = -6
# Episode 601: Total Reward = 11
# Episode 602: Total Reward = -1
# Episode 603: Total Reward = 1
# Episode 604: Total Reward = -162
# Episode 605: Total Reward = -104
# Episode 606: Total Reward = 10
# Episode 607: Total Reward = 6
# Episode 608: Total Reward = 3
# Episode 609: Total Reward = -11
# Episode 610: Total Reward = -78
# Episode 611: Total Reward = 13
# Episode 612: Total Reward = -60
# Episode 613: Total Reward = 6
# Episode 614: Total Reward = 11
# Episode 615: Total Reward = -1
# Episode 616: Total Reward = 0
# Episode 617: Total Reward = -2
# Episode 618: Total Reward = -80
# Episode 619: Total Reward = 8
# Episode 620: Total Reward = -45
# Episode 621: Total Reward = 9
# Episode 622: Total Reward = -22
# Episode 623: Total Reward = -65
# Episode 624: Total Reward = 9
# Episode 625: Total Reward = -113
# Episode 626: Total Reward = -94
# Episode 627: Total Reward = -6
# Episode 628: Total Reward = -23
# Episode 629: Total Reward = -7
# Episode 630: Total Reward = 15
# Episode 631: Total Reward = 9
# Episode 632: Total Reward = -55
# Episode 633: Total Reward = 10
# Episode 634: Total Reward = 0
# Episode 635: Total Reward = 13
# Episode 636: Total Reward = 8
# Episode 637: Total Reward = 10
# Episode 638: Total Reward = 8
# Episode 639: Total Reward = -122
# Episode 640: Total Reward = 12
# Episode 641: Total Reward = 12
# Episode 642: Total Reward = -119
# Episode 643: Total Reward = 11
# Episode 644: Total Reward = -52
# Episode 645: Total Reward = 11
# Episode 646: Total Reward = -25
# Episode 647: Total Reward = 11
# Episode 648: Total Reward = 1
# Episode 649: Total Reward = -18
# Episode 650: Total Reward = -63
# Episode 651: Total Reward = -7
# Episode 652: Total Reward = 10
# Episode 653: Total Reward = -20
# Episode 654: Total Reward = -5
# Episode 655: Total Reward = -80
# Episode 656: Total Reward = 10
# Episode 657: Total Reward = 6
# Episode 658: Total Reward = -3
# Episode 659: Total Reward = 4
# Episode 660: Total Reward = -9
# Episode 661: Total Reward = 9
# Episode 662: Total Reward = -19
# Episode 663: Total Reward = 9
# Episode 664: Total Reward = -2
# Episode 665: Total Reward = -30
# Episode 666: Total Reward = -24
# Episode 667: Total Reward = 13
# Episode 668: Total Reward = 10
# Episode 669: Total Reward = -10
# Episode 670: Total Reward = -44
# Episode 671: Total Reward = -6
# Episode 672: Total Reward = -6
# Episode 673: Total Reward = 13
# Episode 674: Total Reward = -127
# Episode 675: Total Reward = -6
# Episode 676: Total Reward = 12
# Episode 677: Total Reward = 0
# Episode 678: Total Reward = -124
# Episode 679: Total Reward = -28
# Episode 680: Total Reward = 12
# Episode 681: Total Reward = 9
# Episode 682: Total Reward = -262
# Episode 683: Total Reward = 10
# Episode 684: Total Reward = -1
# Episode 685: Total Reward = 10
# Episode 686: Total Reward = 1
# Episode 687: Total Reward = 14
# Episode 688: Total Reward = 9
# Episode 689: Total Reward = -34
# Episode 690: Total Reward = 10
# Episode 691: Total Reward = 8
# Episode 692: Total Reward = 11
# Episode 693: Total Reward = -122
# Episode 694: Total Reward = 11
# Episode 695: Total Reward = 9
# Episode 696: Total Reward = -13
# Episode 697: Total Reward = -1
# Episode 698: Total Reward = 14
# Episode 699: Total Reward = 8
# Episode 700: Total Reward = 8
# Episode 701: Total Reward = 6
# Episode 702: Total Reward = 7
# Episode 703: Total Reward = -5
# Episode 704: Total Reward = -111
# Episode 705: Total Reward = -62
# Episode 706: Total Reward = 9
# Episode 707: Total Reward = 7
# Episode 708: Total Reward = 10
# Episode 709: Total Reward = 12
# Episode 710: Total Reward = 8
# Episode 711: Total Reward = 11
# Episode 712: Total Reward = -17
# Episode 713: Total Reward = -12
# Episode 714: Total Reward = 14
# Episode 715: Total Reward = -245
# Episode 716: Total Reward = -11
# Episode 717: Total Reward = -101
# Episode 718: Total Reward = 6
# Episode 719: Total Reward = 11
# Episode 720: Total Reward = 8
# Episode 721: Total Reward = 8
# Episode 722: Total Reward = -13
# Episode 723: Total Reward = 10
# Episode 724: Total Reward = 9
# Episode 725: Total Reward = -6
# Episode 726: Total Reward = 7
# Episode 727: Total Reward = -64
# Episode 728: Total Reward = 12
# Episode 729: Total Reward = -8
# Episode 730: Total Reward = -4
# Episode 731: Total Reward = 6
# Episode 732: Total Reward = -29
# Episode 733: Total Reward = -44
# Episode 734: Total Reward = -5
# Episode 735: Total Reward = -100
# Episode 736: Total Reward = -9
# Episode 737: Total Reward = 15
# Episode 738: Total Reward = 15
# Episode 739: Total Reward = -6
# Episode 740: Total Reward = -6
# Episode 741: Total Reward = 2
# Episode 742: Total Reward = 1
# Episode 743: Total Reward = -98
# Episode 744: Total Reward = -125
# Episode 745: Total Reward = 10
# Episode 746: Total Reward = -7
# Episode 747: Total Reward = 0
# Episode 748: Total Reward = 9
# Episode 749: Total Reward = -4
# Episode 750: Total Reward = 7
# Episode 751: Total Reward = -22
# Episode 752: Total Reward = 6
# Episode 753: Total Reward = 10
# Episode 754: Total Reward = -14
# Episode 755: Total Reward = 11
# Episode 756: Total Reward = 10
# Episode 757: Total Reward = -2
# Episode 758: Total Reward = -1
# Episode 759: Total Reward = 11
# Episode 760: Total Reward = -101
# Episode 761: Total Reward = 12
# Episode 762: Total Reward = -21
# Episode 763: Total Reward = -50
# Episode 764: Total Reward = -29
# Episode 765: Total Reward = 10
# Episode 766: Total Reward = 8
# Episode 767: Total Reward = 7
# Episode 768: Total Reward = 7
# Episode 769: Total Reward = 9
# Episode 770: Total Reward = 14
# Episode 771: Total Reward = -2
# Episode 772: Total Reward = 9
# Episode 773: Total Reward = 11
# Episode 774: Total Reward = -132
# Episode 775: Total Reward = -15
# Episode 776: Total Reward = 0
# Episode 777: Total Reward = 11
# Episode 778: Total Reward = -40
# Episode 779: Total Reward = 9
# Episode 780: Total Reward = -14
# Episode 781: Total Reward = -1
# Episode 782: Total Reward = 11
# Episode 783: Total Reward = -2
# Episode 784: Total Reward = 10
# Episode 785: Total Reward = 10
# Episode 786: Total Reward = 6
# Episode 787: Total Reward = 8
# Episode 788: Total Reward = 6
# Episode 789: Total Reward = 10
# Episode 790: Total Reward = 6
# Episode 791: Total Reward = -2
# Episode 792: Total Reward = 10
# Episode 793: Total Reward = -86
# Episode 794: Total Reward = 10
# Episode 795: Total Reward = -1
# Episode 796: Total Reward = 12
# Episode 797: Total Reward = 11
# Episode 798: Total Reward = 0
# Episode 799: Total Reward = 3
# Episode 800: Total Reward = 11
# Episode 801: Total Reward = 10
# Episode 802: Total Reward = -154
# Episode 803: Total Reward = 1
# Episode 804: Total Reward = 10
# Episode 805: Total Reward = 5
# Episode 806: Total Reward = 13
# Episode 807: Total Reward = 9
# Episode 808: Total Reward = 8
# Episode 809: Total Reward = 7
# Episode 810: Total Reward = -4
# Episode 811: Total Reward = 10
# Episode 812: Total Reward = 6
# Episode 813: Total Reward = 12
# Episode 814: Total Reward = -80
# Episode 815: Total Reward = 5
# Episode 816: Total Reward = 8
# Episode 817: Total Reward = 1
# Episode 818: Total Reward = 10
# Episode 819: Total Reward = 9
# Episode 820: Total Reward = 15
# Episode 821: Total Reward = -45
# Episode 822: Total Reward = 10
# Episode 823: Total Reward = 12
# Episode 824: Total Reward = 9
# Episode 825: Total Reward = -7
# Episode 826: Total Reward = 3
# Episode 827: Total Reward = 10
# Episode 828: Total Reward = 1
# Episode 829: Total Reward = 3
# Episode 830: Total Reward = 9
# Episode 831: Total Reward = 8
# Episode 832: Total Reward = 13
# Episode 833: Total Reward = 11
# Episode 834: Total Reward = -7
# Episode 835: Total Reward = 14
# Episode 836: Total Reward = 7
# Episode 837: Total Reward = 11
# Episode 838: Total Reward = 5
# Episode 839: Total Reward = 0
# Episode 840: Total Reward = -1
# Episode 841: Total Reward = 8
# Episode 842: Total Reward = -13
# Episode 843: Total Reward = 6
# Episode 844: Total Reward = -12
# Episode 845: Total Reward = -50
# Episode 846: Total Reward = -94
# Episode 847: Total Reward = 7
# Episode 848: Total Reward = 3
# Episode 849: Total Reward = 0
# Episode 850: Total Reward = 4
# Episode 851: Total Reward = 4
# Episode 852: Total Reward = -36
# Episode 853: Total Reward = 11
# Episode 854: Total Reward = -23
# Episode 855: Total Reward = 3
# Episode 856: Total Reward = 8
# Episode 857: Total Reward = 7
# Episode 858: Total Reward = 12
# Episode 859: Total Reward = 12
# Episode 860: Total Reward = 1
# Episode 861: Total Reward = 8
# Episode 862: Total Reward = 7
# Episode 863: Total Reward = 11
# Episode 864: Total Reward = -15
# Episode 865: Total Reward = -29
# Episode 866: Total Reward = -25
# Episode 867: Total Reward = 13
# Episode 868: Total Reward = 11
# Episode 869: Total Reward = 1
# Episode 870: Total Reward = 7
# Episode 871: Total Reward = 9
# Episode 872: Total Reward = -125
# Episode 873: Total Reward = 7
# Episode 874: Total Reward = 13
# Episode 875: Total Reward = 6
# Episode 876: Total Reward = -7
# Episode 877: Total Reward = 13
# Episode 878: Total Reward = 1
# Episode 879: Total Reward = -15
# Episode 880: Total Reward = 6
# Episode 881: Total Reward = 6
# Episode 882: Total Reward = 11
# Episode 883: Total Reward = 3
# Episode 884: Total Reward = 8
# Episode 885: Total Reward = 1
# Episode 886: Total Reward = 11
# Episode 887: Total Reward = 6
# Episode 888: Total Reward = 8
# Episode 889: Total Reward = 5
# Episode 890: Total Reward = 12
# Episode 891: Total Reward = -7
# Episode 892: Total Reward = 8
# Episode 893: Total Reward = 8
# Episode 894: Total Reward = 4
# Episode 895: Total Reward = 4
# Episode 896: Total Reward = 9
# Episode 897: Total Reward = -3
# Episode 898: Total Reward = 7
# Episode 899: Total Reward = 12
# Episode 900: Total Reward = 6
# Episode 901: Total Reward = -95
# Episode 902: Total Reward = 6
# Episode 903: Total Reward = 11
# Episode 904: Total Reward = 7
# Episode 905: Total Reward = 9
# Episode 906: Total Reward = -4
# Episode 907: Total Reward = -50
# Episode 908: Total Reward = 10
# Episode 909: Total Reward = 9
# Episode 910: Total Reward = 14
# Episode 911: Total Reward = 7
# Episode 912: Total Reward = 11
# Episode 913: Total Reward = 6
# Episode 914: Total Reward = 6
# Episode 915: Total Reward = 13
# Episode 916: Total Reward = 4
# Episode 917: Total Reward = 10
# Episode 918: Total Reward = 8
# Episode 919: Total Reward = -238
# Episode 920: Total Reward = -1
# Episode 921: Total Reward = -105
# Episode 922: Total Reward = 11
# Episode 923: Total Reward = 9
# Episode 924: Total Reward = 7
# Episode 925: Total Reward = 11
# Episode 926: Total Reward = 12
# Episode 927: Total Reward = 10
# Episode 928: Total Reward = 7
# Episode 929: Total Reward = 9
# Episode 930: Total Reward = 3
# Episode 931: Total Reward = -87
# Episode 932: Total Reward = 10
# Episode 933: Total Reward = 9
# Episode 934: Total Reward = -1
# Episode 935: Total Reward = 8
# Episode 936: Total Reward = -10
# Episode 937: Total Reward = 7
# Episode 938: Total Reward = 10
# Episode 939: Total Reward = 7
# Episode 940: Total Reward = 9
# Episode 941: Total Reward = 11
# Episode 942: Total Reward = -14
# Episode 943: Total Reward = 11
# Episode 944: Total Reward = 7
# Episode 945: Total Reward = -23
# Episode 946: Total Reward = 8
# Episode 947: Total Reward = -57
# Episode 948: Total Reward = -53
# Episode 949: Total Reward = -4
# Episode 950: Total Reward = 6
# Episode 951: Total Reward = 7
# Episode 952: Total Reward = 10
# Episode 953: Total Reward = 7
# Episode 954: Total Reward = 9
# Episode 955: Total Reward = 12
# Episode 956: Total Reward = 9
# Episode 957: Total Reward = 1
# Episode 958: Total Reward = 7
# Episode 959: Total Reward = 8
# Episode 960: Total Reward = 9
# Episode 961: Total Reward = -9
# Episode 962: Total Reward = -9
# Episode 963: Total Reward = 11
# Episode 964: Total Reward = 7
# Episode 965: Total Reward = 11
# Episode 966: Total Reward = 6
# Episode 967: Total Reward = 14
# Episode 968: Total Reward = 9
# Episode 969: Total Reward = 8
# Episode 970: Total Reward = -5
# Episode 971: Total Reward = 8
# Episode 972: Total Reward = 11
# Episode 973: Total Reward = 6
# Episode 974: Total Reward = 10
# Episode 975: Total Reward = -64
# Episode 976: Total Reward = 1
# Episode 977: Total Reward = -5
# Episode 978: Total Reward = 10
# Episode 979: Total Reward = 8
# Episode 980: Total Reward = 12
# Episode 981: Total Reward = -9
# Episode 982: Total Reward = 11
# Episode 983: Total Reward = 5
# Episode 984: Total Reward = 5
# Episode 985: Total Reward = 2
# Episode 986: Total Reward = 8
# Episode 987: Total Reward = 4
# Episode 988: Total Reward = 4
# Episode 989: Total Reward = 7
# Episode 990: Total Reward = 12
# Episode 991: Total Reward = 11
# Episode 992: Total Reward = 1
# Episode 993: Total Reward = -4
# Episode 994: Total Reward = -4
# Episode 995: Total Reward = 5
# Episode 996: Total Reward = 7
# Episode 997: Total Reward = -3
# Episode 998: Total Reward = 7
# Episode 999: Total Reward = 1
# Episode 1000: Total Reward = -11
# Episode 1001: Total Reward = 5
# Episode 1002: Total Reward = 7
# Episode 1003: Total Reward = -1
# Episode 1004: Total Reward = 7
# Episode 1005: Total Reward = 9
# Episode 1006: Total Reward = 8
# Episode 1007: Total Reward = 12
# Episode 1008: Total Reward = 13
# Episode 1009: Total Reward = -118
# Episode 1010: Total Reward = 4
# Episode 1011: Total Reward = 11
# Episode 1012: Total Reward = 5
# Episode 1013: Total Reward = 9
# Episode 1014: Total Reward = 8
# Episode 1015: Total Reward = 10
# Episode 1016: Total Reward = 3
# Episode 1017: Total Reward = -9
# Episode 1018: Total Reward = 10
# Episode 1019: Total Reward = 7
# Episode 1020: Total Reward = 11
# Episode 1021: Total Reward = 0
# Episode 1022: Total Reward = 3
# Episode 1023: Total Reward = -47
# Episode 1024: Total Reward = 10
# Episode 1025: Total Reward = 12
# Episode 1026: Total Reward = 6
# Episode 1027: Total Reward = 4
# Episode 1028: Total Reward = 10
# Episode 1029: Total Reward = 6
# Episode 1030: Total Reward = 12
# Episode 1031: Total Reward = 7
# Episode 1032: Total Reward = 7
# Episode 1033: Total Reward = 7
# Episode 1034: Total Reward = 9
# Episode 1035: Total Reward = 4
# Episode 1036: Total Reward = 3
# Episode 1037: Total Reward = -9
# Episode 1038: Total Reward = 10
# Episode 1039: Total Reward = 5
# Episode 1040: Total Reward = 8
# Episode 1041: Total Reward = 10
# Episode 1042: Total Reward = 2
# Episode 1043: Total Reward = 3
# Episode 1044: Total Reward = 9
# Episode 1045: Total Reward = 10
# Episode 1046: Total Reward = 10
# Episode 1047: Total Reward = 9
# Episode 1048: Total Reward = 6
# Episode 1049: Total Reward = 0
# Episode 1050: Total Reward = 4
# Episode 1051: Total Reward = 9
# Episode 1052: Total Reward = 10
# Episode 1053: Total Reward = 2
# Episode 1054: Total Reward = 9
# Episode 1055: Total Reward = -13
# Episode 1056: Total Reward = -16
# Episode 1057: Total Reward = 9
# Episode 1058: Total Reward = -81
# Episode 1059: Total Reward = 8
# Episode 1060: Total Reward = 10
# Episode 1061: Total Reward = 9
# Episode 1062: Total Reward = 14
# Episode 1063: Total Reward = 7
# Episode 1064: Total Reward = -41
# Episode 1065: Total Reward = 11
# Episode 1066: Total Reward = 12
# Episode 1067: Total Reward = 10
# Episode 1068: Total Reward = 10
# Episode 1069: Total Reward = 5
# Episode 1070: Total Reward = 7
# Episode 1071: Total Reward = 6
# Episode 1072: Total Reward = 10
# Episode 1073: Total Reward = 8
# Episode 1074: Total Reward = 10
# Episode 1075: Total Reward = 11
# Episode 1076: Total Reward = 5
# Episode 1077: Total Reward = 8
# Episode 1078: Total Reward = -52
# Episode 1079: Total Reward = 6
# Episode 1080: Total Reward = -10
# Episode 1081: Total Reward = -32
# Episode 1082: Total Reward = 6
# Episode 1083: Total Reward = 4
# Episode 1084: Total Reward = 8
# Episode 1085: Total Reward = 13
# Episode 1086: Total Reward = 11
# Episode 1087: Total Reward = 10
# Episode 1088: Total Reward = 8
# Episode 1089: Total Reward = 6
# Episode 1090: Total Reward = 5
# Episode 1091: Total Reward = 10
# Episode 1092: Total Reward = 8
# Episode 1093: Total Reward = 13
# Episode 1094: Total Reward = 11
# Episode 1095: Total Reward = 4
# Episode 1096: Total Reward = 2
# Episode 1097: Total Reward = 6
# Episode 1098: Total Reward = 9
# Episode 1099: Total Reward = 15
# Episode 1100: Total Reward = 5
# Episode 1101: Total Reward = 9
# Episode 1102: Total Reward = 12
# Episode 1103: Total Reward = 6
# Episode 1104: Total Reward = 5
# Episode 1105: Total Reward = -79
# Episode 1106: Total Reward = 6
# Episode 1107: Total Reward = -1
# Episode 1108: Total Reward = 2
# Episode 1109: Total Reward = 6
# Episode 1110: Total Reward = 7
# Episode 1111: Total Reward = 6
# Episode 1112: Total Reward = 5
# Episode 1113: Total Reward = -24
# Episode 1114: Total Reward = 7
# Episode 1115: Total Reward = 9
# Episode 1116: Total Reward = 7
# Episode 1117: Total Reward = -69
# Episode 1118: Total Reward = 9
# Episode 1119: Total Reward = 8
# Episode 1120: Total Reward = 9
# Episode 1121: Total Reward = 6
# Episode 1122: Total Reward = 9
# Episode 1123: Total Reward = 6
# Episode 1124: Total Reward = 2
# Episode 1125: Total Reward = 4
# Episode 1126: Total Reward = 9
# Episode 1127: Total Reward = 7
# Episode 1128: Total Reward = 9
# Episode 1129: Total Reward = 9
# Episode 1130: Total Reward = 7
# Episode 1131: Total Reward = 10
# Episode 1132: Total Reward = 6
# Episode 1133: Total Reward = 7
# Episode 1134: Total Reward = 9
# Episode 1135: Total Reward = 4
# Episode 1136: Total Reward = 6
# Episode 1137: Total Reward = 10
# Episode 1138: Total Reward = -5
# Episode 1139: Total Reward = 6
# Episode 1140: Total Reward = 11
# Episode 1141: Total Reward = 7
# Episode 1142: Total Reward = 11
# Episode 1143: Total Reward = 11
# Episode 1144: Total Reward = 0
# Episode 1145: Total Reward = 10
# Episode 1146: Total Reward = -35
# Episode 1147: Total Reward = 9
# Episode 1148: Total Reward = 8
# Episode 1149: Total Reward = 8
# Episode 1150: Total Reward = 6
# Episode 1151: Total Reward = 8
# Episode 1152: Total Reward = 12
# Episode 1153: Total Reward = 0
# Episode 1154: Total Reward = 11
# Episode 1155: Total Reward = 7
# Episode 1156: Total Reward = 1
# Episode 1157: Total Reward = 1
# Episode 1158: Total Reward = 13
# Episode 1159: Total Reward = 10
# Episode 1160: Total Reward = 9
# Episode 1161: Total Reward = 7
# Episode 1162: Total Reward = 6
# Episode 1163: Total Reward = 7
# Episode 1164: Total Reward = 7
# Episode 1165: Total Reward = 5
# Episode 1166: Total Reward = 13
# Episode 1167: Total Reward = 9
# Episode 1168: Total Reward = 8
# Episode 1169: Total Reward = 11
# Episode 1170: Total Reward = 8
# Episode 1171: Total Reward = 6
# Episode 1172: Total Reward = 8
# Episode 1173: Total Reward = 3
# Episode 1174: Total Reward = 12
# Episode 1175: Total Reward = 12
# Episode 1176: Total Reward = 5
# Episode 1177: Total Reward = 6
# Episode 1178: Total Reward = 11
# Episode 1179: Total Reward = 12
# Episode 1180: Total Reward = 8
# Episode 1181: Total Reward = 8
# Episode 1182: Total Reward = -9
# Episode 1183: Total Reward = -1
# Episode 1184: Total Reward = 7
# Episode 1185: Total Reward = 6
# Episode 1186: Total Reward = 5
# Episode 1187: Total Reward = 10
# Episode 1188: Total Reward = 5
# Episode 1189: Total Reward = 8
# Episode 1190: Total Reward = 8
# Episode 1191: Total Reward = 7
# Episode 1192: Total Reward = 9
# Episode 1193: Total Reward = 7
# Episode 1194: Total Reward = 5
# Episode 1195: Total Reward = 8
# Episode 1196: Total Reward = 7
# Episode 1197: Total Reward = 8
# Episode 1198: Total Reward = 2
# Episode 1199: Total Reward = 11
# Episode 1200: Total Reward = 9
# Episode 1201: Total Reward = 7
# Episode 1202: Total Reward = 9
# Episode 1203: Total Reward = 11
# Episode 1204: Total Reward = 8
# Episode 1205: Total Reward = 8
# Episode 1206: Total Reward = 12
# Episode 1207: Total Reward = 10
# Episode 1208: Total Reward = 6
# Episode 1209: Total Reward = 6
# Episode 1210: Total Reward = 9
# Episode 1211: Total Reward = 6
# Episode 1212: Total Reward = 6
# Episode 1213: Total Reward = 7
# Episode 1214: Total Reward = 12
# Episode 1215: Total Reward = 12
# Episode 1216: Total Reward = -52
# Episode 1217: Total Reward = 10
# Episode 1218: Total Reward = 6
# Episode 1219: Total Reward = 7
# Episode 1220: Total Reward = 8
# Episode 1221: Total Reward = 5
# Episode 1222: Total Reward = 11
# Episode 1223: Total Reward = 8
# Episode 1224: Total Reward = 12
# Episode 1225: Total Reward = 7
# Episode 1226: Total Reward = -9
# Episode 1227: Total Reward = 10
# Episode 1228: Total Reward = -61
# Episode 1229: Total Reward = 8
# Episode 1230: Total Reward = 8
# Episode 1231: Total Reward = 12
# Episode 1232: Total Reward = 9
# Episode 1233: Total Reward = 7
# Episode 1234: Total Reward = 13
# Episode 1235: Total Reward = -7
# Episode 1236: Total Reward = 10
# Episode 1237: Total Reward = 8
# Episode 1238: Total Reward = -6
# Episode 1239: Total Reward = 10
# Episode 1240: Total Reward = 11
# Episode 1241: Total Reward = 6
# Episode 1242: Total Reward = 9
# Episode 1243: Total Reward = -2
# Episode 1244: Total Reward = 0
# Episode 1245: Total Reward = 6
# Episode 1246: Total Reward = 5
# Episode 1247: Total Reward = 9
# Episode 1248: Total Reward = 10
# Episode 1249: Total Reward = 7
# Episode 1250: Total Reward = 7
# Episode 1251: Total Reward = 11
# Episode 1252: Total Reward = 4
# Episode 1253: Total Reward = 9
# Episode 1254: Total Reward = 8
# Episode 1255: Total Reward = 9
# Episode 1256: Total Reward = 10
# Episode 1257: Total Reward = 6
# Episode 1258: Total Reward = 9
# Episode 1259: Total Reward = 8
# Episode 1260: Total Reward = 12
# Episode 1261: Total Reward = 4
# Episode 1262: Total Reward = 9
# Episode 1263: Total Reward = 1
# Episode 1264: Total Reward = 8
# Episode 1265: Total Reward = -7
# Episode 1266: Total Reward = 5
# Episode 1267: Total Reward = 10
# Episode 1268: Total Reward = 10
# Episode 1269: Total Reward = 7
# Episode 1270: Total Reward = 8
# Episode 1271: Total Reward = 5
# Episode 1272: Total Reward = -120
# Episode 1273: Total Reward = 6
# Episode 1274: Total Reward = 5
# Episode 1275: Total Reward = 8
# Episode 1276: Total Reward = 9
# Episode 1277: Total Reward = 9
# Episode 1278: Total Reward = 8
# Episode 1279: Total Reward = 12
# Episode 1280: Total Reward = 5
# Episode 1281: Total Reward = 15
# Episode 1282: Total Reward = 10
# Episode 1283: Total Reward = 0
# Episode 1284: Total Reward = 4
# Episode 1285: Total Reward = 10
# Episode 1286: Total Reward = 9
# Episode 1287: Total Reward = 7
# Episode 1288: Total Reward = 9
# Episode 1289: Total Reward = 9
# Episode 1290: Total Reward = 10
# Episode 1291: Total Reward = 1
# Episode 1292: Total Reward = 9
# Episode 1293: Total Reward = 11
# Episode 1294: Total Reward = 8
# Episode 1295: Total Reward = 9
# Episode 1296: Total Reward = 4
# Episode 1297: Total Reward = -2
# Episode 1298: Total Reward = -2
# Episode 1299: Total Reward = 8
# Episode 1300: Total Reward = -4
# Episode 1301: Total Reward = 8
# Episode 1302: Total Reward = 11
# Episode 1303: Total Reward = 8
# Episode 1304: Total Reward = 7
# Episode 1305: Total Reward = -30
# Episode 1306: Total Reward = 8
# Episode 1307: Total Reward = 8
# Episode 1308: Total Reward = 10
# Episode 1309: Total Reward = 10
# Episode 1310: Total Reward = 5
# Episode 1311: Total Reward = 9
# Episode 1312: Total Reward = 3
# Episode 1313: Total Reward = 10
# Episode 1314: Total Reward = -5
# Episode 1315: Total Reward = -3
# Episode 1316: Total Reward = -100
# Episode 1317: Total Reward = 5
# Episode 1318: Total Reward = 5
# Episode 1319: Total Reward = 12
# Episode 1320: Total Reward = 8
# Episode 1321: Total Reward = 7
# Episode 1322: Total Reward = 11
# Episode 1323: Total Reward = 5
# Episode 1324: Total Reward = 9
# Episode 1325: Total Reward = -1
# Episode 1326: Total Reward = 6
# Episode 1327: Total Reward = 11
# Episode 1328: Total Reward = 9
# Episode 1329: Total Reward = 10
# Episode 1330: Total Reward = 0
# Episode 1331: Total Reward = -82
# Episode 1332: Total Reward = -7
# Episode 1333: Total Reward = 5
# Episode 1334: Total Reward = 6
# Episode 1335: Total Reward = 12
# Episode 1336: Total Reward = 9
# Episode 1337: Total Reward = 13
# Episode 1338: Total Reward = -2
# Episode 1339: Total Reward = 10
# Episode 1340: Total Reward = 11
# Episode 1341: Total Reward = 4
# Episode 1342: Total Reward = 8
# Episode 1343: Total Reward = 8
# Episode 1344: Total Reward = -74
# Episode 1345: Total Reward = 6
# Episode 1346: Total Reward = 7
# Episode 1347: Total Reward = 9
# Episode 1348: Total Reward = 7
# Episode 1349: Total Reward = 5
# Episode 1350: Total Reward = 5
# Episode 1351: Total Reward = 6
# Episode 1352: Total Reward = -5
# Episode 1353: Total Reward = 9
# Episode 1354: Total Reward = 6
# Episode 1355: Total Reward = 8
# Episode 1356: Total Reward = 8
# Episode 1357: Total Reward = 6
# Episode 1358: Total Reward = 8
# Episode 1359: Total Reward = 9
# Episode 1360: Total Reward = 11
# Episode 1361: Total Reward = -77
# Episode 1362: Total Reward = 5
# Episode 1363: Total Reward = 11
# Episode 1364: Total Reward = 8
# Episode 1365: Total Reward = 5
# Episode 1366: Total Reward = 11
# Episode 1367: Total Reward = 6
# Episode 1368: Total Reward = 12
# Episode 1369: Total Reward = 6
# Episode 1370: Total Reward = -112
# Episode 1371: Total Reward = 10
# Episode 1372: Total Reward = -14
# Episode 1373: Total Reward = 10
# Episode 1374: Total Reward = 8
# Episode 1375: Total Reward = 14
# Episode 1376: Total Reward = 6
# Episode 1377: Total Reward = 12
# Episode 1378: Total Reward = 8
# Episode 1379: Total Reward = 5
# Episode 1380: Total Reward = 8
# Episode 1381: Total Reward = 13
# Episode 1382: Total Reward = -62
# Episode 1383: Total Reward = 11
# Episode 1384: Total Reward = 3
# Episode 1385: Total Reward = 9
# Episode 1386: Total Reward = 4
# Episode 1387: Total Reward = 6
# Episode 1388: Total Reward = 12
# Episode 1389: Total Reward = -82
# Episode 1390: Total Reward = 2
# Episode 1391: Total Reward = 4
# Episode 1392: Total Reward = 5
# Episode 1393: Total Reward = 8
# Episode 1394: Total Reward = 7
# Episode 1395: Total Reward = 5
# Episode 1396: Total Reward = 8
# Episode 1397: Total Reward = 9
# Episode 1398: Total Reward = 8
# Episode 1399: Total Reward = 4
# Episode 1400: Total Reward = 5
# Episode 1401: Total Reward = 9
# Episode 1402: Total Reward = 12
# Episode 1403: Total Reward = -1
# Episode 1404: Total Reward = 10
# Episode 1405: Total Reward = 8
# Episode 1406: Total Reward = 4
# Episode 1407: Total Reward = 9
# Episode 1408: Total Reward = 8
# Episode 1409: Total Reward = 11
# Episode 1410: Total Reward = 12
# Episode 1411: Total Reward = 11
# Episode 1412: Total Reward = 11
# Episode 1413: Total Reward = 15
# Episode 1414: Total Reward = 7
# Episode 1415: Total Reward = 7
# Episode 1416: Total Reward = 4
# Episode 1417: Total Reward = 7
# Episode 1418: Total Reward = 8
# Episode 1419: Total Reward = 8
# Episode 1420: Total Reward = -4
# Episode 1421: Total Reward = 6
# Episode 1422: Total Reward = 10
# Episode 1423: Total Reward = 7
# Episode 1424: Total Reward = 11
# Episode 1425: Total Reward = 11
# Episode 1426: Total Reward = 4
# Episode 1427: Total Reward = 11
# Episode 1428: Total Reward = 6
# Episode 1429: Total Reward = 8
# Episode 1430: Total Reward = 11
# Episode 1431: Total Reward = 9
# Episode 1432: Total Reward = 5
# Episode 1433: Total Reward = 10
# Episode 1434: Total Reward = 8
# Episode 1435: Total Reward = 4
# Episode 1436: Total Reward = 10
# Episode 1437: Total Reward = 11
# Episode 1438: Total Reward = 0
# Episode 1439: Total Reward = 7
# Episode 1440: Total Reward = 5
# Episode 1441: Total Reward = 7
# Episode 1442: Total Reward = 7
# Episode 1443: Total Reward = 8
# Episode 1444: Total Reward = 9
# Episode 1445: Total Reward = 7
# Episode 1446: Total Reward = 3
# Episode 1447: Total Reward = 11
# Episode 1448: Total Reward = 7
# Episode 1449: Total Reward = 10
# Episode 1450: Total Reward = 10
# Episode 1451: Total Reward = 10
# Episode 1452: Total Reward = 12
# Episode 1453: Total Reward = 8
# Episode 1454: Total Reward = 6
# Episode 1455: Total Reward = 8
# Episode 1456: Total Reward = 10
# Episode 1457: Total Reward = 8
# Episode 1458: Total Reward = 11
# Episode 1459: Total Reward = 9
# Episode 1460: Total Reward = 9
# Episode 1461: Total Reward = 6
# Episode 1462: Total Reward = 6
# Episode 1463: Total Reward = 7
# Episode 1464: Total Reward = -17
# Episode 1465: Total Reward = 9
# Episode 1466: Total Reward = 14
# Episode 1467: Total Reward = 7
# Episode 1468: Total Reward = 7
# Episode 1469: Total Reward = 6
# Episode 1470: Total Reward = 9
# Episode 1471: Total Reward = -95
# Episode 1472: Total Reward = 13
# Episode 1473: Total Reward = 4
# Episode 1474: Total Reward = 7
# Episode 1475: Total Reward = 8
# Episode 1476: Total Reward = 10
# Episode 1477: Total Reward = 7
# Episode 1478: Total Reward = 9
# Episode 1479: Total Reward = 7
# Episode 1480: Total Reward = 9
# Episode 1481: Total Reward = 8
# Episode 1482: Total Reward = 10
# Episode 1483: Total Reward = 0
# Episode 1484: Total Reward = 12
# Episode 1485: Total Reward = 11
# Episode 1486: Total Reward = 7
# Episode 1487: Total Reward = 12
# Episode 1488: Total Reward = 10
# Episode 1489: Total Reward = 9
# Episode 1490: Total Reward = 15
# Episode 1491: Total Reward = 5
# Episode 1492: Total Reward = 9
# Episode 1493: Total Reward = 9
# Episode 1494: Total Reward = 7
# Episode 1495: Total Reward = 8
# Episode 1496: Total Reward = -10
# Episode 1497: Total Reward = -96
# Episode 1498: Total Reward = 5
# Episode 1499: Total Reward = 3
# Episode 1500: Total Reward = 8
# Episode 1501: Total Reward = 5
# Episode 1502: Total Reward = -83
# Episode 1503: Total Reward = 11
# Episode 1504: Total Reward = 7
# Episode 1505: Total Reward = 10
# Episode 1506: Total Reward = 3
# Episode 1507: Total Reward = 5
# Episode 1508: Total Reward = 5
# Episode 1509: Total Reward = -68
# Episode 1510: Total Reward = 8
# Episode 1511: Total Reward = 8
# Episode 1512: Total Reward = 10
# Episode 1513: Total Reward = 6
# Episode 1514: Total Reward = 6
# Episode 1515: Total Reward = -4
# Episode 1516: Total Reward = 9
# Episode 1517: Total Reward = 11
# Episode 1518: Total Reward = 8
# Episode 1519: Total Reward = 10
# Episode 1520: Total Reward = 0
# Episode 1521: Total Reward = 10
# Episode 1522: Total Reward = 7
# Episode 1523: Total Reward = 0
# ...
# Episode 4491: Total Reward = 8
# Episode 4492: Total Reward = 11
# Episode 4493: Total Reward = 10
# Episode 4494: Total Reward = 7
# Episode 4495: Total Reward = 5
# Episode 4496: Total Reward = 9
# Episode 4497: Total Reward = 11
# Episode 4498: Total Reward = 10
# Episode 4499: Total Reward = -6
# Episode 4500: Total Reward = 9
# Episode 4501: Total Reward = 7
# Episode 4502: Total Reward = -193
# Episode 4503: Total Reward = 10
# Episode 4504: Total Reward = 11
# Episode 4505: Total Reward = -11
# Episode 4506: Total Reward = 9
# Episode 4507: Total Reward = 6
# Episode 4508: Total Reward = 8
# Episode 4509: Total Reward = 11
# Episode 4510: Total Reward = 7
# Episode 4511: Total Reward = 3
# Episode 4512: Total Reward = 9
# Episode 4513: Total Reward = 4
# Episode 4514: Total Reward = 8
# Episode 4515: Total Reward = 10
# Episode 4516: Total Reward = -28
# Episode 4517: Total Reward = 8
# Episode 4518: Total Reward = 10
# Episode 4519: Total Reward = 8
# Episode 4520: Total Reward = 7
# Episode 4521: Total Reward = 4
# Episode 4522: Total Reward = 7
# Episode 4523: Total Reward = 11
# Episode 4524: Total Reward = 10
# Episode 4525: Total Reward = 10
# Episode 4526: Total Reward = 6
# Episode 4527: Total Reward = 8
# Episode 4528: Total Reward = 7
# Episode 4529: Total Reward = 7
# Episode 4530: Total Reward = 8
# Episode 4531: Total Reward = 6
# Episode 4532: Total Reward = 6
# Episode 4533: Total Reward = 7
# Episode 4534: Total Reward = 8
# Episode 4535: Total Reward = 8
# Episode 4536: Total Reward = 11
# Episode 4537: Total Reward = 12
# Episode 4538: Total Reward = 8
# Episode 4539: Total Reward = 14
# Episode 4540: Total Reward = 9
# Episode 4541: Total Reward = 9
# Episode 4542: Total Reward = 9
# Episode 4543: Total Reward = 7
# Episode 4544: Total Reward = 7
# Episode 4545: Total Reward = 9
# Episode 4546: Total Reward = 10
# Episode 4547: Total Reward = 5
# Episode 4548: Total Reward = 8
# Episode 4549: Total Reward = 2
# Episode 4550: Total Reward = 8
# Episode 4551: Total Reward = 8
# Episode 4552: Total Reward = 14
# Episode 4553: Total Reward = 6
# Episode 4554: Total Reward = 11
# Episode 4555: Total Reward = 13
# Episode 4556: Total Reward = 11
# Episode 4557: Total Reward = 8
# Episode 4558: Total Reward = 13
# Episode 4559: Total Reward = 9
# Episode 4560: Total Reward = 9
# Episode 4561: Total Reward = 7
# Episode 4562: Total Reward = 12
# Episode 4563: Total Reward = 10
# Episode 4564: Total Reward = 8
# Episode 4565: Total Reward = 9
# Episode 4566: Total Reward = 7
# Episode 4567: Total Reward = 8
# Episode 4568: Total Reward = 9
# Episode 4569: Total Reward = -5
# Episode 4570: Total Reward = 7
# Episode 4571: Total Reward = 4
# Episode 4572: Total Reward = 3
# Episode 4573: Total Reward = 8
# Episode 4574: Total Reward = 10
# Episode 4575: Total Reward = 5
# Episode 4576: Total Reward = 10
# Episode 4577: Total Reward = 6
# Episode 4578: Total Reward = 5
# Episode 4579: Total Reward = 7
# Episode 4580: Total Reward = 6
# Episode 4581: Total Reward = 10
# Episode 4582: Total Reward = 9
# Episode 4583: Total Reward = 9
# Episode 4584: Total Reward = 12
# Episode 4585: Total Reward = 12
# Episode 4586: Total Reward = 11
# Episode 4587: Total Reward = 7
# Episode 4588: Total Reward = 9
# Episode 4589: Total Reward = 12
# Episode 4590: Total Reward = 8
# Episode 4591: Total Reward = 8
# Episode 4592: Total Reward = 9
# Episode 4593: Total Reward = 11
# Episode 4594: Total Reward = 8
# Episode 4595: Total Reward = 6
# Episode 4596: Total Reward = 5
# Episode 4597: Total Reward = 9
# Episode 4598: Total Reward = 10
# Episode 4599: Total Reward = 7
# Episode 4600: Total Reward = 5
# Episode 4601: Total Reward = 8
# Episode 4602: Total Reward = 8
# Episode 4603: Total Reward = 9
# Episode 4604: Total Reward = 10
# Episode 4605: Total Reward = 9
# Episode 4606: Total Reward = 8
# Episode 4607: Total Reward = 11
# Episode 4608: Total Reward = 7
# Episode 4609: Total Reward = 8
# Episode 4610: Total Reward = 8
# Episode 4611: Total Reward = 10
# Episode 4612: Total Reward = 10
# Episode 4613: Total Reward = 10
# Episode 4614: Total Reward = 10
# Episode 4615: Total Reward = 9
# Episode 4616: Total Reward = 11
# Episode 4617: Total Reward = 6
# Episode 4618: Total Reward = 12
# Episode 4619: Total Reward = 9
# Episode 4620: Total Reward = 10
# Episode 4621: Total Reward = 11
# Episode 4622: Total Reward = 6
# Episode 4623: Total Reward = 13
# Episode 4624: Total Reward = 7
# Episode 4625: Total Reward = 7
# Episode 4626: Total Reward = 7
# Episode 4627: Total Reward = 6
# Episode 4628: Total Reward = 8
# Episode 4629: Total Reward = 11
# Episode 4630: Total Reward = 11
# Episode 4631: Total Reward = 6
# Episode 4632: Total Reward = 8
# Episode 4633: Total Reward = 6
# Episode 4634: Total Reward = 7
# Episode 4635: Total Reward = 10
# Episode 4636: Total Reward = 6
# Episode 4637: Total Reward = -80
# Episode 4638: Total Reward = 11
# Episode 4639: Total Reward = 4
# Episode 4640: Total Reward = 7
# Episode 4641: Total Reward = 10
# Episode 4642: Total Reward = 8
# Episode 4643: Total Reward = 7
# Episode 4644: Total Reward = 5
# Episode 4645: Total Reward = 10
# Episode 4646: Total Reward = 8
# Episode 4647: Total Reward = 6
# Episode 4648: Total Reward = 9
# Episode 4649: Total Reward = 6
# Episode 4650: Total Reward = 5
# Episode 4651: Total Reward = 8
# Episode 4652: Total Reward = 10
# Episode 4653: Total Reward = 5
# Episode 4654: Total Reward = 10
# Episode 4655: Total Reward = 5
# Episode 4656: Total Reward = 6
# Episode 4657: Total Reward = -70
# Episode 4658: Total Reward = 7
# Episode 4659: Total Reward = -3
# Episode 4660: Total Reward = 6
# Episode 4661: Total Reward = 9
# Episode 4662: Total Reward = 6
# Episode 4663: Total Reward = 5
# Episode 4664: Total Reward = 11
# Episode 4665: Total Reward = 7
# Episode 4666: Total Reward = 3
# Episode 4667: Total Reward = 10
# Episode 4668: Total Reward = 10
# Episode 4669: Total Reward = 5
# Episode 4670: Total Reward = 9
# Episode 4671: Total Reward = 7
# Episode 4672: Total Reward = 11
# Episode 4673: Total Reward = 6
# Episode 4674: Total Reward = 7
# Episode 4675: Total Reward = 10
# Episode 4676: Total Reward = 9
# Episode 4677: Total Reward = 13
# Episode 4678: Total Reward = 5
# Episode 4679: Total Reward = 7
# Episode 4680: Total Reward = 7
# Episode 4681: Total Reward = 10
# Episode 4682: Total Reward = 8
# Episode 4683: Total Reward = 10
# Episode 4684: Total Reward = 7
# Episode 4685: Total Reward = 6
# Episode 4686: Total Reward = 5
# Episode 4687: Total Reward = 8
# Episode 4688: Total Reward = 8
# Episode 4689: Total Reward = 6
# Episode 4690: Total Reward = 9
# Episode 4691: Total Reward = 9
# Episode 4692: Total Reward = 11
# Episode 4693: Total Reward = 7
# Episode 4694: Total Reward = 5
# Episode 4695: Total Reward = 10
# Episode 4696: Total Reward = 7
# Episode 4697: Total Reward = 7
# Episode 4698: Total Reward = -16
# Episode 4699: Total Reward = 7
# Episode 4700: Total Reward = 11
# Episode 4701: Total Reward = 7
# Episode 4702: Total Reward = 7
# Episode 4703: Total Reward = 6
# Episode 4704: Total Reward = 6
# Episode 4705: Total Reward = 7
# Episode 4706: Total Reward = 4
# Episode 4707: Total Reward = 9
# Episode 4708: Total Reward = 3
# Episode 4709: Total Reward = 8
# Episode 4710: Total Reward = 6
# Episode 4711: Total Reward = 6
# Episode 4712: Total Reward = 7
# Episode 4713: Total Reward = 10
# Episode 4714: Total Reward = 9
# Episode 4715: Total Reward = 11
# Episode 4716: Total Reward = 5
# Episode 4717: Total Reward = 5
# Episode 4718: Total Reward = 1
# Episode 4719: Total Reward = 8
# Episode 4720: Total Reward = 8
# Episode 4721: Total Reward = 11
# Episode 4722: Total Reward = 5
# Episode 4723: Total Reward = -118
# Episode 4724: Total Reward = 9
# Episode 4725: Total Reward = 8
# Episode 4726: Total Reward = 6
# Episode 4727: Total Reward = 6
# Episode 4728: Total Reward = 7
# Episode 4729: Total Reward = 5
# Episode 4730: Total Reward = 6
# Episode 4731: Total Reward = 14
# Episode 4732: Total Reward = -52
# Episode 4733: Total Reward = 9
# Episode 4734: Total Reward = 8
# Episode 4735: Total Reward = 12
# Episode 4736: Total Reward = 9
# Episode 4737: Total Reward = 13
# Episode 4738: Total Reward = 11
# Episode 4739: Total Reward = 5
# Episode 4740: Total Reward = 7
# Episode 4741: Total Reward = -27
# Episode 4742: Total Reward = 13
# Episode 4743: Total Reward = 9
# Episode 4744: Total Reward = 0
# Episode 4745: Total Reward = 7
# Episode 4746: Total Reward = 9
# Episode 4747: Total Reward = 7
# Episode 4748: Total Reward = 5
# Episode 4749: Total Reward = 8
# Episode 4750: Total Reward = 9
# Episode 4751: Total Reward = 6
# Episode 4752: Total Reward = 10
# Episode 4753: Total Reward = 11
# Episode 4754: Total Reward = 5
# Episode 4755: Total Reward = 10
# Episode 4756: Total Reward = 8
# Episode 4757: Total Reward = 8
# Episode 4758: Total Reward = 7
# Episode 4759: Total Reward = 9
# Episode 4760: Total Reward = 8
# Episode 4761: Total Reward = 5
# Episode 4762: Total Reward = 7
# Episode 4763: Total Reward = 10
# Episode 4764: Total Reward = 7
# Episode 4765: Total Reward = 7
# Episode 4766: Total Reward = 6
# Episode 4767: Total Reward = 10
# Episode 4768: Total Reward = 5
# Episode 4769: Total Reward = 7
# Episode 4770: Total Reward = 8
# Episode 4771: Total Reward = 8
# Episode 4772: Total Reward = 4
# Episode 4773: Total Reward = 12
# Episode 4774: Total Reward = -45
# Episode 4775: Total Reward = 6
# Episode 4776: Total Reward = 7
# Episode 4777: Total Reward = 5
# Episode 4778: Total Reward = 7
# Episode 4779: Total Reward = 8
# Episode 4780: Total Reward = 8
# Episode 4781: Total Reward = -2
# Episode 4782: Total Reward = 8
# Episode 4783: Total Reward = 6
# Episode 4784: Total Reward = 11
# Episode 4785: Total Reward = 4
# Episode 4786: Total Reward = 5
# Episode 4787: Total Reward = 5
# Episode 4788: Total Reward = 8
# Episode 4789: Total Reward = 4
# Episode 4790: Total Reward = 8
# Episode 4791: Total Reward = 6
# Episode 4792: Total Reward = 8
# Episode 4793: Total Reward = 6
# Episode 4794: Total Reward = 6
# Episode 4795: Total Reward = 4
# Episode 4796: Total Reward = -137
# Episode 4797: Total Reward = 11
# Episode 4798: Total Reward = 2
# Episode 4799: Total Reward = 4
# Episode 4800: Total Reward = 5
# Episode 4801: Total Reward = 7
# Episode 4802: Total Reward = -78
# Episode 4803: Total Reward = 9
# Episode 4804: Total Reward = 8
# Episode 4805: Total Reward = 4
# Episode 4806: Total Reward = 4
# Episode 4807: Total Reward = 4
# Episode 4808: Total Reward = 7
# Episode 4809: Total Reward = -89
# Episode 4810: Total Reward = 10
# Episode 4811: Total Reward = 6
# Episode 4812: Total Reward = -3
# Episode 4813: Total Reward = 6
# Episode 4814: Total Reward = -1
# Episode 4815: Total Reward = 5
# Episode 4816: Total Reward = 8
# Episode 4817: Total Reward = 15
# Episode 4818: Total Reward = 12
# Episode 4819: Total Reward = 9
# Episode 4820: Total Reward = 9
# Episode 4821: Total Reward = 10
# Episode 4822: Total Reward = 7
# Episode 4823: Total Reward = 4
# Episode 4824: Total Reward = 6
# Episode 4825: Total Reward = 11
# Episode 4826: Total Reward = 6
# Episode 4827: Total Reward = 11
# Episode 4828: Total Reward = 5
# Episode 4829: Total Reward = 10
# Episode 4830: Total Reward = 4
# Episode 4831: Total Reward = 14
# Episode 4832: Total Reward = 9
# Episode 4833: Total Reward = -6
# Episode 4834: Total Reward = 13
# Episode 4835: Total Reward = 12
# Episode 4836: Total Reward = 6
# Episode 4837: Total Reward = -1
# Episode 4838: Total Reward = 8
# Episode 4839: Total Reward = 8
# Episode 4840: Total Reward = 10
# Episode 4841: Total Reward = 7
# Episode 4842: Total Reward = -24
# Episode 4843: Total Reward = 7
# Episode 4844: Total Reward = 12
# Episode 4845: Total Reward = 9
# Episode 4846: Total Reward = 14
# Episode 4847: Total Reward = 5
# Episode 4848: Total Reward = 10
# Episode 4849: Total Reward = 11
# Episode 4850: Total Reward = 7
# Episode 4851: Total Reward = 6
# Episode 4852: Total Reward = 10
# Episode 4853: Total Reward = 4
# Episode 4854: Total Reward = 5
# Episode 4855: Total Reward = 5
# Episode 4856: Total Reward = 5
# Episode 4857: Total Reward = 5
# Episode 4858: Total Reward = 5
# Episode 4859: Total Reward = 5
# Episode 4860: Total Reward = 14
# Episode 4861: Total Reward = 6
# Episode 4862: Total Reward = 8
# Episode 4863: Total Reward = 10
# Episode 4864: Total Reward = 10
# Episode 4865: Total Reward = 7
# Episode 4866: Total Reward = 8
# Episode 4867: Total Reward = 11
# Episode 4868: Total Reward = 8
# Episode 4869: Total Reward = 7
# Episode 4870: Total Reward = 4
# Episode 4871: Total Reward = 7
# Episode 4872: Total Reward = 5
# Episode 4873: Total Reward = 10
# Episode 4874: Total Reward = -92
# Episode 4875: Total Reward = 8
# Episode 4876: Total Reward = 8
# Episode 4877: Total Reward = 6
# Episode 4878: Total Reward = 5
# Episode 4879: Total Reward = 8
# Episode 4880: Total Reward = 8
# Episode 4881: Total Reward = 10
# Episode 4882: Total Reward = 11
# Episode 4883: Total Reward = 3
# Episode 4884: Total Reward = 6
# Episode 4885: Total Reward = 5
# Episode 4886: Total Reward = 14
# Episode 4887: Total Reward = 10
# Episode 4888: Total Reward = 6
# Episode 4889: Total Reward = 6
# Episode 4890: Total Reward = 11
# Episode 4891: Total Reward = 12
# Episode 4892: Total Reward = 7
# Episode 4893: Total Reward = 7
# Episode 4894: Total Reward = 7
# Episode 4895: Total Reward = 7
# Episode 4896: Total Reward = 10
# Episode 4897: Total Reward = 5
# Episode 4898: Total Reward = 8
# Episode 4899: Total Reward = 10
# Episode 4900: Total Reward = 5
# Episode 4901: Total Reward = 9
# Episode 4902: Total Reward = 7
# Episode 4903: Total Reward = 10
# Episode 4904: Total Reward = 10
# Episode 4905: Total Reward = 6
# Episode 4906: Total Reward = 7
# Episode 4907: Total Reward = 8
# Episode 4908: Total Reward = 8
# Episode 4909: Total Reward = 11
# Episode 4910: Total Reward = 8
# Episode 4911: Total Reward = 6
# Episode 4912: Total Reward = 9
# Episode 4913: Total Reward = 8
# Episode 4914: Total Reward = 6
# Episode 4915: Total Reward = 7
# Episode 4916: Total Reward = 4
# Episode 4917: Total Reward = 6
# Episode 4918: Total Reward = 5
# Episode 4919: Total Reward = -1
# Episode 4920: Total Reward = 8
# Episode 4921: Total Reward = 10
# Episode 4922: Total Reward = 10
# Episode 4923: Total Reward = 8
# Episode 4924: Total Reward = 8
# Episode 4925: Total Reward = 9
# Episode 4926: Total Reward = 6
# Episode 4927: Total Reward = -3
# Episode 4928: Total Reward = 12
# Episode 4929: Total Reward = 10
# Episode 4930: Total Reward = 12
# Episode 4931: Total Reward = 3
# Episode 4932: Total Reward = 13
# Episode 4933: Total Reward = 8
# Episode 4934: Total Reward = 10
# Episode 4935: Total Reward = 6
# Episode 4936: Total Reward = 11
# Episode 4937: Total Reward = 5
# Episode 4938: Total Reward = 7
# Episode 4939: Total Reward = 9
# Episode 4940: Total Reward = 5
# Episode 4941: Total Reward = 8
# Episode 4942: Total Reward = 7
# Episode 4943: Total Reward = -41
# Episode 4944: Total Reward = 10
# Episode 4945: Total Reward = 8
# Episode 4946: Total Reward = 3
# Episode 4947: Total Reward = 5
# Episode 4948: Total Reward = 14
# Episode 4949: Total Reward = 14
# Episode 4950: Total Reward = 6
# Episode 4951: Total Reward = 8
# Episode 4952: Total Reward = 5
# Episode 4953: Total Reward = 10
# Episode 4954: Total Reward = 12
# Episode 4955: Total Reward = 9
# Episode 4956: Total Reward = 4
# Episode 4957: Total Reward = 10
# Episode 4958: Total Reward = -3
# Episode 4959: Total Reward = 10
# Episode 4960: Total Reward = 10
# Episode 4961: Total Reward = 9
# Episode 4962: Total Reward = 7
# Episode 4963: Total Reward = 13
# Episode 4964: Total Reward = 9
# Episode 4965: Total Reward = 12
# Episode 4966: Total Reward = 8
# Episode 4967: Total Reward = 7
# Episode 4968: Total Reward = 9
# Episode 4969: Total Reward = 11
# Episode 4970: Total Reward = 9
# Episode 4971: Total Reward = 5
# Episode 4972: Total Reward = 5
# Episode 4973: Total Reward = 13
# Episode 4974: Total Reward = 11
# Episode 4975: Total Reward = 5
# Episode 4976: Total Reward = 8
# Episode 4977: Total Reward = 8
# Episode 4978: Total Reward = 5
# Episode 4979: Total Reward = 10
# Episode 4980: Total Reward = 6
# Episode 4981: Total Reward = 8
# Episode 4982: Total Reward = 3
# Episode 4983: Total Reward = 8
# Episode 4984: Total Reward = 8
# Episode 4985: Total Reward = 3
# Episode 4986: Total Reward = 7
# Episode 4987: Total Reward = 5
# Episode 4988: Total Reward = 11
# Episode 4989: Total Reward = 3
# Episode 4990: Total Reward = 13
# Episode 4991: Total Reward = 8
# Episode 4992: Total Reward = 10
# Episode 4993: Total Reward = 5
# Episode 4994: Total Reward = 7
# Episode 4995: Total Reward = 8
# Episode 4996: Total Reward = 7
# Episode 4997: Total Reward = 6
# Episode 4998: Total Reward = -5
# Episode 4999: Total Reward = 11
# Episode 5000: Total Reward = 10

# %%
smdp.plot_Q()

# %% [markdown]
# INTRA OPTION

# %%
q_intra = np.zeros((500,10))

class INTRAOPT:
    def __init__(self):
        self.avg_reward = []
        self.total_reward = []

    def Qlearn(self):
        epsilon = 0.1
        for episode in range(5000):
            running = 0
            state, _ = env.reset()
            done = False
            ep_reward = 0
            steps = 0
            while not done :
                steps += 1
                action = choose_action(state,q_intra,epsilon)
                if action < 6:
                    next_state, reward, done, _, _ = env.step(action)
                    ep_reward+= reward
                    q_intra[state,action] += ALPHA * (reward + GAMMA * np.max(q_intra[next_state, :])- q_intra[state, action])
                    state = next_state
                
                if action > 5 :
                    count = 0
                    optdone = False
                    while (optdone == False) :
                        if action == 6:
                            optact, optdone = Red(q_r,state,epsilon) 
                            next_state, reward, done, _, _ = env.step(optact)
                            #q_r[state,optact] = q_r[state, optact] + ALPHA * (reward + GAMMA * np.max(q_r[next_state, :])- q_r[state, optact])
                        if action == 7:
                            optact, optdone = Green(q_g,state,epsilon)
                            next_state, reward, done, _, _ = env.step(optact)
                            #q_g[state,optact] = q_g[state, optact] + ALPHA * (reward + GAMMA * np.max(q_g[next_state, :])- q_g[state, optact])
                        if action == 8:
                            optact, optdone = Blue(q_b,state,epsilon)
                            next_state, reward, done, _, _ = env.step(optact)
                            #q_b[state,optact] = q_b[state, optact] + ALPHA * (reward + GAMMA * np.max(q_b[next_state, :])- q_b[state, optact])
                        if action == 9:
                            optact, optdone = Yellow(q_y,state,epsilon)
                            next_state, reward, done, _, _ = env.step(optact)
                            #q_y[state,optact] = q_y[state, optact] + ALPHA * (reward + GAMMA * np.max(q_y[next_state])- q_y[state, optact])
                        
                        ep_reward += reward
                        count += 1
                        q_intra[state,action] += ALPHA * (reward + GAMMA * np.max(q_intra[next_state, :])- q_intra[state, action])
                        state = next_state
                
            running = 0.35 * ep_reward + (1 - 0.35) * running
            self.avg_reward.append(running)
            self.q=q_intra
            self.total_reward.append(ep_reward)
            print(f"Episode {episode + 1}: Total Reward = {ep_reward}")
        return self.avg_reward, self.total_reward
    
    def plot(self):
        plt.plot(self.avg_reward,label="Moving Average")
        plt.grid()
        plt.plot(self.total_reward,label="Total Rewards",alpha=1, color='orange')
        plt.xlabel('Episode')
        plt.ylabel('Averaged Episodic Returns')
        plt.title("Averaged Episodic Returns")
        plt.legend()
        plt.savefig('SMDP.png')
        plt.show()

    def render_run(self):
        special_env = gym.make('Taxi-v3',render_mode='human')
        done = False
        eps = 0.01
        state, _ = special_env.reset()
        while not done:
            action = choose_action(state,self.q,eps)
            next_state, reward, done, _, _ = special_env.step(action)
            if done:
                break

# %%
agent2 = INTRAOPT()
agent2.Qlearn()
agent2.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[136], line 2
#       1 agent2 = INTRAOPT()
# ----> 2 agent2.Qlearn()
#       3 agent2.plot()
#
# Cell In[135], line 30, in INTRAOPT.Qlearn(self)
#      28 while (optdone == False) :
#      29     if action == 6:
# ---> 30         optact, optdone = Red(q_r,state,epsilon)
#      31         next_state, reward, done, _, _ = env.step(optact)
#      32         #q_r[state,optact] = q_r[state, optact] + ALPHA * (reward + GAMMA * np.max(q_r[next_state, :])- q_r[state, optact])
#
# Cell In[131], line 4, in Red(q_r, state, eps)
#       2 def Red(q_r,state,eps):
#       3     optdone = False
# ----> 4     optact = choose_action(state,q_r,eps)
#       5     state = get_state(state)
#       6     if state[0] == R[0] and state[1] == R[1]:
#
# Cell In[130], line 6, in choose_action(state, qs, eps)
#       4 if not qs[state].any():
#       5     return random.randint(0,length-1)
# ----> 6 action = np.argmax(qs[state])
#       8 if np.random.rand() < eps:
#       9     action = np.random.randint(0,length-1)
#
# File c:\Users\anike\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:1229, in argmax(a, axis, out, keepdims)
#    1142 """
#    1143 Returns the indices of the maximum values along an axis.
#    1144
#    (...)
#    1226 (2, 1, 4)
#    1227 """
#    1228 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1229 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File c:\Users\anike\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#      68     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:
