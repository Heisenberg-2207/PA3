# %%
import numpy as np
from tqdm import tqdm
import gym
import math
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
env = gym.make('Taxi-v3')
num_actions = env.action_space
num_obs = env.observation_space
R, G, B, Y = env.unwrapped.locs
R, G, B, Y = list(R), list(G), list(B), list(Y)
env.reset()
# Out:
# (247, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})

# %%
def get_state(state):
    row, col, pass_id, dest_id = env.unwrapped.decode(state)
    state = np.asarray([row,col,pass_id,dest_id])
    return state

#encoding a 5x5 matrix as a 25x1 vector
def encode(pose):
    [row,col] = pose
    state_num = row * 5 + col
    return state_num

def decode(state_num):
    row = state_num // 5
    col = state_num % 5
    return row, col

print(R,G,B,Y)
# Out:
# [0, 0] [0, 4] [4, 0] [4, 3]

# %%
curr_state = get_state(env.s)
print("Taxi at",curr_state)
next_state, reward, done, _, _ = env.step(4)
row, col, pass_id, dest_id = env.unwrapped.decode(next_state)
# Out:
# Taxi at [2 2 1 3]
# c:\Users\anike\AppData\Local\Programs\Python\Python312\Lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):

# %%
# Set the number of episodes and maximum number of steps per episode
EPS = 10000
MAX_STEPS = 500
EXP = 1
# Set the learning rate, discount factor, and exploration rate
ALPHA = 0.15
GAMMA = 0.99
exploration_rate = 1.0
MIN_EXP = 0.01
EXP_DECAY = 0.01

# %%
def choose_action(state,qs,eps):
    #print(np.shape(q))
    length = np.shape(qs)[1]
    if not qs[state].any():
        return random.randint(0,length-1)
    action = np.argmax(qs[state])
    
    if np.random.rand() < eps:
        action = np.random.randint(0,length-1)
        return action
    return action   

def choose_action_option(state,qs):
    action = np.argmax(qs[state])
    return action

# %%
# Options where policy is greedy wrt the corresponding q Value function
def Red(q_r,state,eps):
    optdone = False
    optact = choose_action(state,q_r,eps)
    state = decode(state)
    if state[0] == R[0] and state[1] == R[1]:
        optdone = True
    return optact,optdone

def Green(q_g,state,eps):
    optdone = False
    optact = choose_action(state,q_g,eps)
    state = decode(state)
    if state[0] == G[0] and state[1] == G[1]:
        optdone = True
    return optact,optdone
    
def Yellow(q_y,state,eps):
    optdone = False
    optact = choose_action(state,q_y,eps)
    state = decode(state)
    if state[0] == Y[0] and state[1] == Y[1]:
        optdone = True
    return optact,optdone 

def Blue(q_b,state,eps):
    optdone = False
    optact = choose_action(state,q_b,eps)
    state = decode(state)
    if state[0] == B[0] and state[1] == B[1]:
        optdone = True
    return optact,optdone

# %%
Q_opt = np.zeros((4,25,4))
q = np.zeros((500,10))
qf = np.zeros((500,10))
qof = np.zeros((4,25,4))

# %% [markdown]
# ### SMDP

# %%
class SMDP:
    def __init__(self):
        self.avg_reward = []
        self.total_reward = []

    def Qlearn(self):
        epsilon = 0.1
        for episode in range(10000):
            running = 0
            state, _ = env.reset()
            done = False
            ep_reward = 0
            steps = 0

            while not done :
                steps += 1
                action = choose_action(state,q,epsilon)
                if action < 6:
                    next_state, reward, done, _, _ = env.step(action)
                    ep_reward += reward
                    q[state,action] = q[state, action] + ALPHA * (reward + GAMMA * np.max(q[next_state, :])- q[state, action])
                    qf[state,action] += 1
                    state = next_state
                
                reward_bar = 0
                if action > 5 :
                    count = 0
                    optdone = False
                    current_state = state
                    state = encode(get_state(state)[0:2]) 

                    while (optdone == False) :
                        if action == 6:
                            optact, optdone = Red(Q_opt[0],state,epsilon) 
                            next_state, reward, done, _, _ = env.step(optact)
                            next = encode(get_state(next_state)[0:2])
                            Q_opt[0][state,optact] = Q_opt[0][state, optact] + ALPHA * (reward + GAMMA * np.max(Q_opt[0][next, :])- Q_opt[0][state, optact])
                            qof[0][state,optact] += 1

                        if action == 7:
                            optact, optdone = Green(Q_opt[1],state,epsilon)
                            next_state, reward, done, _, _ = env.step(optact)
                            next = encode(get_state(next_state)[0:2])
                            Q_opt[1][state,optact] = Q_opt[1][state, optact] + ALPHA * (reward + GAMMA * np.max(Q_opt[1][next, :])- Q_opt[1][state, optact])
                            qof[1][state,optact] += 1

                        if action == 8:
                            optact, optdone = Blue(Q_opt[2],state,epsilon)
                            next_state, reward, done, _, _ = env.step(optact)
                            next = encode(get_state(next_state)[0:2])
                            Q_opt[2][state,optact] = Q_opt[2][state, optact] + ALPHA * (reward + GAMMA * np.max(Q_opt[2][next, :])- Q_opt[2][state, optact])
                            qof[2][state,optact] += 1

                        if action == 9:

                            optact, optdone = Yellow(Q_opt[3],state,epsilon)
                            next_state, reward, done, _, _ = env.step(optact)
                            next = encode(get_state(next_state)[0:2])
                            Q_opt[3][state,optact] = Q_opt[3][state, optact] + ALPHA * (reward + GAMMA * np.max(Q_opt[3][next])- Q_opt[3][state, optact])
                            qof[3][state,optact] += 1

                        reward_bar =  reward_bar + (GAMMA**count)*reward
                        ep_reward += reward
                        count += 1
                        state = next
                        if optdone == True:
                            q[current_state, action] += ALPHA * (reward_bar - q[current_state, action] + (GAMMA**count) * np.max(q[next_state, :]))
                            state = env.s
                        
                if epsilon > 0.01:
                    epsilon = epsilon*np.exp(-0.01)
            running = 0.35 * ep_reward + (1 - 0.35) * running
            self.avg_reward.append(running)
            self.total_reward.append(ep_reward)
            print(f"Episode {episode + 1}: Total Reward = {running}")
        return self.avg_reward, self.total_reward
    
    def plot(self):
        plt.plot(self.avg_reward,label="Moving Average")
        plt.grid()
        plt.plot(self.total_reward,label="Total Rewards",alpha=1, color='orange')
        plt.xlabel('Episode')
        plt.ylabel('Averaged Episodic Returns')
        plt.title("Averaged Episodic Returns")
        plt.legend()
        plt.savefig('SMDP.png')
        plt.show()

    def render_run(self):
        special_env = gym.make('Taxi-v3',render_mode='human')
        done = False
        eps = 0.01
        state, _ = special_env.reset()
        while not done:
            action = choose_action(state,q,eps)
            next_state, reward, done, _, _ = special_env.step(action)
            if done:
                break

    def plot_Q(self):
        ACTIONS = {0: "South",1: "Up",2: "East",3: "West",4: "Pick",5: "Drop",6: "R",7: "G",8: "B", 9: "Y"}
        # decode each state 
        # ((taxi_row * 5 + taxi_col) * 5 + passenger_location) * 4 + destination
        action = np.argmax(q,axis=1)
        action_f = np.argmax(qf,axis=1)

        dest_r = action[::4]
        dest_g = action[1::4]
        dest_b = action[2::4]
        dest_y = action[3::4]

        dest_r_f = action_f[::4]
        dest_g_f = action_f[1::4]
        dest_b_f = action_f[2::4]
        dest_y_f = action_f[3::4]

        loc_r_r = dest_r[::5]
        loc_r_g = dest_g[::5]
        loc_r_b = dest_b[::5]
        loc_r_y = dest_y[::5]

        loc_r_r_f = dest_r_f[::5]
        loc_r_g_f = dest_g_f[::5]
        loc_r_b_f = dest_b_f[::5]
        loc_r_y_f = dest_y_f[::5]

        loc_g_r = dest_r[1::5]
        loc_g_g = dest_g[1::5]
        loc_g_b = dest_b[1::5]
        loc_g_y = dest_y[1::5]

        loc_g_r_f = dest_r_f[1::5]
        loc_g_g_f = dest_g_f[1::5]
        loc_g_b_f = dest_b_f[1::5]
        loc_g_y_f = dest_y_f[1::5]

        loc_b_r = dest_r[2::5]
        loc_b_g = dest_g[2::5]
        loc_b_b = dest_b[2::5]
        loc_b_y = dest_y[2::5]

        loc_b_r_f = dest_r_f[2::5]
        loc_b_g_f = dest_g_f[2::5]
        loc_b_b_f = dest_b_f[2::5]
        loc_b_y_f = dest_y_f[2::5]

        loc_y_r = dest_r[3::5]
        loc_y_g = dest_g[3::5]
        loc_y_b = dest_b[3::5]
        loc_y_y = dest_y[3::5]

        loc_y_r_f = dest_r_f[3::5]
        loc_y_g_f = dest_g_f[3::5]
        loc_y_b_f = dest_b_f[3::5]
        loc_y_y_f = dest_y_f[3::5]

        action_o = np.argmax(Q_opt,axis=2)
        action_o_f = np.argmax(qof,axis=2)

        dest_r = action_o[0]
        dest_g = action_o[1]
        dest_b = action_o[2]
        dest_y = action_o[3]

        freq_r = action_o_f[0]
        freq_g = action_o_f[1]
        freq_b = action_o_f[2]
        freq_y = action_o_f[3]

        # Create a 5x5 grid for grid and frequncy
        grid = np.reshape(loc_r_g, (5, 5))
        freq = np.reshape(loc_r_g_f, (5, 5))

        # Create a 5x5 grid for grid and frequncy
        grid_dest = np.reshape(dest_g, (5, 5))
        freq_dest = np.reshape(freq_g, (5, 5))

        fig, axs = plt.subplots(1, 2, figsize=(10, 5))
        
        # Display the grid with numbers for loc_r_g
        cax = axs[0].imshow(freq, cmap='viridis', interpolation='nearest')
        fig.colorbar(cax, ax=axs[0])
        for i in range(5):
            for j in range(5):
                text = ACTIONS[grid[i, j]]
                axs[0].text(j, i, text, ha='center', va='center', color='black')

        # Add labels and title for loc_r_g
        axs[0].set_title("Red passenger (dest Green) Policy")
        axs[0].set_xlabel('Column')
        axs[0].set_ylabel('Row')

        # Display the grid with numbers for dest_r
        cax = axs[1].imshow(freq_dest, cmap='viridis', interpolation='nearest')
        fig.colorbar(cax, ax=axs[1])
        for i in range(5):
            for j in range(5):
                text = ACTIONS[grid_dest[i, j]]
                axs[1].text(j, i, text, ha='center', va='center', color='black')

        # Add labels and title for dest_r
        axs[1].set_title("Red Option Policy")
        axs[1].set_xlabel('Column')
        axs[1].set_ylabel('Row')

        plt.tight_layout()
        plt.show()

# %% [markdown]
# Working

# %%
smdp = SMDP()
smdp.Qlearn()
smdp.plot()
# Out:
# Episode 1: Total Reward = -1508.85
# Episode 2: Total Reward = -801.15
# Episode 3: Total Reward = -1365.35
# Episode 4: Total Reward = -562.8
# Episode 5: Total Reward = -221.89999999999998
# Episode 6: Total Reward = -116.19999999999999
# Episode 7: Total Reward = -295.4
# Episode 8: Total Reward = -756.0
# Episode 9: Total Reward = -250.95
# Episode 10: Total Reward = -512.4
# Episode 11: Total Reward = -714.0
# Episode 12: Total Reward = -712.9499999999999
# Episode 13: Total Reward = -499.79999999999995
# Episode 14: Total Reward = -643.65
# Episode 15: Total Reward = -248.85
# Episode 16: Total Reward = -549.5
# Episode 17: Total Reward = -1021.3
# Episode 18: Total Reward = -607.25
# Episode 19: Total Reward = -991.55
# Episode 20: Total Reward = -306.95
# Episode 21: Total Reward = -270.54999999999995
# Episode 22: Total Reward = -317.09999999999997
# Episode 23: Total Reward = -345.45
# Episode 24: Total Reward = -664.65
# Episode 25: Total Reward = -90.3
# Episode 26: Total Reward = -429.45
# Episode 27: Total Reward = -2007.9499999999998
# Episode 28: Total Reward = -609.6999999999999
# Episode 29: Total Reward = -1031.8
# Episode 30: Total Reward = -196.35
# Episode 31: Total Reward = -893.1999999999999
# Episode 32: Total Reward = -842.4499999999999
# Episode 33: Total Reward = -224.7
# Episode 34: Total Reward = -140.0
# Episode 35: Total Reward = -712.9499999999999
# Episode 36: Total Reward = -702.0999999999999
# Episode 37: Total Reward = -486.15
# Episode 38: Total Reward = -848.4
# Episode 39: Total Reward = -592.1999999999999
# Episode 40: Total Reward = -876.4
# Episode 41: Total Reward = -598.5
# Episode 42: Total Reward = -362.25
# Episode 43: Total Reward = -958.3
# Episode 44: Total Reward = -558.9499999999999
# Episode 45: Total Reward = -482.65
# Episode 46: Total Reward = -110.6
# Episode 47: Total Reward = -864.15
# Episode 48: Total Reward = -586.9499999999999
# Episode 49: Total Reward = -208.25
# Episode 50: Total Reward = -264.59999999999997
# Episode 51: Total Reward = -233.1
# Episode 52: Total Reward = -413.0
# Episode 53: Total Reward = -285.95
# Episode 54: Total Reward = -80.85
# Episode 55: Total Reward = -241.85
# Episode 56: Total Reward = -140.35
# Episode 57: Total Reward = -186.89999999999998
# Episode 58: Total Reward = -153.29999999999998
# Episode 59: Total Reward = -234.85
# Episode 60: Total Reward = -207.2
# Episode 61: Total Reward = -236.6
# Episode 62: Total Reward = -159.95
# Episode 63: Total Reward = -213.14999999999998
# Episode 64: Total Reward = -400.4
# Episode 65: Total Reward = -305.54999999999995
# Episode 66: Total Reward = -108.85
# Episode 67: Total Reward = -236.95
# Episode 68: Total Reward = -520.8
# Episode 69: Total Reward = -374.5
# Episode 70: Total Reward = -305.9
# Episode 223: Total Reward = -57.74999999999999
# Episode 224: Total Reward = 4.199999999999999
# Episode 225: Total Reward = -1.75
# Episode 226: Total Reward = -47.25
# Episode 227: Total Reward = -64.75
# Episode 228: Total Reward = -67.55
# Episode 229: Total Reward = -69.64999999999999
# Episode 230: Total Reward = 5.25
# Episode 231: Total Reward = -53.9
# Episode 232: Total Reward = -57.74999999999999
# Episode 233: Total Reward = -46.9
# Episode 234: Total Reward = -64.39999999999999
# Episode 235: Total Reward = -80.14999999999999
# Episode 236: Total Reward = -131.25
# Episode 237: Total Reward = -17.15
# Episode 238: Total Reward = -43.75
# Episode 239: Total Reward = -29.4
# Episode 240: Total Reward = -190.04999999999998
# Episode 241: Total Reward = -26.25
# Episode 242: Total Reward = -69.64999999999999
# Episode 243: Total Reward = -89.94999999999999
# Episode 244: Total Reward = -20.65
# Episode 245: Total Reward = -9.799999999999999
# Episode 246: Total Reward = -87.14999999999999
# Episode 247: Total Reward = -263.55
# Episode 248: Total Reward = -41.3
# Episode 249: Total Reward = -14.0
# Episode 250: Total Reward = -0.35
# Episode 251: Total Reward = 0.35
# Episode 252: Total Reward = -48.65
# Episode 253: Total Reward = -2.4499999999999997
# Episode 254: Total Reward = 5.25
# Episode 255: Total Reward = -12.6
# Episode 256: Total Reward = -29.4
# Episode 257: Total Reward = -140.0
# Episode 258: Total Reward = -37.8
# Episode 259: Total Reward = -29.4
# Episode 260: Total Reward = -25.9
# Episode 261: Total Reward = -185.85
# Episode 262: Total Reward = 4.8999999999999995
# Episode 263: Total Reward = -15.399999999999999
# Episode 264: Total Reward = -82.94999999999999
# Episode 265: Total Reward = -164.5
# Episode 266: Total Reward = -58.099999999999994
# Episode 267: Total Reward = -32.55
# Episode 268: Total Reward = 3.8499999999999996
# Episode 269: Total Reward = -43.75
# Episode 270: Total Reward = 3.5
# Episode 271: Total Reward = -0.35
# Episode 272: Total Reward = -33.949999999999996
# Episode 273: Total Reward = -68.25
# Episode 274: Total Reward = -66.14999999999999
# Episode 275: Total Reward = -28.0
# Episode 276: Total Reward = -54.599999999999994
# Episode 277: Total Reward = -70.0
# Episode 278: Total Reward = -5.6
# Episode 279: Total Reward = -15.049999999999999
# Episode 280: Total Reward = -123.55
# Episode 281: Total Reward = -5.6
# Episode 282: Total Reward = -0.35
# Episode 283: Total Reward = -1.4
# Episode 284: Total Reward = -77.0
# Episode 285: Total Reward = -39.199999999999996
# Episode 286: Total Reward = 4.199999999999999
# Episode 287: Total Reward = -42.0
# Episode 288: Total Reward = -22.049999999999997
# Episode 289: Total Reward = -77.35
# Episode 290: Total Reward = -4.8999999999999995
# Episode 291: Total Reward = -72.44999999999999
# Episode 292: Total Reward = -199.14999999999998
# Episode 293: Total Reward = -131.95
# Episode 294: Total Reward = -47.25
# Episode 295: Total Reward = -39.199999999999996
# Episode 296: Total Reward = -21.349999999999998
# Episode 297: Total Reward = -44.449999999999996
# Episode 298: Total Reward = -9.1
# Episode 299: Total Reward = -22.049999999999997
# Episode 376: Total Reward = -63.699999999999996
# Episode 377: Total Reward = 3.5
# Episode 378: Total Reward = -0.7
# Episode 379: Total Reward = 5.25
# Episode 380: Total Reward = -79.44999999999999
# Episode 381: Total Reward = -71.39999999999999
# Episode 382: Total Reward = -30.099999999999998
# Episode 383: Total Reward = -15.749999999999998
# Episode 384: Total Reward = 3.15
# Episode 385: Total Reward = -24.5
# Episode 386: Total Reward = 3.8499999999999996
# Episode 387: Total Reward = 4.199999999999999
# Episode 388: Total Reward = 2.4499999999999997
# Episode 389: Total Reward = 4.55
# Episode 390: Total Reward = -21.349999999999998
# Episode 391: Total Reward = 2.0999999999999996
# Episode 392: Total Reward = 1.75
# Episode 393: Total Reward = -43.05
# Episode 394: Total Reward = 3.5
# Episode 395: Total Reward = -49.349999999999994
# Episode 396: Total Reward = -57.74999999999999
# Episode 397: Total Reward = -68.6
# Episode 398: Total Reward = 2.8
# Episode 399: Total Reward = -14.35
# Episode 400: Total Reward = 0.35
# Episode 401: Total Reward = 4.8999999999999995
# Episode 402: Total Reward = -2.4499999999999997
# Episode 403: Total Reward = -139.29999999999998
# Episode 404: Total Reward = 3.8499999999999996
# Episode 405: Total Reward = -29.749999999999996
# Episode 406: Total Reward = 1.4
# Episode 407: Total Reward = 3.8499999999999996
# Episode 408: Total Reward = 0.0
# Episode 409: Total Reward = -115.85
# Episode 410: Total Reward = -57.05
# Episode 411: Total Reward = -57.74999999999999
# Episode 412: Total Reward = -43.75
# Episode 413: Total Reward = 4.8999999999999995
# Episode 414: Total Reward = -58.8
# Episode 415: Total Reward = 3.8499999999999996
# Episode 416: Total Reward = -10.5
# Episode 417: Total Reward = -15.749999999999998
# Episode 418: Total Reward = 3.5
# Episode 419: Total Reward = -32.9
# Episode 420: Total Reward = 4.8999999999999995
# Episode 421: Total Reward = 0.7
# Episode 422: Total Reward = -80.5
# Episode 423: Total Reward = -22.049999999999997
# Episode 424: Total Reward = -17.849999999999998
# Episode 425: Total Reward = -42.0
# Episode 426: Total Reward = -17.15
# Episode 427: Total Reward = 3.8499999999999996
# Episode 428: Total Reward = -32.55
# Episode 429: Total Reward = 5.25
# Episode 430: Total Reward = -16.799999999999997
# Episode 431: Total Reward = 0.7
# Episode 432: Total Reward = -84.0
# Episode 433: Total Reward = -17.15
# Episode 434: Total Reward = -41.65
# Episode 435: Total Reward = -59.49999999999999
# Episode 436: Total Reward = -4.8999999999999995
# Episode 437: Total Reward = -46.199999999999996
# Episode 438: Total Reward = -28.349999999999998
# Episode 439: Total Reward = -51.099999999999994
# Episode 440: Total Reward = -75.25
# Episode 441: Total Reward = -61.24999999999999
# Episode 442: Total Reward = -20.299999999999997
# Episode 443: Total Reward = -39.199999999999996
# Episode 444: Total Reward = -27.299999999999997
# Episode 445: Total Reward = 0.7
# Episode 446: Total Reward = -17.5
# Episode 447: Total Reward = -57.4
# Episode 448: Total Reward = -112.69999999999999
# Episode 449: Total Reward = -22.75
# Episode 450: Total Reward = -15.399999999999999
# Episode 527: Total Reward = 3.15
# Episode 528: Total Reward = -4.199999999999999
# Episode 529: Total Reward = -5.6
# Episode 530: Total Reward = -48.65
# Episode 531: Total Reward = 2.4499999999999997
# Episode 532: Total Reward = -19.25
# Episode 533: Total Reward = -52.5
# Episode 534: Total Reward = -0.35
# Episode 535: Total Reward = 3.15
# Episode 536: Total Reward = -47.25
# Episode 537: Total Reward = -3.15
# Episode 538: Total Reward = -45.849999999999994
# Episode 539: Total Reward = 2.8
# Episode 540: Total Reward = -0.7
# Episode 541: Total Reward = 0.7
# Episode 542: Total Reward = -9.45
# Episode 543: Total Reward = 3.15
# Episode 544: Total Reward = 4.199999999999999
# Episode 545: Total Reward = -19.25
# Episode 546: Total Reward = 2.0999999999999996
# Episode 547: Total Reward = 3.15
# Episode 548: Total Reward = -4.55
# Episode 549: Total Reward = -40.25
# Episode 550: Total Reward = 0.7
# Episode 551: Total Reward = -11.549999999999999
# Episode 552: Total Reward = -13.299999999999999
# Episode 553: Total Reward = -33.599999999999994
# Episode 554: Total Reward = 3.5
# Episode 555: Total Reward = 3.8499999999999996
# Episode 556: Total Reward = 3.5
# Episode 557: Total Reward = 2.0999999999999996
# Episode 558: Total Reward = 3.15
# Episode 559: Total Reward = 0.0
# Episode 560: Total Reward = -42.0
# Episode 561: Total Reward = 4.8999999999999995
# Episode 562: Total Reward = 3.8499999999999996
# Episode 563: Total Reward = -25.9
# Episode 564: Total Reward = -4.55
# Episode 565: Total Reward = -6.3
# Episode 566: Total Reward = -2.4499999999999997
# Episode 567: Total Reward = -36.05
# Episode 568: Total Reward = -14.0
# Episode 569: Total Reward = 3.15
# Episode 570: Total Reward = -0.35
# Episode 571: Total Reward = 4.8999999999999995
# Episode 572: Total Reward = -58.449999999999996
# Episode 573: Total Reward = 3.5
# Episode 574: Total Reward = -48.3
# Episode 575: Total Reward = -50.05
# Episode 576: Total Reward = -49.349999999999994
# Episode 577: Total Reward = -21.7
# Episode 578: Total Reward = -10.5
# Episode 579: Total Reward = -10.5
# Episode 580: Total Reward = -41.3
# Episode 581: Total Reward = -14.0
# Episode 582: Total Reward = 1.4
# Episode 583: Total Reward = 3.15
# Episode 584: Total Reward = 3.5
# Episode 585: Total Reward = -42.699999999999996
# Episode 586: Total Reward = 2.8
# Episode 587: Total Reward = 2.4499999999999997
# Episode 588: Total Reward = -40.599999999999994
# Episode 589: Total Reward = 1.75
# Episode 590: Total Reward = -4.8999999999999995
# Episode 591: Total Reward = -9.799999999999999
# Episode 592: Total Reward = 3.15
# Episode 593: Total Reward = -7.0
# Episode 594: Total Reward = 4.199999999999999
# Episode 595: Total Reward = -6.3
# Episode 596: Total Reward = 4.55
# Episode 597: Total Reward = -0.35
# Episode 598: Total Reward = -19.95
# Episode 599: Total Reward = 3.15
# Episode 600: Total Reward = -75.25
# Episode 601: Total Reward = 3.15
# Episode 602: Total Reward = -1.75
# Episode 603: Total Reward = 3.15
# Episode 604: Total Reward = -2.8
# Episode 605: Total Reward = 3.15
# Episode 606: Total Reward = 3.5
# Episode 607: Total Reward = -11.2
# Episode 608: Total Reward = -0.7
# Episode 609: Total Reward = -16.099999999999998
# Episode 610: Total Reward = 3.8499999999999996
# Episode 611: Total Reward = -7.0
# Episode 612: Total Reward = 3.5
# Episode 613: Total Reward = -35.0
# Episode 614: Total Reward = -63.699999999999996
# Episode 615: Total Reward = -13.649999999999999
# Episode 616: Total Reward = -27.65
# Episode 617: Total Reward = -13.649999999999999
# Episode 618: Total Reward = -4.8999999999999995
# Episode 619: Total Reward = -45.849999999999994
# Episode 620: Total Reward = -41.3
# Episode 621: Total Reward = -16.099999999999998
# Episode 622: Total Reward = 1.4
# Episode 623: Total Reward = 1.4
# Episode 624: Total Reward = -43.05
# Episode 625: Total Reward = 2.8
# Episode 626: Total Reward = -36.75
# Episode 627: Total Reward = 4.199999999999999
# Episode 628: Total Reward = 0.35
# Episode 629: Total Reward = 4.199999999999999
# Episode 630: Total Reward = -13.299999999999999
# Episode 631: Total Reward = -2.0999999999999996
# Episode 632: Total Reward = 3.5
# Episode 633: Total Reward = 1.0499999999999998
# Episode 634: Total Reward = 1.75
# Episode 635: Total Reward = -32.55
# Episode 636: Total Reward = 1.0499999999999998
# Episode 637: Total Reward = 2.8
# Episode 638: Total Reward = 0.0
# Episode 639: Total Reward = 4.8999999999999995
# Episode 640: Total Reward = 3.5
# Episode 641: Total Reward = 2.0999999999999996
# Episode 642: Total Reward = 0.7
# Episode 643: Total Reward = -57.05
# Episode 644: Total Reward = 1.75
# Episode 645: Total Reward = 4.199999999999999
# Episode 646: Total Reward = -17.849999999999998
# Episode 647: Total Reward = 2.8
# Episode 648: Total Reward = -4.8999999999999995
# Episode 649: Total Reward = -4.55
# Episode 650: Total Reward = -16.799999999999997
# Episode 651: Total Reward = -16.799999999999997
# Episode 652: Total Reward = 4.55
# Episode 653: Total Reward = 1.0499999999999998
# Episode 654: Total Reward = -58.099999999999994
# Episode 655: Total Reward = 3.15
# Episode 656: Total Reward = 2.4499999999999997
# Episode 657: Total Reward = -1.75
# Episode 658: Total Reward = -42.699999999999996
# Episode 659: Total Reward = 1.4
# Episode 660: Total Reward = 0.0
# Episode 661: Total Reward = 3.15
# Episode 662: Total Reward = 3.15
# Episode 663: Total Reward = 2.4499999999999997
# Episode 664: Total Reward = 2.0999999999999996
# Episode 665: Total Reward = 2.4499999999999997
# Episode 666: Total Reward = 4.199999999999999
# Episode 667: Total Reward = 3.5
# Episode 668: Total Reward = 3.5
# Episode 669: Total Reward = 3.8499999999999996
# Episode 670: Total Reward = 3.15
# Episode 671: Total Reward = 3.8499999999999996
# Episode 672: Total Reward = -19.25
# Episode 673: Total Reward = 3.8499999999999996
# Episode 674: Total Reward = 2.8
# Episode 675: Total Reward = 2.8
# Episode 676: Total Reward = -38.15
# Episode 677: Total Reward = 0.7
# Episode 678: Total Reward = 1.0499999999999998
# Episode 679: Total Reward = 2.8
# Episode 680: Total Reward = 2.8
# Episode 681: Total Reward = -43.4
# Episode 682: Total Reward = -4.8999999999999995
# Episode 683: Total Reward = 3.8499999999999996
# Episode 684: Total Reward = 3.5
# Episode 685: Total Reward = 1.0499999999999998
# Episode 686: Total Reward = 1.75
# Episode 687: Total Reward = -4.8999999999999995
# Episode 688: Total Reward = 3.8499999999999996
# Episode 689: Total Reward = 2.4499999999999997
# Episode 690: Total Reward = 3.15
# Episode 691: Total Reward = 4.8999999999999995
# Episode 692: Total Reward = 3.5
# Episode 693: Total Reward = 1.4
# Episode 694: Total Reward = -18.549999999999997
# Episode 695: Total Reward = -3.15
# Episode 696: Total Reward = -0.7
# Episode 697: Total Reward = 3.15
# Episode 698: Total Reward = 3.15
# Episode 699: Total Reward = 3.15
# Episode 700: Total Reward = 3.8499999999999996
# Episode 701: Total Reward = 2.0999999999999996
# Episode 702: Total Reward = 2.4499999999999997
# Episode 703: Total Reward = -3.15
# Episode 704: Total Reward = 5.25
# Episode 705: Total Reward = 2.0999999999999996
# Episode 706: Total Reward = 3.5
# Episode 707: Total Reward = 3.5
# Episode 708: Total Reward = 3.5
# Episode 709: Total Reward = 3.15
# Episode 710: Total Reward = -38.5
# Episode 711: Total Reward = 2.4499999999999997
# Episode 712: Total Reward = 2.8
# Episode 713: Total Reward = 3.8499999999999996
# Episode 714: Total Reward = -4.199999999999999
# Episode 715: Total Reward = 0.35
# Episode 716: Total Reward = 4.199999999999999
# Episode 717: Total Reward = 3.5
# Episode 718: Total Reward = 3.5
# Episode 719: Total Reward = -56.699999999999996
# Episode 720: Total Reward = 4.8999999999999995
# Episode 721: Total Reward = 2.8
# Episode 722: Total Reward = 3.5
# Episode 723: Total Reward = 3.15
# Episode 724: Total Reward = 1.75
# Episode 725: Total Reward = 4.199999999999999
# Episode 726: Total Reward = 3.5
# Episode 727: Total Reward = 3.15
# Episode 728: Total Reward = 0.0
# Episode 729: Total Reward = 4.8999999999999995
# Episode 730: Total Reward = 3.5
# Episode 731: Total Reward = 0.35
# Episode 732: Total Reward = -9.1
# Episode 733: Total Reward = 3.15
# Episode 734: Total Reward = 0.35
# Episode 735: Total Reward = 4.199999999999999
# Episode 736: Total Reward = 0.0
# Episode 737: Total Reward = 3.8499999999999996
# Episode 738: Total Reward = 4.199999999999999
# Episode 739: Total Reward = -25.2
# Episode 740: Total Reward = 1.0499999999999998
# Episode 741: Total Reward = -10.149999999999999
# Episode 742: Total Reward = 2.8
# Episode 743: Total Reward = 3.8499999999999996
# Episode 744: Total Reward = -1.75
# Episode 745: Total Reward = -1.0499999999999998
# Episode 746: Total Reward = 2.4499999999999997
# Episode 747: Total Reward = 3.5
# Episode 748: Total Reward = 2.4499999999999997
# Episode 749: Total Reward = -24.849999999999998
# Episode 750: Total Reward = 1.4
# Episode 751: Total Reward = 3.5
# Episode 752: Total Reward = 3.15
# Episode 753: Total Reward = 3.5
# Episode 754: Total Reward = 2.8
# Episode 755: Total Reward = 1.4
# Episode 756: Total Reward = 4.199999999999999
# Episode 757: Total Reward = 3.5
# Episode 758: Total Reward = 3.15
# Episode 759: Total Reward = 2.0999999999999996
# Episode 760: Total Reward = 3.15
# Episode 761: Total Reward = -3.15
# Episode 762: Total Reward = 4.8999999999999995
# Episode 763: Total Reward = 3.5
# Episode 764: Total Reward = 4.55
# Episode 765: Total Reward = -37.449999999999996
# Episode 766: Total Reward = 2.8
# Episode 767: Total Reward = -6.3
# Episode 768: Total Reward = 0.7
# Episode 769: Total Reward = 1.4
# Episode 770: Total Reward = 3.15
# Episode 771: Total Reward = -42.699999999999996
# Episode 772: Total Reward = 3.15
# Episode 773: Total Reward = 3.8499999999999996
# Episode 774: Total Reward = -1.4
# Episode 775: Total Reward = -1.0499999999999998
# Episode 776: Total Reward = 3.8499999999999996
# Episode 777: Total Reward = 3.8499999999999996
# Episode 778: Total Reward = 3.8499999999999996
# Episode 779: Total Reward = 4.199999999999999
# Episode 780: Total Reward = -7.0
# Episode 781: Total Reward = 3.5
# Episode 782: Total Reward = -48.65
# Episode 783: Total Reward = -19.25
# Episode 784: Total Reward = 3.5
# Episode 785: Total Reward = 3.15
# Episode 786: Total Reward = 2.8
# Episode 787: Total Reward = -43.4
# Episode 788: Total Reward = -1.75
# Episode 789: Total Reward = 2.0999999999999996
# Episode 790: Total Reward = 0.0
# Episode 791: Total Reward = 2.8
# Episode 792: Total Reward = 1.75
# Episode 793: Total Reward = 3.8499999999999996
# Episode 794: Total Reward = 3.8499999999999996
# Episode 795: Total Reward = -5.25
# Episode 796: Total Reward = 3.15
# Episode 797: Total Reward = 3.5
# Episode 798: Total Reward = -2.0999999999999996
# Episode 799: Total Reward = 2.4499999999999997
# Episode 800: Total Reward = 3.8499999999999996
# Episode 801: Total Reward = 2.4499999999999997
# Episode 802: Total Reward = -2.4499999999999997
# Episode 803: Total Reward = 2.0999999999999996
# Episode 804: Total Reward = 0.7
# Episode 805: Total Reward = 3.5
# Episode 806: Total Reward = 4.55
# Episode 807: Total Reward = -2.8
# Episode 808: Total Reward = 4.55
# Episode 809: Total Reward = 2.8
# Episode 810: Total Reward = 3.5
# Episode 811: Total Reward = -14.35
# Episode 812: Total Reward = -9.45
# Episode 813: Total Reward = 2.8
# Episode 814: Total Reward = -3.8499999999999996
# Episode 815: Total Reward = 3.15
# Episode 816: Total Reward = 4.55
# Episode 817: Total Reward = 4.8999999999999995
# Episode 818: Total Reward = 3.8499999999999996
# Episode 819: Total Reward = 0.35
# Episode 820: Total Reward = 3.8499999999999996
# Episode 821: Total Reward = 2.8
# Episode 822: Total Reward = 2.0999999999999996
# Episode 823: Total Reward = 3.5
# Episode 824: Total Reward = 3.15
# Episode 825: Total Reward = 2.8
# Episode 826: Total Reward = 2.8
# Episode 827: Total Reward = -21.7
# Episode 828: Total Reward = 3.5
# Episode 829: Total Reward = -10.85
# Episode 830: Total Reward = 3.8499999999999996
# Episode 831: Total Reward = 2.8
# Episode 832: Total Reward = 4.199999999999999
# Episode 833: Total Reward = 3.8499999999999996
# Episode 834: Total Reward = 3.15
# Episode 835: Total Reward = 2.8
# Episode 836: Total Reward = 3.5
# Episode 837: Total Reward = 3.5
# Episode 838: Total Reward = -55.65
# Episode 839: Total Reward = 3.5
# Episode 840: Total Reward = -3.15
# Episode 841: Total Reward = 3.15
# Episode 842: Total Reward = -9.45
# Episode 843: Total Reward = 2.0999999999999996
# Episode 844: Total Reward = 4.55
# Episode 845: Total Reward = 3.5
# Episode 846: Total Reward = 2.4499999999999997
# Episode 847: Total Reward = 3.5
# Episode 848: Total Reward = -45.849999999999994
# Episode 849: Total Reward = 3.15
# Episode 850: Total Reward = -0.7
# Episode 851: Total Reward = -1.4
# Episode 852: Total Reward = -33.949999999999996
# Episode 853: Total Reward = 3.5
# Episode 854: Total Reward = 2.4499999999999997
# Episode 855: Total Reward = -7.0
# Episode 856: Total Reward = 3.5
# Episode 857: Total Reward = 1.0499999999999998
# Episode 858: Total Reward = 1.75
# Episode 859: Total Reward = 3.5
# Episode 860: Total Reward = 4.199999999999999
# Episode 861: Total Reward = -7.35
# Episode 862: Total Reward = -7.0
# Episode 863: Total Reward = -29.4
# Episode 864: Total Reward = 2.4499999999999997
# Episode 865: Total Reward = 4.8999999999999995
# Episode 866: Total Reward = 4.199999999999999
# Episode 867: Total Reward = 2.4499999999999997
# Episode 868: Total Reward = -0.7
# Episode 869: Total Reward = -38.15
# Episode 870: Total Reward = -23.099999999999998
# Episode 871: Total Reward = -0.35
# Episode 872: Total Reward = -25.2
# Episode 873: Total Reward = 3.8499999999999996
# Episode 874: Total Reward = 3.15
# Episode 875: Total Reward = 3.15
# Episode 876: Total Reward = 3.5
# Episode 877: Total Reward = 3.5
# Episode 878: Total Reward = 1.0499999999999998
# Episode 879: Total Reward = -5.949999999999999
# Episode 880: Total Reward = 3.15
# Episode 881: Total Reward = 0.35
# Episode 882: Total Reward = 3.15
# Episode 883: Total Reward = 4.199999999999999
# Episode 884: Total Reward = 2.8
# Episode 885: Total Reward = -19.599999999999998
# Episode 886: Total Reward = 0.7
# Episode 887: Total Reward = 3.15
# Episode 888: Total Reward = 2.4499999999999997
# Episode 889: Total Reward = 3.5
# Episode 890: Total Reward = 2.4499999999999997
# Episode 891: Total Reward = 2.8
# Episode 892: Total Reward = 3.5
# Episode 893: Total Reward = 3.8499999999999996
# Episode 894: Total Reward = 1.75
# Episode 895: Total Reward = 3.15
# Episode 896: Total Reward = 0.35
# Episode 897: Total Reward = 1.4
# Episode 898: Total Reward = 2.4499999999999997
# Episode 899: Total Reward = 3.5
# Episode 900: Total Reward = 3.15
# Episode 901: Total Reward = 3.5
# Episode 902: Total Reward = 3.5
# Episode 903: Total Reward = -14.7
# Episode 904: Total Reward = 2.4499999999999997
# Episode 905: Total Reward = 2.4499999999999997
# Episode 906: Total Reward = -1.75
# Episode 907: Total Reward = 3.5
# Episode 908: Total Reward = 1.75
# Episode 909: Total Reward = 3.15
# Episode 910: Total Reward = 3.8499999999999996
# Episode 911: Total Reward = 2.8
# Episode 912: Total Reward = -1.0499999999999998
# Episode 913: Total Reward = 3.15
# Episode 914: Total Reward = -0.35
# Episode 915: Total Reward = -38.15
# Episode 916: Total Reward = 3.5
# Episode 917: Total Reward = 1.0499999999999998
# Episode 918: Total Reward = 0.0
# Episode 919: Total Reward = 2.8
# Episode 920: Total Reward = 2.8
# Episode 921: Total Reward = 3.5
# Episode 922: Total Reward = 2.8
# Episode 923: Total Reward = 3.15
# Episode 924: Total Reward = 1.0499999999999998
# Episode 925: Total Reward = -0.7
# Episode 926: Total Reward = -31.849999999999998
# Episode 927: Total Reward = 3.5
# Episode 928: Total Reward = 3.5
# Episode 929: Total Reward = 4.199999999999999
# Episode 930: Total Reward = -0.35
# Episode 931: Total Reward = 3.8499999999999996
# Episode 932: Total Reward = 2.8
# Episode 933: Total Reward = 2.4499999999999997
# Episode 934: Total Reward = -1.75
# Episode 935: Total Reward = -0.35
# Episode 936: Total Reward = 3.15
# Episode 937: Total Reward = 2.8
# Episode 938: Total Reward = 2.4499999999999997
# Episode 939: Total Reward = 0.35
# Episode 940: Total Reward = 2.8
# Episode 941: Total Reward = 1.4
# Episode 942: Total Reward = 3.5
# Episode 943: Total Reward = 0.7
# Episode 944: Total Reward = 3.15
# Episode 945: Total Reward = 1.4
# Episode 946: Total Reward = 2.4499999999999997
# Episode 947: Total Reward = 1.0499999999999998
# Episode 948: Total Reward = 3.5
# Episode 949: Total Reward = 1.75
# Episode 950: Total Reward = -9.1
# Episode 951: Total Reward = 3.5
# Episode 952: Total Reward = -36.05
# Episode 953: Total Reward = 1.75
# Episode 954: Total Reward = 1.75
# Episode 955: Total Reward = 3.15
# Episode 956: Total Reward = -46.9
# Episode 957: Total Reward = 3.5
# Episode 958: Total Reward = 1.0499999999999998
# Episode 959: Total Reward = 2.0999999999999996
# Episode 960: Total Reward = 3.15
# Episode 961: Total Reward = -1.4
# Episode 962: Total Reward = 2.4499999999999997
# Episode 963: Total Reward = -31.15
# Episode 964: Total Reward = 3.5
# Episode 965: Total Reward = 4.55
# Episode 966: Total Reward = 3.8499999999999996
# Episode 967: Total Reward = 2.4499999999999997
# Episode 968: Total Reward = 3.8499999999999996
# Episode 969: Total Reward = 5.25
# Episode 970: Total Reward = 3.8499999999999996
# Episode 971: Total Reward = 2.8
# Episode 972: Total Reward = 2.0999999999999996
# Episode 973: Total Reward = 3.8499999999999996
# Episode 974: Total Reward = 3.8499999999999996
# Episode 975: Total Reward = 3.5
# Episode 976: Total Reward = 1.4
# Episode 977: Total Reward = 1.4
# Episode 978: Total Reward = -9.45
# Episode 979: Total Reward = 3.15
# Episode 980: Total Reward = -12.25
# Episode 981: Total Reward = 2.4499999999999997
# Episode 982: Total Reward = 2.8
# Episode 983: Total Reward = 3.15
# Episode 984: Total Reward = 3.5
# Episode 985: Total Reward = 5.25
# Episode 986: Total Reward = 3.15
# Episode 987: Total Reward = 3.15
# Episode 988: Total Reward = -6.6499999999999995
# Episode 989: Total Reward = 3.8499999999999996
# Episode 990: Total Reward = 0.0
# Episode 991: Total Reward = 1.4
# Episode 992: Total Reward = 2.4499999999999997
# Episode 993: Total Reward = 2.4499999999999997
# Episode 994: Total Reward = -5.6
# Episode 995: Total Reward = 2.8
# Episode 996: Total Reward = 2.0999999999999996
# Episode 997: Total Reward = 3.8499999999999996
# Episode 998: Total Reward = 2.4499999999999997
# Episode 999: Total Reward = 4.55
# Episode 1000: Total Reward = 4.199999999999999
# Episode 1001: Total Reward = 2.0999999999999996
# Episode 1002: Total Reward = 3.5
# Episode 1003: Total Reward = -0.35
# Episode 1004: Total Reward = 2.8
# Episode 1005: Total Reward = 3.8499999999999996
# Episode 1006: Total Reward = 0.35
# Episode 1007: Total Reward = 4.199999999999999
# Episode 1008: Total Reward = 1.0499999999999998
# Episode 1009: Total Reward = 1.75
# Episode 1010: Total Reward = 2.4499999999999997
# Episode 1011: Total Reward = 2.4499999999999997
# Episode 1012: Total Reward = -8.049999999999999
# Episode 1013: Total Reward = 3.15
# Episode 1014: Total Reward = 3.8499999999999996
# Episode 1015: Total Reward = 4.199999999999999
# Episode 1016: Total Reward = 2.8
# Episode 1017: Total Reward = -1.0499999999999998
# Episode 1018: Total Reward = 4.55
# Episode 1019: Total Reward = 3.8499999999999996
# Episode 1020: Total Reward = -14.7
# Episode 1021: Total Reward = 4.199999999999999
# Episode 1022: Total Reward = 2.8
# Episode 1023: Total Reward = 3.8499999999999996
# Episode 1024: Total Reward = 3.5
# Episode 1025: Total Reward = 1.75
# Episode 1026: Total Reward = 3.5
# Episode 1027: Total Reward = 4.55
# Episode 1028: Total Reward = 1.75
# Episode 1029: Total Reward = 2.4499999999999997
# Episode 1030: Total Reward = 4.8999999999999995
# Episode 1031: Total Reward = 1.75
# Episode 1032: Total Reward = 1.4
# Episode 1033: Total Reward = 2.0999999999999996
# Episode 1034: Total Reward = -0.35
# Episode 1035: Total Reward = 4.199999999999999
# Episode 1036: Total Reward = 1.75
# Episode 1037: Total Reward = -30.799999999999997
# Episode 1038: Total Reward = 2.4499999999999997
# Episode 1039: Total Reward = 3.5
# Episode 1040: Total Reward = 3.8499999999999996
# Episode 1041: Total Reward = 2.0999999999999996
# Episode 1042: Total Reward = 2.0999999999999996
# Episode 1043: Total Reward = 3.5
# Episode 1044: Total Reward = 1.75
# Episode 1045: Total Reward = 1.75
# Episode 1046: Total Reward = 2.8
# Episode 1047: Total Reward = 2.8
# Episode 1048: Total Reward = 3.8499999999999996
# Episode 1049: Total Reward = 2.4499999999999997
# Episode 1050: Total Reward = -77.69999999999999
# Episode 1051: Total Reward = 1.0499999999999998
# Episode 1052: Total Reward = -0.7
# Episode 1053: Total Reward = 3.5
# Episode 1054: Total Reward = 1.75
# Episode 1055: Total Reward = 1.75
# Episode 1056: Total Reward = 1.75
# Episode 1057: Total Reward = 0.35
# Episode 1058: Total Reward = -33.599999999999994
# Episode 1059: Total Reward = 1.0499999999999998
# Episode 1060: Total Reward = 1.75
# Episode 1061: Total Reward = 4.199999999999999
# Episode 1062: Total Reward = 2.4499999999999997
# Episode 1063: Total Reward = 1.0499999999999998
# Episode 1134: Total Reward = 3.8499999999999996
# Episode 1135: Total Reward = 2.4499999999999997
# Episode 1136: Total Reward = 2.4499999999999997
# Episode 1137: Total Reward = 3.8499999999999996
# Episode 1138: Total Reward = 3.15
# Episode 1139: Total Reward = 2.8
# Episode 1140: Total Reward = 1.0499999999999998
# Episode 1141: Total Reward = 3.15
# Episode 1142: Total Reward = 3.8499999999999996
# Episode 1143: Total Reward = 2.8
# Episode 1144: Total Reward = -5.6
# Episode 1145: Total Reward = 4.199999999999999
# Episode 1146: Total Reward = 1.75
# Episode 1147: Total Reward = 3.5
# Episode 1148: Total Reward = 4.8999999999999995
# Episode 1149: Total Reward = 1.0499999999999998
# Episode 1150: Total Reward = 3.15
# Episode 1151: Total Reward = 2.4499999999999997
# Episode 1152: Total Reward = 4.199999999999999
# Episode 1153: Total Reward = 1.4
# Episode 1154: Total Reward = 2.0999999999999996
# Episode 1155: Total Reward = -23.799999999999997
# Episode 1156: Total Reward = -4.55
# Episode 1157: Total Reward = 1.4
# Episode 1158: Total Reward = 3.5
# Episode 1159: Total Reward = 3.15
# Episode 1160: Total Reward = 3.8499999999999996
# Episode 1161: Total Reward = 2.4499999999999997
# Episode 1162: Total Reward = -1.75
# Episode 1163: Total Reward = 2.0999999999999996
# Episode 1164: Total Reward = 3.5
# Episode 1165: Total Reward = 1.75
# Episode 1166: Total Reward = -18.2
# Episode 1167: Total Reward = 2.8
# Episode 1168: Total Reward = 2.0999999999999996
# Episode 1169: Total Reward = -11.549999999999999
# Episode 1170: Total Reward = 0.35
# Episode 1171: Total Reward = 0.35
# Episode 1172: Total Reward = 3.15
# Episode 1173: Total Reward = 3.15
# Episode 1174: Total Reward = 4.199999999999999
# Episode 1175: Total Reward = -0.7
# Episode 1176: Total Reward = 0.7
# Episode 1177: Total Reward = 2.4499999999999997
# Episode 1178: Total Reward = 2.8
# Episode 1179: Total Reward = 2.8
# Episode 1180: Total Reward = 3.8499999999999996
# Episode 1181: Total Reward = -1.4
# Episode 1182: Total Reward = 3.5
# Episode 1183: Total Reward = -5.25
# Episode 1184: Total Reward = 2.8
# Episode 1185: Total Reward = 2.0999999999999996
# Episode 1186: Total Reward = 3.15
# Episode 1187: Total Reward = 3.15
# Episode 1188: Total Reward = 3.15
# Episode 1189: Total Reward = 4.199999999999999
# Episode 1190: Total Reward = 3.15
# Episode 1191: Total Reward = 2.0999999999999996
# Episode 1192: Total Reward = -5.949999999999999
# Episode 1193: Total Reward = 1.0499999999999998
# Episode 1194: Total Reward = 0.35
# Episode 1195: Total Reward = 2.4499999999999997
# Episode 1196: Total Reward = 3.8499999999999996
# Episode 1197: Total Reward = 1.75
# Episode 1198: Total Reward = 3.8499999999999996
# Episode 1199: Total Reward = 4.199999999999999
# Episode 1200: Total Reward = 3.15
# Episode 1201: Total Reward = 1.75
# Episode 1202: Total Reward = -0.35
# Episode 1203: Total Reward = -1.4
# Episode 1204: Total Reward = 2.4499999999999997
# Episode 1205: Total Reward = 3.15
# Episode 1206: Total Reward = 3.15
# Episode 9945: Total Reward = 4.199999999999999
# Episode 9946: Total Reward = 2.8
# Episode 9947: Total Reward = 3.8499999999999996
# Episode 9948: Total Reward = 2.8
# Episode 9949: Total Reward = 2.4499999999999997
# Episode 9950: Total Reward = 2.0999999999999996
# Episode 9951: Total Reward = 4.55
# Episode 9952: Total Reward = 1.4
# Episode 9953: Total Reward = 2.8
# Episode 9954: Total Reward = 1.75
# Episode 9955: Total Reward = 1.4
# Episode 9956: Total Reward = 4.199999999999999
# Episode 9957: Total Reward = 2.4499999999999997
# Episode 9958: Total Reward = 2.0999999999999996
# Episode 9959: Total Reward = 2.4499999999999997
# Episode 9960: Total Reward = 2.8
# Episode 9961: Total Reward = 3.15
# Episode 9962: Total Reward = 0.0
# Episode 9963: Total Reward = 3.15
# Episode 9964: Total Reward = 1.75
# Episode 9965: Total Reward = 2.8
# Episode 9966: Total Reward = -0.7
# Episode 9967: Total Reward = 2.0999999999999996
# Episode 9968: Total Reward = 3.8499999999999996
# Episode 9969: Total Reward = -1.0499999999999998
# Episode 9970: Total Reward = 2.8
# Episode 9971: Total Reward = 3.15
# Episode 9972: Total Reward = 2.4499999999999997
# Episode 9973: Total Reward = 2.4499999999999997
# Episode 9974: Total Reward = 3.15
# Episode 9975: Total Reward = 3.15
# Episode 9976: Total Reward = 4.8999999999999995
# Episode 9977: Total Reward = 4.8999999999999995
# Episode 9978: Total Reward = -4.199999999999999
# Episode 9979: Total Reward = 1.75
# Episode 9980: Total Reward = 1.0499999999999998
# Episode 9981: Total Reward = 2.4499999999999997
# Episode 9982: Total Reward = 1.0499999999999998
# Episode 9983: Total Reward = 3.8499999999999996
# Episode 9984: Total Reward = 1.75
# Episode 9985: Total Reward = 2.8
# Episode 9986: Total Reward = 4.199999999999999
# Episode 9987: Total Reward = 3.5
# Episode 9988: Total Reward = 4.55
# Episode 9989: Total Reward = -32.55
# Episode 9990: Total Reward = 4.199999999999999
# Episode 9991: Total Reward = 5.25
# Episode 9992: Total Reward = 1.4
# Episode 9993: Total Reward = 1.75
# Episode 9994: Total Reward = 2.8
# Episode 9995: Total Reward = 4.8999999999999995
# Episode 9996: Total Reward = 1.75
# Episode 9997: Total Reward = 2.0999999999999996
# Episode 9998: Total Reward = 3.5
# Episode 9999: Total Reward = 4.55
# Episode 10000: Total Reward = 2.4499999999999997

# %%
smdp.plot_Q()

# %% [markdown]
# ### INTRA OPTION

# %%
q_intra = np.zeros((500,10))
qf = np.zeros((500,10))
qof = np.zeros((4,25,4))

# %%
class INTRAOPT:
    def __init__(self):
        self.avg_reward = []
        self.total_reward = []

    def Qlearn(self):
        epsilon = 0.1
        for episode in range(5000):
            running = 0
            state, _ = env.reset()
            done = False
            ep_reward = 0
            steps = 0

            while not done :
                steps += 1
                state = env.s
                action = choose_action(state,q_intra,epsilon)
                if action < 6:
                    next_state, reward, done, _, _ = env.step(action)
                    ep_reward += reward
                    q_intra[state,action] = q_intra[state, action] + ALPHA * (reward + GAMMA * np.max(q_intra[next_state, :])- q_intra[state, action])
                    qf[state,action] += 1
                    state = next_state
                
                reward_bar = 0
                if action > 5 :
                    count = 0
                    
                    optdone = False
                    current_state = state
                    state = encode(get_state(state)[0:2]) 

                    while (optdone == False) :
                        if action == 6:
                            optact, optdone = Red(Q_opt[0],state,epsilon) 
                            next_state, reward, done, _, _ = env.step(optact)
                            next = encode(get_state(next_state)[0:2])
                            #Q_opt[0][state,optact] = Q_opt[0][state, optact] + ALPHA * (reward + GAMMA * np.max(Q_opt[0][next, :])- Q_opt[0][state, optact])
                            qof[0][state,optact] += 1

                        if action == 7:
                            optact, optdone = Green(Q_opt[1],state,epsilon)
                            next_state, reward, done, _, _ = env.step(optact)
                            next = encode(get_state(next_state)[0:2])
                            #Q_opt[1][state,optact] = Q_opt[1][state, optact] + ALPHA * (reward + GAMMA * np.max(Q_opt[1][next, :])- Q_opt[1][state, optact])
                            qof[1][state,optact] += 1

                        if action == 8:
                            optact, optdone = Blue(Q_opt[2],state,epsilon)
                            next_state, reward, done, _, _ = env.step(optact)
                            next = encode(get_state(next_state)[0:2])
                            #Q_opt[2][state,optact] = Q_opt[2][state, optact] + ALPHA * (reward + GAMMA * np.max(Q_opt[2][next, :])- Q_opt[2][state, optact])
                            qof[2][state,optact] += 1

                        if action == 9:

                            optact, optdone = Yellow(Q_opt[3],state,epsilon)
                            next_state, reward, done, _, _ = env.step(optact)
                            next = encode(get_state(next_state)[0:2])
                            #Q_opt[3][state,optact] = Q_opt[3][state, optact] + ALPHA * (reward + GAMMA * np.max(Q_opt[3][next])- Q_opt[3][state, optact])
                            qof[3][state,optact] += 1

                        reward_bar =  reward_bar + (GAMMA**count)*reward
                        ep_reward += reward
                        count += 1
                        state = next
                        statey = env.s
                        q_intra[statey, action] += ALPHA * (reward_bar - q_intra[statey, action] + (GAMMA**count) * np.max(q_intra[statey, :]))
                        
                        
                if epsilon > 0.01:
                    epsilon = epsilon*np.exp(-0.01)
            running = 0.35 * ep_reward + (1 - 0.35) * running
            self.avg_reward.append(running)
            self.total_reward.append(ep_reward)
            print(f"Episode {episode + 1}: Total Reward = {running}")
        return self.avg_reward, self.total_reward
    
    def plot(self):
        plt.plot(self.avg_reward,label="Moving Average")
        plt.grid()
        plt.plot(self.total_reward,label="Total Rewards",alpha=1, color='orange')
        plt.xlabel('Episode')
        plt.ylabel('Averaged Episodic Returns')
        plt.title("Averaged Episodic Returns")
        plt.legend()
        plt.savefig('SMDP.png')
        plt.show()

    def render_run(self):
        special_env = gym.make('Taxi-v3',render_mode='human')
        done = False
        eps = 0.01
        state, _ = special_env.reset()
        while not done:
            action = choose_action(state,q,eps)
            next_state, reward, done, _, _ = special_env.step(action)
            if done:
                break

    def plot_Q(self):
        ACTIONS = {0: "South",1: "Up",2: "East",3: "West",4: "Pick",5: "Drop",6: "R",7: "G",8: "B", 9: "Y"}
        # decode each state 
        # ((taxi_row * 5 + taxi_col) * 5 + passenger_location) * 4 + destination
        action = np.argmax(q,axis=1)
        action_f = np.argmax(qf,axis=1)

        dest_r = action[::4]
        dest_g = action[1::4]
        dest_b = action[2::4]
        dest_y = action[3::4]

        dest_r_f = action_f[::4]
        dest_g_f = action_f[1::4]
        dest_b_f = action_f[2::4]
        dest_y_f = action_f[3::4]

        loc_r_r = dest_r[::5]
        loc_r_g = dest_g[::5]
        loc_r_b = dest_b[::5]
        loc_r_y = dest_y[::5]

        loc_r_r_f = dest_r_f[::5]
        loc_r_g_f = dest_g_f[::5]
        loc_r_b_f = dest_b_f[::5]
        loc_r_y_f = dest_y_f[::5]

        loc_g_r = dest_r[1::5]
        loc_g_g = dest_g[1::5]
        loc_g_b = dest_b[1::5]
        loc_g_y = dest_y[1::5]

        loc_g_r_f = dest_r_f[1::5]
        loc_g_g_f = dest_g_f[1::5]
        loc_g_b_f = dest_b_f[1::5]
        loc_g_y_f = dest_y_f[1::5]

        loc_b_r = dest_r[2::5]
        loc_b_g = dest_g[2::5]
        loc_b_b = dest_b[2::5]
        loc_b_y = dest_y[2::5]

        loc_b_r_f = dest_r_f[2::5]
        loc_b_g_f = dest_g_f[2::5]
        loc_b_b_f = dest_b_f[2::5]
        loc_b_y_f = dest_y_f[2::5]

        loc_y_r = dest_r[3::5]
        loc_y_g = dest_g[3::5]
        loc_y_b = dest_b[3::5]
        loc_y_y = dest_y[3::5]

        loc_y_r_f = dest_r_f[3::5]
        loc_y_g_f = dest_g_f[3::5]
        loc_y_b_f = dest_b_f[3::5]
        loc_y_y_f = dest_y_f[3::5]

        action_o = np.argmax(Q_opt,axis=2)
        action_o_f = np.argmax(qof,axis=2)

        dest_r = action_o[0]
        dest_g = action_o[1]
        dest_b = action_o[2]
        dest_y = action_o[3]

        freq_r = action_o_f[0]
        freq_g = action_o_f[1]
        freq_b = action_o_f[2]
        freq_y = action_o_f[3]

        # Create a 5x5 grid for grid and frequncy
        grid = np.reshape(loc_r_g, (5, 5))
        freq = np.reshape(loc_r_g_f, (5, 5))

        # Create a 5x5 grid for grid and frequncy
        grid_dest = np.reshape(dest_r, (5, 5))
        freq_dest = np.reshape(freq_r, (5, 5))

        fig, axs = plt.subplots(1, 2, figsize=(10, 5))

        # Display the grid with numbers for loc_r_g
        axs[0].imshow(freq, cmap='viridis', interpolation='nearest')
        for i in range(5):
            for j in range(5):
                text = ACTIONS[grid[i, j]]
                axs[0].text(j, i, text, ha='center', va='center', color='black')

        # Add labels and title for loc_r_g
        axs[0].set_title("Red passenger to dest Green q table")
        axs[0].set_xlabel('Column')
        axs[0].set_ylabel('Row')

        # Display the grid with numbers for dest_r
        axs[1].imshow(freq_dest, cmap='viridis', interpolation='nearest')
        for i in range(5):
            for j in range(5):
                text = ACTIONS[grid_dest[i, j]]
                axs[1].text(j, i, text, ha='center', va='center', color='black')

        # Add labels and title for dest_r
        axs[1].set_title("Red Option Policy")
        axs[1].set_xlabel('Column')
        axs[1].set_ylabel('Row')

        plt.tight_layout()
        plt.show()

# %%
agent2 = INTRAOPT()
agent2.Qlearn()
agent2.plot()
