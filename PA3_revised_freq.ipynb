# %%
import numpy as np
from tqdm import tqdm
import gym
import math
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
env = gym.make('Taxi-v3')
num_actions = env.action_space
num_obs = env.observation_space
R, G, B, Y = env.unwrapped.locs
R, G, B, Y = list(R), list(G), list(B), list(Y)
env.reset()
# Out:
# (242, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})

# %%
def get_state(state):
    row, col, pass_id, dest_id = env.unwrapped.decode(state)
    state = np.asarray([row,col,pass_id,dest_id])
    return state

#encoding a 5x5 matrix as a 25x1 vector
def encode(pose):
    [row,col] = pose
    state_num = row * 5 + col
    return state_num

def decode(state_num):
    row = state_num // 5
    col = state_num % 5
    return row, col

print(R,G,B,Y)
# Out:
# [0, 0] [0, 4] [4, 0] [4, 3]

# %%
curr_state = get_state(env.s)
print("Taxi at",curr_state)
next_state, reward, done, _, _ = env.step(4)
row, col, pass_id, dest_id = env.unwrapped.decode(next_state)
# Out:
# Taxi at [2 2 0 2]

# %%
# Set the number of episodes and maximum number of steps per episode
EPS = 10000
MAX_STEPS = 500
EXP = 1
# Set the learning rate, discount factor, and exploration rate
ALPHA = 0.15
GAMMA = 0.99
exploration_rate = 1.0
MIN_EXP = 0.01
EXP_DECAY = 0.01

# %%
def choose_action(state,qs,eps):
    #print(np.shape(q))
    length = np.shape(qs)[1]
    if not qs[state].any():
        return random.randint(0,length-1)
    action = np.argmax(qs[state])
    
    if np.random.rand() < eps:
        action = np.random.randint(0,length-1)
        return action
    return action   

def choose_action_option(state,qs):
    action = np.argmax(qs[state])
    return action

# %%
# Options where policy is greedy wrt the corresponding q Value function
def Red(q_r,state,eps):
    optdone = False
    optact = choose_action(state,q_r,eps)
    state = decode(state)
    if state[0] == R[0] and state[1] == R[1]:
        optdone = True
    return optact,optdone

def Green(q_g,state,eps):
    optdone = False
    optact = choose_action(state,q_g,eps)
    state = decode(state)
    if state[0] == G[0] and state[1] == G[1]:
        optdone = True
    return optact,optdone
    
def Yellow(q_y,state,eps):
    optdone = False
    optact = choose_action(state,q_y,eps)
    state = decode(state)
    if state[0] == Y[0] and state[1] == Y[1]:
        optdone = True
    return optact,optdone 

def Blue(q_b,state,eps):
    optdone = False
    optact = choose_action(state,q_b,eps)
    state = decode(state)
    if state[0] == B[0] and state[1] == B[1]:
        optdone = True
    return optact,optdone

# %%
Q_opt = np.zeros((4,25,4))
q = np.zeros((500,10))
qf = np.zeros((500,10))
qof = np.zeros((4,25,4))

# %% [markdown]
# SMDP

# %%
class SMDP:
    def __init__(self):
        self.avg_reward = []
        self.total_reward = []

    def Qlearn(self):
        epsilon = 0.1
        for episode in range(5000):
            running = 0
            state, _ = env.reset()
            done = False
            ep_reward = 0
            steps = 0

            while not done :
                steps += 1
                action = choose_action(state,q,epsilon)
                if action < 6:
                    next_state, reward, done, _, _ = env.step(action)
                    ep_reward += reward
                    q[state,action] = q[state, action] + ALPHA * (reward + GAMMA * np.max(q[next_state, :])- q[state, action])
                    qf[state,action] += 1
                    state = next_state
                
                reward_bar = 0
                if action > 5 :
                    count = 0
                    optdone = False
                    current_state = state
                    state = encode(get_state(state)[0:2]) 

                    while (optdone == False) :
                        if action == 6:
                            optact, optdone = Red(Q_opt[0],state,epsilon) 
                            next_state, reward, done, _, _ = env.step(optact)
                            next = encode(get_state(next_state)[0:2])
                            Q_opt[0][state,optact] = Q_opt[0][state, optact] + ALPHA * (reward + GAMMA * np.max(Q_opt[0][next, :])- Q_opt[0][state, optact])
                            qof[0][state,optact] += 1

                        if action == 7:
                            optact, optdone = Green(Q_opt[1],state,epsilon)
                            next_state, reward, done, _, _ = env.step(optact)
                            next = encode(get_state(next_state)[0:2])
                            Q_opt[1][state,optact] = Q_opt[1][state, optact] + ALPHA * (reward + GAMMA * np.max(Q_opt[1][next, :])- Q_opt[1][state, optact])
                            qof[1][state,optact] += 1

                        if action == 8:
                            optact, optdone = Blue(Q_opt[2],state,epsilon)
                            next_state, reward, done, _, _ = env.step(optact)
                            next = encode(get_state(next_state)[0:2])
                            Q_opt[2][state,optact] = Q_opt[2][state, optact] + ALPHA * (reward + GAMMA * np.max(Q_opt[2][next, :])- Q_opt[2][state, optact])
                            qof[2][state,optact] += 1

                        if action == 9:

                            optact, optdone = Yellow(Q_opt[3],state,epsilon)
                            next_state, reward, done, _, _ = env.step(optact)
                            next = encode(get_state(next_state)[0:2])
                            Q_opt[3][state,optact] = Q_opt[3][state, optact] + ALPHA * (reward + GAMMA * np.max(Q_opt[3][next])- Q_opt[3][state, optact])
                            qof[3][state,optact] += 1

                        reward_bar =  reward_bar + (GAMMA**count)*reward
                        ep_reward += reward
                        count += 1
                        state = next
                        if optdone == True:
                            q[current_state, action] += ALPHA * (reward_bar - q[current_state, action] + (GAMMA**count) * np.max(q[next_state, :]))
                            state = env.s
                        
                if epsilon > 0.01:
                    epsilon = epsilon*np.exp(-0.01)
            running = 0.35 * ep_reward + (1 - 0.35) * running
            self.avg_reward.append(running)
            self.total_reward.append(ep_reward)
            print(f"Episode {episode + 1}: Total Reward = {running}")
        return self.avg_reward, self.total_reward
    
    def plot(self):
        plt.plot(self.avg_reward,label="Moving Average")
        plt.grid()
        plt.plot(self.total_reward,label="Total Rewards",alpha=1, color='orange')
        plt.xlabel('Episode')
        plt.ylabel('Averaged Episodic Returns')
        plt.title("Averaged Episodic Returns")
        plt.legend()
        plt.savefig('SMDP.png')
        plt.show()

    def render_run(self):
        special_env = gym.make('Taxi-v3',render_mode='human')
        done = False
        eps = 0.01
        state, _ = special_env.reset()
        while not done:
            action = choose_action(state,q,eps)
            next_state, reward, done, _, _ = special_env.step(action)
            if done:
                break

    def plot_Q(self):
        ACTIONS = {0: "South",1: "Up",2: "East",3: "West",4: "Pick",5: "Drop",6: "R",7: "G",8: "B", 9: "Y"}
        # decode each state 
        # ((taxi_row * 5 + taxi_col) * 5 + passenger_location) * 4 + destination
        action = np.argmax(q,axis=1)
        action_f = np.argmax(qof,axis=1)

        dest_r = action[::4]
        dest_g = action[1::4]
        dest_b = action[2::4]
        dest_y = action[3::4]

        dest_r_f = action_f[::4]
        dest_g_f = action_f[1::4]
        dest_b_f = action_f[2::4]
        dest_y_f = action_f[3::4]

        loc_r_r = dest_r[::5]
        loc_r_g = dest_g[::5]
        loc_r_b = dest_b[::5]
        loc_r_y = dest_y[::5]

        loc_r_r_f = dest_r_f[::5]
        loc_r_g_f = dest_g_f[::5]
        loc_r_b_f = dest_b_f[::5]
        loc_r_y_f = dest_y_f[::5]

        loc_g_r = dest_r[1::5]
        loc_g_g = dest_g[1::5]
        loc_g_b = dest_b[1::5]
        loc_g_y = dest_y[1::5]

        loc_g_r_f = dest_r_f[1::5]
        loc_g_g_f = dest_g_f[1::5]
        loc_g_b_f = dest_b_f[1::5]
        loc_g_y_f = dest_y_f[1::5]

        loc_b_r = dest_r[2::5]
        loc_b_g = dest_g[2::5]
        loc_b_b = dest_b[2::5]
        loc_b_y = dest_y[2::5]

        loc_b_r_f = dest_r_f[2::5]
        loc_b_g_f = dest_g_f[2::5]
        loc_b_b_f = dest_b_f[2::5]
        loc_b_y_f = dest_y_f[2::5]

        loc_y_r = dest_r[3::5]
        loc_y_g = dest_g[3::5]
        loc_y_b = dest_b[3::5]
        loc_y_y = dest_y[3::5]

        loc_y_r_f = dest_r_f[3::5]
        loc_y_g_f = dest_g_f[3::5]
        loc_y_b_f = dest_b_f[3::5]
        loc_y_y_f = dest_y_f[3::5]

    # Create a 5x5 grid for grid and frequncy
        grid = np.reshape(loc_r_g, (5, 5))
        freq = np.reshape(loc_r_g_f, (5, 5))

    # Display the grid with numbers
        plt.imshow(freq, cmap='viridis', interpolation='nearest')
        for i in range(5):
            for j in range(5):
                text = ACTIONS[grid[i, j]]
                plt.text(j, i, text, ha='center', va='center', color='black')

    # Add labels and title
        plt.colorbar()
        plt.xlabel('Column')
        plt.ylabel('Row')
        plt.show()

# %% [markdown]
# Working

# %%
smdp = SMDP()
smdp.Qlearn()
smdp.plot()
# Out:
# Episode 1: Total Reward = -1668.1
# Episode 2: Total Reward = -1479.8
# Episode 3: Total Reward = -251.29999999999998
# Episode 4: Total Reward = -44.8
# Episode 5: Total Reward = -276.84999999999997
# Episode 6: Total Reward = -705.9499999999999
# Episode 7: Total Reward = -501.9
# Episode 8: Total Reward = -177.79999999999998
# Episode 9: Total Reward = -793.0999999999999
# Episode 10: Total Reward = -929.5999999999999
# Episode 11: Total Reward = -209.64999999999998
# Episode 12: Total Reward = -550.55
# Episode 13: Total Reward = -1811.9499999999998
# Episode 14: Total Reward = -163.1
# Episode 15: Total Reward = -353.84999999999997
# Episode 16: Total Reward = -209.29999999999998
# Episode 17: Total Reward = -204.04999999999998
# Episode 18: Total Reward = -527.1
# Episode 19: Total Reward = -279.29999999999995
# Episode 20: Total Reward = -1234.4499999999998
# Episode 21: Total Reward = -171.85
# Episode 22: Total Reward = -1075.1999999999998
# Episode 23: Total Reward = -410.9
# Episode 24: Total Reward = -164.85
# Episode 25: Total Reward = -1297.8
# Episode 26: Total Reward = -661.5
# Episode 27: Total Reward = -141.04999999999998
# Episode 28: Total Reward = -1123.1499999999999
# Episode 29: Total Reward = -651.3499999999999
# Episode 30: Total Reward = -510.99999999999994
# Episode 31: Total Reward = -463.4
# Episode 32: Total Reward = -230.29999999999998
# Episode 33: Total Reward = -499.79999999999995
# Episode 34: Total Reward = -280.0
# Episode 35: Total Reward = -442.04999999999995
# Episode 36: Total Reward = -229.95
# Episode 37: Total Reward = -572.5999999999999
# Episode 38: Total Reward = -367.15
# Episode 39: Total Reward = -382.9
# Episode 40: Total Reward = -335.29999999999995
# Episode 41: Total Reward = -801.8499999999999
# Episode 42: Total Reward = -745.5
# Episode 43: Total Reward = -135.45
# Episode 44: Total Reward = -758.4499999999999
# Episode 45: Total Reward = -412.29999999999995
# Episode 46: Total Reward = -1869.35
# Episode 47: Total Reward = -430.84999999999997
# Episode 48: Total Reward = -274.4
# Episode 49: Total Reward = -118.64999999999999
# Episode 50: Total Reward = -111.3
# Episode 51: Total Reward = -812.3499999999999
# Episode 52: Total Reward = -254.45
# Episode 53: Total Reward = -565.5999999999999
# Episode 54: Total Reward = -92.39999999999999
# Episode 55: Total Reward = -895.3
# Episode 56: Total Reward = -241.49999999999997
# Episode 57: Total Reward = -329.34999999999997
# Episode 58: Total Reward = -403.54999999999995
# Episode 59: Total Reward = -37.8
# Episode 60: Total Reward = -192.5
# Episode 61: Total Reward = -248.85
# Episode 62: Total Reward = -91.0
# Episode 63: Total Reward = -227.14999999999998
# Episode 64: Total Reward = -245.7
# Episode 65: Total Reward = -707.0
# Episode 66: Total Reward = -169.04999999999998
# Episode 67: Total Reward = -269.5
# Episode 68: Total Reward = -149.45
# Episode 69: Total Reward = -64.05
# Episode 70: Total Reward = -29.4
# Episode 71: Total Reward = -52.15
# Episode 72: Total Reward = -306.95
# Episode 73: Total Reward = -95.55
# Episode 74: Total Reward = -68.6
# Episode 75: Total Reward = -71.05
# Episode 76: Total Reward = -43.05
# Episode 77: Total Reward = -336.7
# Episode 78: Total Reward = -115.14999999999999
# Episode 79: Total Reward = -905.8
# Episode 80: Total Reward = -65.1
# Episode 81: Total Reward = -271.59999999999997
# Episode 82: Total Reward = -155.04999999999998
# Episode 83: Total Reward = -559.65
# Episode 84: Total Reward = -172.2
# Episode 85: Total Reward = -126.69999999999999
# Episode 86: Total Reward = -39.55
# Episode 87: Total Reward = -173.25
# Episode 88: Total Reward = -240.45
# Episode 89: Total Reward = -223.64999999999998
# Episode 90: Total Reward = -62.65
# Episode 91: Total Reward = -1510.9499999999998
# Episode 92: Total Reward = -147.0
# Episode 93: Total Reward = -278.95
# Episode 94: Total Reward = -50.4
# Episode 95: Total Reward = -76.64999999999999
# Episode 96: Total Reward = -145.6
# Episode 97: Total Reward = -197.75
# Episode 98: Total Reward = -401.79999999999995
# Episode 99: Total Reward = -144.54999999999998
# Episode 100: Total Reward = -30.099999999999998
# Episode 101: Total Reward = -310.45
# Episode 102: Total Reward = -222.6
# Episode 103: Total Reward = -128.1
# Episode 104: Total Reward = -172.2
# Episode 105: Total Reward = -284.54999999999995
# Episode 106: Total Reward = -132.29999999999998
# Episode 107: Total Reward = -121.8
# Episode 108: Total Reward = -223.29999999999998
# Episode 109: Total Reward = -451.15
# Episode 110: Total Reward = -178.5
# Episode 111: Total Reward = -63.699999999999996
# Episode 112: Total Reward = -184.79999999999998
# Episode 113: Total Reward = -258.65
# Episode 114: Total Reward = -169.04999999999998
# Episode 115: Total Reward = -47.25
# Episode 116: Total Reward = -166.6
# Episode 117: Total Reward = -285.59999999999997
# Episode 118: Total Reward = -131.25
# Episode 119: Total Reward = -30.799999999999997
# Episode 120: Total Reward = -326.9
# Episode 121: Total Reward = -103.6
# Episode 122: Total Reward = -316.04999999999995
# Episode 123: Total Reward = -17.15
# Episode 124: Total Reward = -167.64999999999998
# Episode 125: Total Reward = -32.55
# Episode 126: Total Reward = -143.14999999999998
# Episode 127: Total Reward = -119.69999999999999
# Episode 128: Total Reward = -104.64999999999999
# Episode 129: Total Reward = -130.54999999999998
# Episode 130: Total Reward = -61.949999999999996
# Episode 131: Total Reward = -226.79999999999998
# Episode 132: Total Reward = -13.299999999999999
# Episode 133: Total Reward = -156.1
# Episode 134: Total Reward = -203.7
# Episode 135: Total Reward = -325.5
# Episode 136: Total Reward = -362.59999999999997
# Episode 137: Total Reward = -30.099999999999998
# Episode 138: Total Reward = -98.35
# Episode 139: Total Reward = -371.7
# Episode 140: Total Reward = -47.949999999999996
# Episode 141: Total Reward = -123.89999999999999
# Episode 142: Total Reward = -31.499999999999996
# Episode 143: Total Reward = -85.05
# Episode 144: Total Reward = -66.5
# Episode 145: Total Reward = -113.05
# Episode 146: Total Reward = -210.0
# Episode 147: Total Reward = -151.2
# Episode 148: Total Reward = -107.44999999999999
# Episode 149: Total Reward = -142.45
# Episode 150: Total Reward = -134.04999999999998
# Episode 151: Total Reward = -45.5
# Episode 152: Total Reward = -73.14999999999999
# Episode 153: Total Reward = -26.95
# Episode 154: Total Reward = -62.3
# Episode 155: Total Reward = -197.39999999999998
# Episode 156: Total Reward = -46.55
# Episode 157: Total Reward = -90.64999999999999
# Episode 158: Total Reward = -26.25
# Episode 159: Total Reward = -155.04999999999998
# Episode 160: Total Reward = -73.5
# Episode 161: Total Reward = -57.4
# Episode 162: Total Reward = -5.949999999999999
# Episode 163: Total Reward = -35.0
# Episode 164: Total Reward = -107.8
# Episode 165: Total Reward = -199.85
# Episode 166: Total Reward = -122.49999999999999
# Episode 167: Total Reward = -211.04999999999998
# Episode 168: Total Reward = -75.6
# Episode 169: Total Reward = -81.19999999999999
# Episode 170: Total Reward = -113.39999999999999
# Episode 171: Total Reward = -1.0499999999999998
# Episode 172: Total Reward = -123.19999999999999
# Episode 173: Total Reward = -63.349999999999994
# Episode 174: Total Reward = 2.4499999999999997
# Episode 175: Total Reward = 0.35
# Episode 176: Total Reward = -25.549999999999997
# Episode 177: Total Reward = -34.65
# Episode 178: Total Reward = -107.8
# Episode 179: Total Reward = -169.75
# Episode 180: Total Reward = -88.55
# Episode 181: Total Reward = -30.799999999999997
# Episode 182: Total Reward = -254.79999999999998
# Episode 183: Total Reward = -101.14999999999999
# Episode 184: Total Reward = -9.1
# Episode 185: Total Reward = -24.849999999999998
# Episode 186: Total Reward = -15.399999999999999
# Episode 187: Total Reward = -20.299999999999997
# Episode 188: Total Reward = -36.4
# Episode 189: Total Reward = -53.9
# Episode 190: Total Reward = -70.69999999999999
# Episode 191: Total Reward = -28.349999999999998
# Episode 192: Total Reward = -40.25
# Episode 193: Total Reward = 0.35
# Episode 194: Total Reward = -86.44999999999999
# Episode 195: Total Reward = -81.89999999999999
# Episode 196: Total Reward = -92.05
# Episode 197: Total Reward = -75.94999999999999
# Episode 198: Total Reward = -101.14999999999999
# Episode 199: Total Reward = -159.95
# Episode 200: Total Reward = -217.35
# Episode 201: Total Reward = -109.89999999999999
# Episode 202: Total Reward = -145.25
# Episode 203: Total Reward = -87.85
# Episode 204: Total Reward = -43.75
# Episode 205: Total Reward = -45.15
# Episode 206: Total Reward = -1.75
# Episode 207: Total Reward = -13.299999999999999
# Episode 208: Total Reward = -185.85
# Episode 209: Total Reward = -15.749999999999998
# Episode 210: Total Reward = 0.35
# Episode 211: Total Reward = -79.8
# Episode 212: Total Reward = 2.4499999999999997
# Episode 213: Total Reward = -89.94999999999999
# Episode 214: Total Reward = -8.399999999999999
# Episode 215: Total Reward = -11.549999999999999
# Episode 216: Total Reward = -49.349999999999994
# Episode 217: Total Reward = -113.39999999999999
# Episode 218: Total Reward = -15.749999999999998
# Episode 219: Total Reward = -114.44999999999999
# Episode 220: Total Reward = -162.39999999999998
# Episode 221: Total Reward = -81.89999999999999
# Episode 222: Total Reward = -21.349999999999998
# Episode 223: Total Reward = -8.049999999999999
# Episode 224: Total Reward = -168.7
# Episode 225: Total Reward = -40.25
# Episode 226: Total Reward = -79.1
# Episode 227: Total Reward = -347.54999999999995
# Episode 228: Total Reward = -201.25
# Episode 229: Total Reward = -71.05
# Episode 230: Total Reward = -148.04999999999998
# Episode 231: Total Reward = -82.94999999999999
# Episode 232: Total Reward = -18.2
# Episode 233: Total Reward = -47.25
# Episode 234: Total Reward = -78.39999999999999
# Episode 235: Total Reward = -2.8
# Episode 236: Total Reward = -68.6
# Episode 237: Total Reward = 2.8
# Episode 238: Total Reward = -36.05
# Episode 239: Total Reward = -70.35
# Episode 240: Total Reward = -20.299999999999997
# Episode 241: Total Reward = -124.24999999999999
# Episode 242: Total Reward = -2.0999999999999996
# Episode 243: Total Reward = -4.199999999999999
# Episode 244: Total Reward = -95.89999999999999
# Episode 245: Total Reward = 2.8
# Episode 246: Total Reward = -74.55
# Episode 247: Total Reward = 4.55
# Episode 248: Total Reward = 2.0999999999999996
# Episode 249: Total Reward = -124.24999999999999
# Episode 250: Total Reward = -35.699999999999996
# Episode 251: Total Reward = -94.85
# Episode 252: Total Reward = -118.64999999999999
# Episode 253: Total Reward = -50.05
# Episode 254: Total Reward = -83.3
# Episode 255: Total Reward = -22.75
# Episode 256: Total Reward = -109.89999999999999
# Episode 257: Total Reward = -30.799999999999997
# Episode 258: Total Reward = -44.099999999999994
# Episode 259: Total Reward = -141.39999999999998
# Episode 260: Total Reward = -116.19999999999999
# Episode 261: Total Reward = -133.7
# Episode 262: Total Reward = -68.6
# Episode 263: Total Reward = -109.55
# Episode 264: Total Reward = -86.44999999999999
# Episode 265: Total Reward = -123.19999999999999
# Episode 266: Total Reward = -143.14999999999998
# Episode 267: Total Reward = -201.95
# Episode 268: Total Reward = 3.5
# Episode 269: Total Reward = 4.55
# Episode 270: Total Reward = -17.5
# Episode 271: Total Reward = -104.64999999999999
# Episode 272: Total Reward = -46.199999999999996
# Episode 273: Total Reward = -26.95
# Episode 274: Total Reward = 3.5
# Episode 275: Total Reward = -36.75
# Episode 276: Total Reward = -2.0999999999999996
# Episode 277: Total Reward = -14.35
# Episode 278: Total Reward = -72.1
# Episode 279: Total Reward = -23.099999999999998
# Episode 280: Total Reward = -82.6
# Episode 281: Total Reward = 0.35
# Episode 282: Total Reward = -36.05
# Episode 283: Total Reward = -129.15
# Episode 284: Total Reward = -19.25
# Episode 285: Total Reward = -33.949999999999996
# Episode 286: Total Reward = 2.8
# Episode 287: Total Reward = -141.39999999999998
# Episode 288: Total Reward = -60.55
# Episode 289: Total Reward = -5.949999999999999
# Episode 290: Total Reward = -22.75
# Episode 291: Total Reward = -63.699999999999996
# Episode 292: Total Reward = -120.39999999999999
# Episode 293: Total Reward = 0.0
# Episode 294: Total Reward = -105.0
# Episode 295: Total Reward = -115.85
# Episode 296: Total Reward = -77.69999999999999
# Episode 297: Total Reward = -60.199999999999996
# Episode 298: Total Reward = -122.14999999999999
# Episode 299: Total Reward = 3.8499999999999996
# Episode 300: Total Reward = 0.0
# Episode 301: Total Reward = 3.8499999999999996
# Episode 302: Total Reward = -96.25
# Episode 303: Total Reward = -11.2
# Episode 304: Total Reward = 0.7
# Episode 305: Total Reward = -11.899999999999999
# Episode 306: Total Reward = -15.049999999999999
# Episode 307: Total Reward = -21.349999999999998
# Episode 308: Total Reward = 0.0
# Episode 309: Total Reward = -33.25
# Episode 310: Total Reward = 3.8499999999999996
# Episode 311: Total Reward = -131.6
# Episode 312: Total Reward = -92.05
# Episode 313: Total Reward = -2.4499999999999997
# Episode 314: Total Reward = -10.85
# Episode 315: Total Reward = -42.0
# Episode 316: Total Reward = -65.1
# Episode 317: Total Reward = -7.35
# Episode 318: Total Reward = 1.75
# Episode 319: Total Reward = -18.9
# Episode 320: Total Reward = -34.3
# Episode 321: Total Reward = -42.699999999999996
# Episode 322: Total Reward = -13.649999999999999
# Episode 323: Total Reward = -72.1
# Episode 324: Total Reward = -76.64999999999999
# Episode 325: Total Reward = 4.199999999999999
# Episode 326: Total Reward = -4.55
# Episode 327: Total Reward = 3.5
# Episode 328: Total Reward = -4.55
# Episode 329: Total Reward = -30.799999999999997
# Episode 330: Total Reward = -27.65
# Episode 331: Total Reward = -48.65
# Episode 332: Total Reward = -15.399999999999999
# Episode 333: Total Reward = -27.299999999999997
# Episode 334: Total Reward = -9.1
# Episode 335: Total Reward = -55.65
# Episode 336: Total Reward = -63.699999999999996
# Episode 337: Total Reward = -109.19999999999999
# Episode 338: Total Reward = -12.6
# Episode 339: Total Reward = -0.35
# Episode 340: Total Reward = -9.799999999999999
# Episode 341: Total Reward = -43.05
# Episode 342: Total Reward = 0.7
# Episode 343: Total Reward = -0.7
# Episode 344: Total Reward = -16.799999999999997
# Episode 345: Total Reward = -88.19999999999999
# Episode 346: Total Reward = -25.9
# Episode 347: Total Reward = -15.399999999999999
# Episode 348: Total Reward = -37.449999999999996
# Episode 349: Total Reward = -2.8
# Episode 350: Total Reward = 1.75
# Episode 351: Total Reward = -52.5
# Episode 352: Total Reward = 1.75
# Episode 353: Total Reward = -0.35
# Episode 354: Total Reward = -52.15
# Episode 355: Total Reward = -94.5
# Episode 356: Total Reward = -1.75
# Episode 357: Total Reward = -89.94999999999999
# Episode 358: Total Reward = 0.35
# Episode 359: Total Reward = -52.849999999999994
# Episode 360: Total Reward = -2.0999999999999996
# Episode 361: Total Reward = -2.8
# Episode 362: Total Reward = -29.049999999999997
# Episode 363: Total Reward = -12.95
# Episode 364: Total Reward = -20.299999999999997
# Episode 365: Total Reward = -43.4
# Episode 366: Total Reward = -43.05
# Episode 367: Total Reward = -31.849999999999998
# Episode 368: Total Reward = -157.5
# Episode 369: Total Reward = -29.749999999999996
# Episode 370: Total Reward = 0.7
# Episode 371: Total Reward = -44.449999999999996
# Episode 372: Total Reward = -45.849999999999994
# Episode 373: Total Reward = 2.4499999999999997
# Episode 374: Total Reward = -7.35
# Episode 375: Total Reward = -3.8499999999999996
# Episode 376: Total Reward = -71.05
# Episode 377: Total Reward = 4.199999999999999
# Episode 378: Total Reward = -1.75
# Episode 379: Total Reward = -75.25
# Episode 380: Total Reward = -82.94999999999999
# Episode 381: Total Reward = 4.199999999999999
# Episode 382: Total Reward = -31.15
# Episode 383: Total Reward = 3.8499999999999996
# Episode 384: Total Reward = 4.8999999999999995
# Episode 385: Total Reward = -56.0
# Episode 386: Total Reward = 3.5
# Episode 387: Total Reward = -13.649999999999999
# Episode 388: Total Reward = 1.0499999999999998
# Episode 389: Total Reward = -51.8
# Episode 390: Total Reward = -3.15
# Episode 391: Total Reward = -53.9
# Episode 392: Total Reward = -33.949999999999996
# Episode 393: Total Reward = 4.55
# Episode 394: Total Reward = -45.849999999999994
# Episode 395: Total Reward = -14.35
# Episode 396: Total Reward = -12.25
# Episode 397: Total Reward = -143.14999999999998
# Episode 398: Total Reward = -5.949999999999999
# Episode 399: Total Reward = -3.8499999999999996
# Episode 400: Total Reward = -29.4
# Episode 401: Total Reward = 5.25
# Episode 402: Total Reward = -21.0
# Episode 403: Total Reward = 4.55
# Episode 404: Total Reward = -2.8
# Episode 405: Total Reward = 3.8499999999999996
# Episode 406: Total Reward = 2.8
# Episode 407: Total Reward = 2.8
# Episode 408: Total Reward = -17.15
# Episode 409: Total Reward = 1.0499999999999998
# Episode 410: Total Reward = -29.4
# Episode 411: Total Reward = -29.049999999999997
# Episode 412: Total Reward = -29.049999999999997
# Episode 413: Total Reward = -100.1
# Episode 414: Total Reward = -8.399999999999999
# Episode 415: Total Reward = -0.7
# Episode 416: Total Reward = 3.8499999999999996
# Episode 417: Total Reward = -4.55
# Episode 418: Total Reward = 4.199999999999999
# Episode 419: Total Reward = 4.8999999999999995
# Episode 420: Total Reward = -4.8999999999999995
# Episode 421: Total Reward = 4.8999999999999995
# Episode 422: Total Reward = -6.6499999999999995
# Episode 423: Total Reward = -28.7
# Episode 424: Total Reward = -6.6499999999999995
# Episode 425: Total Reward = -11.549999999999999
# Episode 426: Total Reward = -30.799999999999997
# Episode 427: Total Reward = -38.15
# Episode 428: Total Reward = -29.049999999999997
# Episode 429: Total Reward = 1.75
# Episode 430: Total Reward = -5.25
# Episode 431: Total Reward = 2.0999999999999996
# Episode 432: Total Reward = -12.25
# Episode 433: Total Reward = 3.5
# Episode 434: Total Reward = 1.75
# Episode 435: Total Reward = -55.65
# Episode 436: Total Reward = -30.45
# Episode 437: Total Reward = 3.15
# Episode 438: Total Reward = 1.75
# Episode 439: Total Reward = -42.699999999999996
# Episode 440: Total Reward = -101.14999999999999
# Episode 441: Total Reward = -5.949999999999999
# Episode 442: Total Reward = -1.0499999999999998
# Episode 443: Total Reward = 1.4
# Episode 444: Total Reward = -23.799999999999997
# Episode 445: Total Reward = -35.0
# Episode 446: Total Reward = -32.9
# Episode 447: Total Reward = 2.8
# Episode 448: Total Reward = -0.35
# Episode 449: Total Reward = 3.5
# Episode 450: Total Reward = -59.849999999999994
# Episode 451: Total Reward = -9.45
# Episode 452: Total Reward = -42.699999999999996
# Episode 453: Total Reward = -50.05
# Episode 454: Total Reward = -32.199999999999996
# Episode 455: Total Reward = 3.15
# Episode 456: Total Reward = -28.349999999999998
# Episode 457: Total Reward = 3.5
# Episode 458: Total Reward = 1.75
# Episode 459: Total Reward = -85.39999999999999
# Episode 460: Total Reward = 3.8499999999999996
# Episode 461: Total Reward = -23.45
# Episode 462: Total Reward = 4.199999999999999
# Episode 463: Total Reward = -52.15
# Episode 464: Total Reward = -17.15
# Episode 465: Total Reward = 4.55
# Episode 466: Total Reward = 1.4
# Episode 467: Total Reward = -62.99999999999999
# Episode 468: Total Reward = -24.849999999999998
# Episode 469: Total Reward = -14.7
# Episode 470: Total Reward = -67.19999999999999
# Episode 471: Total Reward = -19.25
# Episode 472: Total Reward = 1.4
# Episode 473: Total Reward = -39.55
# Episode 474: Total Reward = -12.25
# Episode 475: Total Reward = 2.8
# Episode 476: Total Reward = 4.199999999999999
# Episode 477: Total Reward = 3.5
# Episode 478: Total Reward = 2.4499999999999997
# Episode 479: Total Reward = 2.4499999999999997
# Episode 480: Total Reward = 1.75
# Episode 481: Total Reward = -9.1
# Episode 482: Total Reward = -2.4499999999999997
# Episode 483: Total Reward = 3.15
# Episode 484: Total Reward = -29.4
# Episode 485: Total Reward = -86.44999999999999
# Episode 486: Total Reward = -6.3
# Episode 487: Total Reward = -26.599999999999998
# Episode 488: Total Reward = 2.8
# Episode 489: Total Reward = -37.099999999999994
# Episode 490: Total Reward = -8.399999999999999
# Episode 491: Total Reward = 3.5
# Episode 492: Total Reward = 3.8499999999999996
# Episode 493: Total Reward = -43.75
# Episode 494: Total Reward = -8.75
# Episode 495: Total Reward = -126.69999999999999
# Episode 496: Total Reward = 2.4499999999999997
# Episode 497: Total Reward = -27.299999999999997
# Episode 498: Total Reward = 4.199999999999999
# Episode 499: Total Reward = 3.15
# Episode 500: Total Reward = -8.049999999999999
# Episode 501: Total Reward = -2.0999999999999996
# Episode 502: Total Reward = 0.7
# Episode 503: Total Reward = -6.6499999999999995
# Episode 504: Total Reward = -16.799999999999997
# Episode 505: Total Reward = -65.45
# Episode 506: Total Reward = -28.0
# Episode 507: Total Reward = 2.8
# Episode 508: Total Reward = -0.7
# Episode 509: Total Reward = -3.5
# Episode 510: Total Reward = -4.199999999999999
# Episode 511: Total Reward = -39.9
# Episode 512: Total Reward = -44.099999999999994
# Episode 513: Total Reward = 3.8499999999999996
# Episode 514: Total Reward = -7.35
# Episode 515: Total Reward = 3.8499999999999996
# Episode 516: Total Reward = -21.349999999999998
# Episode 517: Total Reward = 2.4499999999999997
# Episode 518: Total Reward = -4.55
# Episode 519: Total Reward = 3.15
# Episode 520: Total Reward = -4.199999999999999
# Episode 521: Total Reward = 0.7
# Episode 522: Total Reward = -53.55
# Episode 523: Total Reward = 4.55
# Episode 524: Total Reward = -51.8
# Episode 525: Total Reward = -10.5
# Episode 526: Total Reward = -6.3
# Episode 527: Total Reward = -9.799999999999999
# Episode 528: Total Reward = 3.8499999999999996
# Episode 529: Total Reward = -59.15
# Episode 530: Total Reward = 3.8499999999999996
# Episode 531: Total Reward = -5.949999999999999
# Episode 532: Total Reward = 1.0499999999999998
# Episode 533: Total Reward = 2.0999999999999996
# Episode 534: Total Reward = -0.7
# Episode 535: Total Reward = 3.8499999999999996
# Episode 536: Total Reward = -16.799999999999997
# Episode 537: Total Reward = -40.599999999999994
# Episode 538: Total Reward = -20.299999999999997
# Episode 539: Total Reward = -32.9
# Episode 540: Total Reward = 0.7
# Episode 541: Total Reward = 3.15
# Episode 542: Total Reward = 2.8
# Episode 543: Total Reward = -5.6
# Episode 544: Total Reward = -1.4
# Episode 545: Total Reward = -3.5
# Episode 546: Total Reward = 3.5
# Episode 547: Total Reward = 2.0999999999999996
# Episode 548: Total Reward = 2.4499999999999997
# Episode 549: Total Reward = 2.4499999999999997
# Episode 550: Total Reward = -1.0499999999999998
# Episode 551: Total Reward = -7.35
# Episode 552: Total Reward = -18.2
# Episode 553: Total Reward = -2.0999999999999996
# Episode 554: Total Reward = -42.0
# Episode 555: Total Reward = -7.699999999999999
# Episode 556: Total Reward = 2.0999999999999996
# Episode 557: Total Reward = -12.95
# Episode 558: Total Reward = -46.9
# Episode 559: Total Reward = 0.35
# Episode 560: Total Reward = -10.5
# Episode 561: Total Reward = -1.0499999999999998
# Episode 562: Total Reward = 3.8499999999999996
# Episode 563: Total Reward = 2.8
# Episode 564: Total Reward = -5.25
# Episode 565: Total Reward = 3.8499999999999996
# Episode 566: Total Reward = 4.55
# Episode 567: Total Reward = -3.8499999999999996
# Episode 568: Total Reward = -4.199999999999999
# Episode 569: Total Reward = -38.15
# Episode 570: Total Reward = -21.0
# Episode 571: Total Reward = 3.5
# Episode 572: Total Reward = 2.8
# Episode 573: Total Reward = -2.8
# Episode 574: Total Reward = 1.75
# Episode 575: Total Reward = 2.0999999999999996
# Episode 576: Total Reward = -13.299999999999999
# Episode 577: Total Reward = -18.549999999999997
# Episode 578: Total Reward = -96.25
# Episode 579: Total Reward = -10.5
# Episode 580: Total Reward = -12.95
# Episode 581: Total Reward = -56.699999999999996
# Episode 582: Total Reward = 3.5
# Episode 583: Total Reward = 3.5
# Episode 584: Total Reward = 3.8499999999999996
# Episode 585: Total Reward = -0.7
# Episode 586: Total Reward = -10.85
# Episode 587: Total Reward = 2.4499999999999997
# Episode 588: Total Reward = 3.5
# Episode 589: Total Reward = -2.8
# Episode 590: Total Reward = 0.0
# Episode 591: Total Reward = -1.75
# Episode 592: Total Reward = 0.0
# Episode 593: Total Reward = -2.8
# Episode 594: Total Reward = 3.15
# Episode 595: Total Reward = -108.14999999999999
# Episode 596: Total Reward = 1.0499999999999998
# Episode 597: Total Reward = -2.8
# Episode 598: Total Reward = 3.8499999999999996
# Episode 599: Total Reward = 4.199999999999999
# Episode 600: Total Reward = -1.75
# Episode 601: Total Reward = 4.8999999999999995
# Episode 602: Total Reward = -6.3
# Episode 603: Total Reward = 3.5
# Episode 604: Total Reward = -3.5
# Episode 605: Total Reward = -53.9
# Episode 606: Total Reward = -25.9
# Episode 607: Total Reward = -30.799999999999997
# Episode 608: Total Reward = -5.25
# Episode 609: Total Reward = -50.05
# Episode 610: Total Reward = -1.4
# Episode 611: Total Reward = 0.35
# Episode 612: Total Reward = 4.55
# Episode 613: Total Reward = 0.7
# Episode 614: Total Reward = -9.799999999999999
# Episode 615: Total Reward = -12.6
# Episode 616: Total Reward = -9.1
# Episode 617: Total Reward = 1.75
# Episode 618: Total Reward = 3.8499999999999996
# Episode 619: Total Reward = 4.199999999999999
# Episode 620: Total Reward = -36.75
# Episode 621: Total Reward = 3.15
# Episode 622: Total Reward = 2.0999999999999996
# Episode 623: Total Reward = -3.8499999999999996
# Episode 624: Total Reward = -1.75
# Episode 625: Total Reward = -1.4
# Episode 626: Total Reward = 0.0
# Episode 627: Total Reward = -0.35
# Episode 628: Total Reward = 4.55
# Episode 629: Total Reward = -1.4
# Episode 630: Total Reward = -1.75
# Episode 631: Total Reward = 2.8
# Episode 632: Total Reward = 1.75
# Episode 633: Total Reward = -1.0499999999999998
# Episode 634: Total Reward = -26.25
# Episode 635: Total Reward = 0.7
# Episode 636: Total Reward = 2.8
# Episode 637: Total Reward = -45.15
# Episode 638: Total Reward = -2.0999999999999996
# Episode 639: Total Reward = 3.15
# Episode 640: Total Reward = -52.849999999999994
# Episode 641: Total Reward = -42.349999999999994
# Episode 642: Total Reward = 3.15
# Episode 643: Total Reward = -32.9
# Episode 644: Total Reward = 2.0999999999999996
# Episode 645: Total Reward = 4.199999999999999
# Episode 646: Total Reward = 2.8
# Episode 647: Total Reward = 3.15
# Episode 648: Total Reward = 2.0999999999999996
# Episode 649: Total Reward = -16.799999999999997
# Episode 650: Total Reward = -17.849999999999998
# Episode 651: Total Reward = 3.15
# Episode 652: Total Reward = 3.5
# Episode 653: Total Reward = 3.15
# Episode 654: Total Reward = 1.75
# Episode 655: Total Reward = 3.8499999999999996
# Episode 656: Total Reward = 4.199999999999999
# Episode 657: Total Reward = -3.15
# Episode 658: Total Reward = 3.5
# Episode 659: Total Reward = 2.8
# Episode 660: Total Reward = 2.8
# Episode 661: Total Reward = -0.7
# Episode 662: Total Reward = 3.8499999999999996
# Episode 663: Total Reward = -26.95
# Episode 664: Total Reward = 2.4499999999999997
# Episode 665: Total Reward = 3.5
# Episode 666: Total Reward = -0.35
# Episode 667: Total Reward = 0.7
# Episode 668: Total Reward = -12.95
# Episode 669: Total Reward = 5.25
# Episode 670: Total Reward = 2.8
# Episode 671: Total Reward = 0.35
# Episode 672: Total Reward = 1.4
# Episode 673: Total Reward = 3.5
# Episode 674: Total Reward = 3.15
# Episode 675: Total Reward = -1.0499999999999998
# Episode 676: Total Reward = -3.5
# Episode 677: Total Reward = -4.8999999999999995
# Episode 678: Total Reward = 3.15
# Episode 679: Total Reward = 3.15
# Episode 680: Total Reward = 1.0499999999999998
# Episode 681: Total Reward = -10.5
# Episode 682: Total Reward = -28.0
# Episode 683: Total Reward = -30.45
# Episode 684: Total Reward = -10.5
# Episode 685: Total Reward = 2.8
# Episode 686: Total Reward = 1.0499999999999998
# Episode 687: Total Reward = 3.15
# Episode 688: Total Reward = 3.5
# Episode 689: Total Reward = -5.25
# Episode 690: Total Reward = 0.7
# Episode 691: Total Reward = 3.15
# Episode 692: Total Reward = 2.8
# Episode 693: Total Reward = 1.4
# Episode 694: Total Reward = 2.8
# Episode 695: Total Reward = 4.199999999999999
# Episode 696: Total Reward = -1.4
# Episode 697: Total Reward = 1.0499999999999998
# Episode 698: Total Reward = -45.5
# Episode 699: Total Reward = 3.15
# Episode 700: Total Reward = 2.4499999999999997
# Episode 701: Total Reward = -9.1
# Episode 702: Total Reward = 2.4499999999999997
# Episode 703: Total Reward = -3.8499999999999996
# Episode 704: Total Reward = 4.199999999999999
# Episode 705: Total Reward = 3.8499999999999996
# Episode 706: Total Reward = -53.9
# Episode 707: Total Reward = -0.35
# Episode 708: Total Reward = -1.0499999999999998
# Episode 709: Total Reward = 3.5
# Episode 710: Total Reward = -77.0
# Episode 711: Total Reward = -4.8999999999999995
# Episode 712: Total Reward = 3.15
# Episode 713: Total Reward = 2.8
# Episode 714: Total Reward = 2.0999999999999996
# Episode 715: Total Reward = 3.5
# Episode 716: Total Reward = 3.8499999999999996
# Episode 717: Total Reward = -0.35
# Episode 718: Total Reward = -2.0999999999999996
# Episode 719: Total Reward = -3.15
# Episode 720: Total Reward = 3.15
# Episode 721: Total Reward = -8.049999999999999
# Episode 722: Total Reward = -39.199999999999996
# Episode 723: Total Reward = 1.0499999999999998
# Episode 724: Total Reward = 3.8499999999999996
# Episode 725: Total Reward = 1.0499999999999998
# Episode 726: Total Reward = 4.199999999999999
# Episode 727: Total Reward = 4.55
# Episode 728: Total Reward = -7.699999999999999
# Episode 729: Total Reward = -15.399999999999999
# Episode 730: Total Reward = 4.199999999999999
# Episode 731: Total Reward = 3.5
# Episode 732: Total Reward = -22.4
# Episode 733: Total Reward = 2.0999999999999996
# Episode 734: Total Reward = -23.799999999999997
# Episode 735: Total Reward = 2.4499999999999997
# Episode 736: Total Reward = -53.55
# Episode 737: Total Reward = 3.5
# Episode 738: Total Reward = 3.15
# Episode 739: Total Reward = 2.8
# Episode 740: Total Reward = 2.0999999999999996
# Episode 741: Total Reward = -43.75
# Episode 742: Total Reward = 0.7
# Episode 743: Total Reward = -1.75
# Episode 744: Total Reward = -3.8499999999999996
# Episode 745: Total Reward = 2.0999999999999996
# Episode 746: Total Reward = 4.55
# Episode 747: Total Reward = 3.15
# Episode 748: Total Reward = -6.3
# Episode 749: Total Reward = 1.4
# Episode 750: Total Reward = 0.7
# Episode 751: Total Reward = 1.4
# Episode 752: Total Reward = 2.8
# Episode 753: Total Reward = 2.0999999999999996
# Episode 754: Total Reward = 3.5
# Episode 755: Total Reward = -1.0499999999999998
# Episode 756: Total Reward = 0.35
# Episode 757: Total Reward = 3.5
# Episode 758: Total Reward = 3.5
# Episode 759: Total Reward = 3.5
# Episode 760: Total Reward = 3.8499999999999996
# Episode 761: Total Reward = 3.15
# Episode 762: Total Reward = 2.8
# Episode 763: Total Reward = 2.4499999999999997
# Episode 764: Total Reward = 3.8499999999999996
# Episode 765: Total Reward = 2.0999999999999996
# Episode 766: Total Reward = 3.15
# Episode 767: Total Reward = 2.4499999999999997
# Episode 768: Total Reward = -1.75
# Episode 769: Total Reward = 2.4499999999999997
# Episode 770: Total Reward = 3.15
# Episode 771: Total Reward = -85.75
# Episode 772: Total Reward = 3.5
# Episode 773: Total Reward = 0.7
# Episode 774: Total Reward = -23.799999999999997
# Episode 775: Total Reward = 3.5
# Episode 776: Total Reward = 2.0999999999999996
# Episode 777: Total Reward = -18.2
# Episode 778: Total Reward = 0.35
# Episode 779: Total Reward = -25.9
# Episode 780: Total Reward = 1.75
# Episode 781: Total Reward = 2.4499999999999997
# Episode 782: Total Reward = 1.4
# Episode 783: Total Reward = 3.15
# Episode 784: Total Reward = 4.199999999999999
# Episode 785: Total Reward = 0.0
# Episode 786: Total Reward = 4.199999999999999
# Episode 787: Total Reward = -2.0999999999999996
# Episode 788: Total Reward = -1.75
# Episode 789: Total Reward = 3.8499999999999996
# Episode 790: Total Reward = 3.15
# Episode 791: Total Reward = 3.15
# Episode 792: Total Reward = -8.399999999999999
# Episode 793: Total Reward = 4.199999999999999
# Episode 794: Total Reward = -14.7
# Episode 795: Total Reward = 3.8499999999999996
# Episode 796: Total Reward = -14.7
# Episode 797: Total Reward = 3.8499999999999996
# Episode 798: Total Reward = 3.15
# Episode 799: Total Reward = 3.5
# Episode 800: Total Reward = 4.55
# Episode 801: Total Reward = 2.0999999999999996
# Episode 802: Total Reward = 4.199999999999999
# Episode 803: Total Reward = 3.15
# Episode 804: Total Reward = -11.549999999999999
# Episode 805: Total Reward = 1.0499999999999998
# Episode 806: Total Reward = 1.4
# Episode 807: Total Reward = -9.799999999999999
# Episode 808: Total Reward = 4.199999999999999
# Episode 809: Total Reward = -6.6499999999999995
# Episode 810: Total Reward = 3.8499999999999996
# Episode 811: Total Reward = 3.15
# Episode 812: Total Reward = 3.5
# Episode 813: Total Reward = -1.4
# Episode 814: Total Reward = 0.35
# Episode 815: Total Reward = 3.15
# Episode 816: Total Reward = 2.0999999999999996
# Episode 817: Total Reward = 2.0999999999999996
# Episode 818: Total Reward = -15.749999999999998
# Episode 819: Total Reward = 3.8499999999999996
# Episode 820: Total Reward = 4.55
# Episode 821: Total Reward = -22.4
# Episode 822: Total Reward = -5.6
# Episode 823: Total Reward = -2.0999999999999996
# Episode 824: Total Reward = 0.7
# Episode 825: Total Reward = 1.4
# Episode 826: Total Reward = 4.199999999999999
# Episode 827: Total Reward = 3.5
# Episode 828: Total Reward = 2.8
# Episode 829: Total Reward = 1.75
# Episode 830: Total Reward = -0.35
# Episode 831: Total Reward = -8.75
# Episode 832: Total Reward = -48.3
# Episode 833: Total Reward = 4.55
# Episode 834: Total Reward = -7.35
# Episode 835: Total Reward = 4.55
# Episode 836: Total Reward = 3.5
# Episode 837: Total Reward = 1.4
# Episode 838: Total Reward = -142.1
# Episode 839: Total Reward = 2.8
# Episode 840: Total Reward = -9.799999999999999
# Episode 841: Total Reward = 1.75
# Episode 842: Total Reward = 1.0499999999999998
# Episode 843: Total Reward = -14.7
# Episode 844: Total Reward = -8.399999999999999
# Episode 845: Total Reward = -3.5
# Episode 846: Total Reward = 3.15
# Episode 847: Total Reward = 2.4499999999999997
# Episode 848: Total Reward = 2.0999999999999996
# Episode 849: Total Reward = 3.8499999999999996
# Episode 850: Total Reward = 1.4
# Episode 851: Total Reward = 4.55
# Episode 852: Total Reward = 4.199999999999999
# Episode 853: Total Reward = 1.75
# Episode 854: Total Reward = -23.45
# Episode 855: Total Reward = -22.049999999999997
# Episode 856: Total Reward = 4.8999999999999995
# Episode 857: Total Reward = 2.8
# Episode 858: Total Reward = 2.4499999999999997
# Episode 859: Total Reward = 2.4499999999999997
# Episode 860: Total Reward = 3.5
# Episode 861: Total Reward = 4.8999999999999995
# Episode 862: Total Reward = 3.5
# Episode 863: Total Reward = 2.8
# Episode 864: Total Reward = 1.0499999999999998
# Episode 865: Total Reward = 3.5
# Episode 866: Total Reward = 3.8499999999999996
# Episode 867: Total Reward = 0.7
# Episode 868: Total Reward = 3.15
# Episode 869: Total Reward = 1.4
# Episode 870: Total Reward = 3.8499999999999996
# Episode 871: Total Reward = 2.8
# Episode 872: Total Reward = 4.199999999999999
# Episode 873: Total Reward = -0.7
# Episode 874: Total Reward = -1.0499999999999998
# Episode 875: Total Reward = 4.8999999999999995
# Episode 876: Total Reward = -42.699999999999996
# Episode 877: Total Reward = -38.5
# Episode 878: Total Reward = 2.8
# Episode 879: Total Reward = -9.1
# Episode 880: Total Reward = 1.0499999999999998
# Episode 881: Total Reward = 3.8499999999999996
# Episode 882: Total Reward = 2.8
# Episode 883: Total Reward = 5.25
# Episode 884: Total Reward = 3.8499999999999996
# Episode 885: Total Reward = 3.15
# Episode 886: Total Reward = -1.0499999999999998
# Episode 887: Total Reward = 2.4499999999999997
# Episode 888: Total Reward = 2.0999999999999996
# Episode 889: Total Reward = 3.5
# Episode 890: Total Reward = 2.4499999999999997
# Episode 891: Total Reward = 1.75
# Episode 892: Total Reward = 3.8499999999999996
# Episode 893: Total Reward = 3.15
# Episode 894: Total Reward = 1.4
# Episode 895: Total Reward = 3.15
# Episode 896: Total Reward = -1.4
# Episode 897: Total Reward = 4.55
# Episode 898: Total Reward = 1.0499999999999998
# Episode 899: Total Reward = 0.35
# Episode 900: Total Reward = 3.5
# Episode 901: Total Reward = 2.0999999999999996
# Episode 902: Total Reward = 3.15
# Episode 903: Total Reward = 2.0999999999999996
# Episode 904: Total Reward = 2.4499999999999997
# Episode 905: Total Reward = 2.4499999999999997
# Episode 906: Total Reward = 3.15
# Episode 907: Total Reward = 0.0
# Episode 908: Total Reward = 0.35
# Episode 909: Total Reward = -1.0499999999999998
# Episode 910: Total Reward = 3.15
# Episode 911: Total Reward = 2.4499999999999997
# Episode 912: Total Reward = 1.75
# Episode 913: Total Reward = -44.449999999999996
# Episode 914: Total Reward = 2.4499999999999997
# Episode 915: Total Reward = 4.199999999999999
# Episode 916: Total Reward = 2.8
# Episode 917: Total Reward = 1.75
# Episode 918: Total Reward = 2.0999999999999996
# Episode 919: Total Reward = 2.4499999999999997
# Episode 920: Total Reward = 3.8499999999999996
# Episode 921: Total Reward = -50.75
# Episode 922: Total Reward = -12.95
# Episode 923: Total Reward = 3.15
# Episode 924: Total Reward = 2.0999999999999996
# Episode 925: Total Reward = 2.4499999999999997
# Episode 926: Total Reward = 3.5
# Episode 927: Total Reward = 0.7
# Episode 928: Total Reward = 3.15
# Episode 929: Total Reward = 2.8
# Episode 930: Total Reward = 1.4
# Episode 931: Total Reward = 2.4499999999999997
# Episode 932: Total Reward = 2.8
# Episode 933: Total Reward = 3.5
# Episode 934: Total Reward = 0.7
# Episode 935: Total Reward = 4.199999999999999
# Episode 936: Total Reward = 2.8
# Episode 937: Total Reward = -6.6499999999999995
# Episode 938: Total Reward = 2.4499999999999997
# Episode 939: Total Reward = 2.0999999999999996
# Episode 940: Total Reward = 2.8
# Episode 941: Total Reward = 2.8
# Episode 942: Total Reward = 4.199999999999999
# Episode 943: Total Reward = 5.25
# Episode 944: Total Reward = 4.199999999999999
# Episode 945: Total Reward = 3.5
# Episode 946: Total Reward = 0.0
# Episode 947: Total Reward = -2.8
# Episode 948: Total Reward = 2.8
# Episode 949: Total Reward = -10.149999999999999
# Episode 950: Total Reward = 3.5
# Episode 951: Total Reward = 2.4499999999999997
# Episode 952: Total Reward = 3.5
# Episode 953: Total Reward = -41.3
# Episode 954: Total Reward = 1.4
# Episode 955: Total Reward = 2.4499999999999997
# Episode 956: Total Reward = -26.95
# Episode 957: Total Reward = 4.55
# Episode 958: Total Reward = -1.0499999999999998
# Episode 959: Total Reward = -5.949999999999999
# Episode 960: Total Reward = -64.39999999999999
# Episode 961: Total Reward = 1.75
# Episode 962: Total Reward = 1.4
# Episode 963: Total Reward = -27.65
# Episode 964: Total Reward = 1.4
# Episode 965: Total Reward = 3.15
# Episode 966: Total Reward = 3.5
# Episode 967: Total Reward = -8.049999999999999
# Episode 968: Total Reward = 3.5
# Episode 969: Total Reward = 4.199999999999999
# Episode 970: Total Reward = 3.5
# Episode 971: Total Reward = -5.25
# Episode 972: Total Reward = -6.3
# Episode 973: Total Reward = 3.8499999999999996
# Episode 974: Total Reward = 3.5
# Episode 975: Total Reward = -2.0999999999999996
# Episode 976: Total Reward = 3.5
# Episode 977: Total Reward = 4.199999999999999
# Episode 978: Total Reward = -16.799999999999997
# Episode 979: Total Reward = 3.8499999999999996
# Episode 980: Total Reward = -34.3
# Episode 981: Total Reward = 1.4
# Episode 982: Total Reward = 2.0999999999999996
# Episode 983: Total Reward = 4.55
# Episode 984: Total Reward = 3.15
# Episode 985: Total Reward = 3.15
# Episode 986: Total Reward = 2.4499999999999997
# Episode 987: Total Reward = 1.75
# Episode 988: Total Reward = 2.8
# Episode 989: Total Reward = 2.0999999999999996
# Episode 990: Total Reward = 2.8
# Episode 991: Total Reward = 3.8499999999999996
# Episode 992: Total Reward = 3.15
# Episode 993: Total Reward = 4.199999999999999
# Episode 994: Total Reward = 3.8499999999999996
# Episode 995: Total Reward = 2.0999999999999996
# Episode 996: Total Reward = 2.4499999999999997
# Episode 997: Total Reward = -36.05
# Episode 998: Total Reward = 2.4499999999999997
# Episode 999: Total Reward = -16.799999999999997
# Episode 1000: Total Reward = -1.0499999999999998
# Episode 1001: Total Reward = 3.8499999999999996
# Episode 1002: Total Reward = 2.8
# Episode 1003: Total Reward = 2.8
# Episode 1004: Total Reward = 3.5
# Episode 1005: Total Reward = 1.75
# Episode 1006: Total Reward = 4.199999999999999
# Episode 1007: Total Reward = 1.0499999999999998
# Episode 1008: Total Reward = 4.55
# Episode 1009: Total Reward = 3.15
# Episode 1010: Total Reward = -14.0
# Episode 1011: Total Reward = 2.8
# Episode 1012: Total Reward = 2.0999999999999996
# Episode 1013: Total Reward = 3.5
# Episode 1014: Total Reward = 3.8499999999999996
# Episode 1015: Total Reward = 4.55
# Episode 1016: Total Reward = 4.199999999999999
# Episode 1017: Total Reward = 1.4
# Episode 1018: Total Reward = -17.849999999999998
# Episode 1019: Total Reward = 1.75
# Episode 1020: Total Reward = 1.75
# Episode 1021: Total Reward = 2.8
# Episode 1022: Total Reward = 3.15
# Episode 1023: Total Reward = -47.25
# Episode 1024: Total Reward = 3.8499999999999996
# Episode 1025: Total Reward = 3.5
# Episode 1026: Total Reward = 2.8
# Episode 1027: Total Reward = 3.15
# Episode 1028: Total Reward = -23.799999999999997
# Episode 1029: Total Reward = -5.949999999999999
# Episode 1030: Total Reward = -8.75
# Episode 1031: Total Reward = -12.95
# Episode 1032: Total Reward = 3.15
# Episode 1033: Total Reward = 3.5
# Episode 1034: Total Reward = 5.25
# Episode 1035: Total Reward = 2.4499999999999997
# Episode 1036: Total Reward = 3.5
# Episode 1037: Total Reward = 2.8
# Episode 1038: Total Reward = 2.4499999999999997
# Episode 1039: Total Reward = 2.8
# Episode 1040: Total Reward = 2.8
# Episode 1041: Total Reward = 1.4
# Episode 1042: Total Reward = -50.05
# Episode 1043: Total Reward = 1.4
# Episode 1044: Total Reward = -1.0499999999999998
# Episode 1045: Total Reward = 2.8
# Episode 1046: Total Reward = 3.5
# Episode 1047: Total Reward = 4.199999999999999
# Episode 1048: Total Reward = -4.8999999999999995
# Episode 1049: Total Reward = 3.15
# Episode 1050: Total Reward = 5.25
# Episode 1051: Total Reward = 2.8
# Episode 1052: Total Reward = 2.8
# Episode 1053: Total Reward = 3.8499999999999996
# Episode 1054: Total Reward = 3.8499999999999996
# Episode 1055: Total Reward = -54.599999999999994
# Episode 1056: Total Reward = 1.75
# Episode 1057: Total Reward = 3.15
# Episode 1058: Total Reward = -0.35
# Episode 1059: Total Reward = 3.5
# Episode 1060: Total Reward = 2.4499999999999997
# Episode 1061: Total Reward = 2.4499999999999997
# Episode 1062: Total Reward = 3.5
# Episode 1063: Total Reward = 2.8
# Episode 1064: Total Reward = 3.8499999999999996
# Episode 1065: Total Reward = 3.5
# Episode 1066: Total Reward = 1.75
# Episode 1067: Total Reward = 2.8
# Episode 1068: Total Reward = 0.35
# Episode 1069: Total Reward = 3.15
# Episode 1070: Total Reward = 0.0
# Episode 1071: Total Reward = 2.4499999999999997
# Episode 1072: Total Reward = 3.15
# Episode 1073: Total Reward = 3.5
# Episode 1074: Total Reward = 3.5
# Episode 1075: Total Reward = 3.5
# Episode 1076: Total Reward = 1.4
# Episode 1077: Total Reward = 2.4499999999999997
# Episode 1078: Total Reward = 2.4499999999999997
# Episode 1079: Total Reward = 2.4499999999999997
# Episode 1080: Total Reward = 2.0999999999999996
# Episode 1081: Total Reward = -28.349999999999998
# Episode 1082: Total Reward = 2.0999999999999996
# Episode 1083: Total Reward = 2.4499999999999997
# Episode 1084: Total Reward = 2.0999999999999996
# Episode 1085: Total Reward = 3.5
# Episode 1086: Total Reward = 3.8499999999999996
# Episode 1087: Total Reward = 2.8
# Episode 1088: Total Reward = -32.199999999999996
# Episode 1089: Total Reward = 0.7
# Episode 1090: Total Reward = 3.15
# Episode 1091: Total Reward = 3.15
# Episode 1092: Total Reward = -9.45
# Episode 1093: Total Reward = 3.15
# Episode 1094: Total Reward = 2.4499999999999997
# Episode 1095: Total Reward = 1.75
# Episode 1096: Total Reward = 2.4499999999999997
# Episode 1097: Total Reward = 3.5
# Episode 1098: Total Reward = 3.8499999999999996
# Episode 1099: Total Reward = 2.4499999999999997
# Episode 1100: Total Reward = 2.4499999999999997
# Episode 1101: Total Reward = 2.0999999999999996
# Episode 1102: Total Reward = 0.7
# Episode 1103: Total Reward = 2.0999999999999996
# Episode 1104: Total Reward = 4.199999999999999
# Episode 1105: Total Reward = 1.4
# Episode 1106: Total Reward = 3.5
# Episode 1107: Total Reward = 4.199999999999999
# Episode 1108: Total Reward = 1.0499999999999998
# Episode 1109: Total Reward = 4.199999999999999
# Episode 1110: Total Reward = 2.4499999999999997
# Episode 1111: Total Reward = 2.4499999999999997
# Episode 1112: Total Reward = 2.8
# Episode 1113: Total Reward = 3.5
# Episode 1114: Total Reward = 3.5
# Episode 1115: Total Reward = 1.4
# Episode 1116: Total Reward = 2.0999999999999996
# Episode 1117: Total Reward = 2.0999999999999996
# Episode 1118: Total Reward = 1.0499999999999998
# Episode 1119: Total Reward = -2.8
# Episode 1120: Total Reward = 1.75
# Episode 1121: Total Reward = 3.5
# Episode 1122: Total Reward = -17.15
# Episode 1123: Total Reward = 2.0999999999999996
# Episode 1124: Total Reward = 4.199999999999999
# Episode 1125: Total Reward = 1.4
# Episode 1126: Total Reward = 2.8
# Episode 1127: Total Reward = 3.8499999999999996
# Episode 1128: Total Reward = -6.3
# Episode 1129: Total Reward = 4.199999999999999
# Episode 1130: Total Reward = 1.4
# Episode 1131: Total Reward = 3.5
# Episode 1132: Total Reward = 2.4499999999999997
# Episode 1133: Total Reward = 3.8499999999999996
# Episode 1134: Total Reward = 5.25
# Episode 1135: Total Reward = 1.75
# Episode 1136: Total Reward = 3.5
# Episode 1137: Total Reward = 3.8499999999999996
# Episode 1138: Total Reward = 2.0999999999999996
# Episode 1139: Total Reward = 2.0999999999999996
# Episode 1140: Total Reward = 3.8499999999999996
# Episode 1141: Total Reward = 1.75
# Episode 1142: Total Reward = 2.8
# Episode 1143: Total Reward = 2.4499999999999997
# Episode 1144: Total Reward = 0.7
# Episode 1145: Total Reward = -29.749999999999996
# Episode 1146: Total Reward = 3.15
# Episode 1147: Total Reward = 2.4499999999999997
# Episode 1148: Total Reward = 0.0
# Episode 1149: Total Reward = 1.4
# Episode 1150: Total Reward = 2.0999999999999996
# Episode 1151: Total Reward = -22.049999999999997
# Episode 1152: Total Reward = 3.5
# Episode 1153: Total Reward = 2.8
# Episode 1154: Total Reward = 2.4499999999999997
# Episode 1155: Total Reward = 2.8
# Episode 1156: Total Reward = 1.75
# Episode 1157: Total Reward = 4.8999999999999995
# Episode 1158: Total Reward = -10.5
# Episode 1159: Total Reward = -7.0
# Episode 1160: Total Reward = 2.8
# Episode 1161: Total Reward = 3.8499999999999996
# Episode 1162: Total Reward = 2.4499999999999997
# Episode 1163: Total Reward = 4.8999999999999995
# Episode 1164: Total Reward = 1.75
# Episode 1165: Total Reward = 1.75
# Episode 1166: Total Reward = 2.4499999999999997
# Episode 1167: Total Reward = 3.5
# Episode 1168: Total Reward = 2.8
# Episode 1169: Total Reward = 1.75
# Episode 1170: Total Reward = 2.0999999999999996
# Episode 1171: Total Reward = 2.8
# Episode 1172: Total Reward = 4.8999999999999995
# Episode 1173: Total Reward = 2.4499999999999997
# Episode 1174: Total Reward = 1.4
# Episode 1175: Total Reward = 3.15
# Episode 1176: Total Reward = 2.0999999999999996
# Episode 1177: Total Reward = 1.0499999999999998
# Episode 1178: Total Reward = 2.8
# Episode 1179: Total Reward = -1.0499999999999998
# Episode 1180: Total Reward = 1.75
# Episode 1181: Total Reward = 3.5
# Episode 1182: Total Reward = 2.4499999999999997
# Episode 1183: Total Reward = 3.15
# Episode 1184: Total Reward = 3.15
# Episode 1185: Total Reward = 2.4499999999999997
# Episode 1186: Total Reward = 2.8
# Episode 1187: Total Reward = -1.0499999999999998
# Episode 1188: Total Reward = 2.8
# Episode 1189: Total Reward = 3.8499999999999996
# Episode 1190: Total Reward = 3.15
# Episode 1191: Total Reward = 1.4
# Episode 1192: Total Reward = 2.4499999999999997
# Episode 1193: Total Reward = 2.4499999999999997
# Episode 1194: Total Reward = 3.8499999999999996
# Episode 1195: Total Reward = 3.15
# Episode 1196: Total Reward = 3.15
# Episode 1197: Total Reward = 1.75
# Episode 1198: Total Reward = 2.8
# Episode 1199: Total Reward = 2.8
# Episode 1200: Total Reward = 3.15
# Episode 1201: Total Reward = 1.75
# Episode 1202: Total Reward = 2.4499999999999997
# Episode 1203: Total Reward = -4.8999999999999995
# Episode 1204: Total Reward = 2.0999999999999996
# Episode 1205: Total Reward = 2.0999999999999996
# Episode 1206: Total Reward = 3.8499999999999996
# Episode 1207: Total Reward = 0.7
# Episode 1208: Total Reward = 1.75
# Episode 1209: Total Reward = 2.0999999999999996
# Episode 1210: Total Reward = 3.8499999999999996
# Episode 1211: Total Reward = 3.15
# Episode 1212: Total Reward = 2.4499999999999997
# Episode 1213: Total Reward = 3.15
# Episode 1214: Total Reward = 2.4499999999999997
# ...
# Episode 4601: Total Reward = 3.8499999999999996
# Episode 4602: Total Reward = 3.8499999999999996
# Episode 4603: Total Reward = 2.8
# Episode 4604: Total Reward = 2.4499999999999997
# Episode 4605: Total Reward = 3.8499999999999996
# Episode 4606: Total Reward = 1.75
# Episode 4607: Total Reward = 3.8499999999999996
# Episode 4608: Total Reward = 2.0999999999999996
# Episode 4609: Total Reward = 3.8499999999999996
# Episode 4610: Total Reward = 3.15
# Episode 4611: Total Reward = 2.8
# Episode 4612: Total Reward = 2.8
# Episode 4613: Total Reward = 3.8499999999999996
# Episode 4614: Total Reward = 2.4499999999999997
# Episode 4615: Total Reward = 3.15
# Episode 4616: Total Reward = 2.0999999999999996
# Episode 4617: Total Reward = 1.75
# Episode 4618: Total Reward = 1.75
# Episode 4619: Total Reward = 2.8
# Episode 4620: Total Reward = 1.4
# Episode 4621: Total Reward = 2.8
# Episode 4622: Total Reward = 4.8999999999999995
# Episode 4623: Total Reward = 2.4499999999999997
# Episode 4624: Total Reward = 2.0999999999999996
# Episode 4625: Total Reward = 3.15
# Episode 4626: Total Reward = 3.15
# Episode 4627: Total Reward = 3.5
# Episode 4628: Total Reward = 3.8499999999999996
# Episode 4629: Total Reward = 2.0999999999999996
# Episode 4630: Total Reward = 4.8999999999999995
# Episode 4631: Total Reward = 2.0999999999999996
# Episode 4632: Total Reward = 2.8
# Episode 4633: Total Reward = 3.15
# Episode 4634: Total Reward = 4.8999999999999995
# Episode 4635: Total Reward = 3.8499999999999996
# Episode 4636: Total Reward = 0.35
# Episode 4637: Total Reward = 2.8
# Episode 4638: Total Reward = 4.199999999999999
# Episode 4639: Total Reward = 2.0999999999999996
# Episode 4640: Total Reward = 3.5
# Episode 4641: Total Reward = 2.8
# Episode 4642: Total Reward = 3.8499999999999996
# Episode 4643: Total Reward = 1.75
# Episode 4644: Total Reward = 1.75
# Episode 4645: Total Reward = 2.0999999999999996
# Episode 4646: Total Reward = 1.75
# Episode 4647: Total Reward = 3.15
# Episode 4648: Total Reward = 1.0499999999999998
# Episode 4649: Total Reward = 1.4
# Episode 4650: Total Reward = 2.0999999999999996
# Episode 4651: Total Reward = 2.4499999999999997
# Episode 4652: Total Reward = -2.0999999999999996
# Episode 4653: Total Reward = 2.0999999999999996
# Episode 4654: Total Reward = 4.8999999999999995
# Episode 4655: Total Reward = 2.8
# Episode 4656: Total Reward = 2.8
# Episode 4657: Total Reward = 3.8499999999999996
# Episode 4658: Total Reward = 2.0999999999999996
# Episode 4659: Total Reward = -28.7
# Episode 4660: Total Reward = 4.199999999999999
# Episode 4661: Total Reward = 1.4
# Episode 4662: Total Reward = 2.4499999999999997
# Episode 4663: Total Reward = 2.0999999999999996
# Episode 4664: Total Reward = 2.0999999999999996
# Episode 4665: Total Reward = -24.5
# Episode 4666: Total Reward = 1.75
# Episode 4667: Total Reward = 4.8999999999999995
# Episode 4668: Total Reward = 3.5
# Episode 4669: Total Reward = -1.0499999999999998
# Episode 4670: Total Reward = 3.15
# Episode 4671: Total Reward = 3.15
# Episode 4672: Total Reward = 2.4499999999999997
# Episode 4673: Total Reward = 3.5
# Episode 4674: Total Reward = 3.5
# Episode 4675: Total Reward = 3.8499999999999996
# Episode 4676: Total Reward = 2.4499999999999997
# Episode 4677: Total Reward = 3.15
# Episode 4678: Total Reward = 2.0999999999999996
# Episode 4679: Total Reward = 3.15
# Episode 4680: Total Reward = -27.299999999999997
# Episode 4681: Total Reward = 1.0499999999999998
# Episode 4682: Total Reward = 1.4
# Episode 4683: Total Reward = 1.75
# Episode 4684: Total Reward = 2.4499999999999997
# Episode 4685: Total Reward = 3.5
# Episode 4686: Total Reward = 2.4499999999999997
# Episode 4687: Total Reward = 2.0999999999999996
# Episode 4688: Total Reward = 4.199999999999999
# Episode 4689: Total Reward = 4.199999999999999
# Episode 4690: Total Reward = 4.199999999999999
# Episode 4691: Total Reward = 2.0999999999999996
# Episode 4692: Total Reward = 4.199999999999999
# Episode 4693: Total Reward = 3.15
# Episode 4694: Total Reward = 2.4499999999999997
# Episode 4695: Total Reward = 2.0999999999999996
# Episode 4696: Total Reward = -0.7
# Episode 4697: Total Reward = 2.8
# Episode 4698: Total Reward = 2.8
# Episode 4699: Total Reward = 3.5
# Episode 4700: Total Reward = 2.8
# Episode 4701: Total Reward = 3.5
# Episode 4702: Total Reward = 3.15
# Episode 4703: Total Reward = 3.5
# Episode 4704: Total Reward = 2.8
# Episode 4705: Total Reward = 2.0999999999999996
# Episode 4706: Total Reward = 3.5
# Episode 4707: Total Reward = 3.8499999999999996
# Episode 4708: Total Reward = 1.4
# Episode 4709: Total Reward = 1.0499999999999998
# Episode 4710: Total Reward = 3.8499999999999996
# Episode 4711: Total Reward = -8.75
# Episode 4712: Total Reward = 3.5
# Episode 4713: Total Reward = 4.55
# Episode 4714: Total Reward = 3.15
# Episode 4715: Total Reward = 2.8
# Episode 4716: Total Reward = -8.049999999999999
# Episode 4717: Total Reward = 3.5
# Episode 4718: Total Reward = 2.4499999999999997
# Episode 4719: Total Reward = 1.75
# Episode 4720: Total Reward = 3.5
# Episode 4721: Total Reward = 3.8499999999999996
# Episode 4722: Total Reward = 1.75
# Episode 4723: Total Reward = 4.55
# Episode 4724: Total Reward = -0.35
# Episode 4725: Total Reward = 4.199999999999999
# Episode 4726: Total Reward = 3.8499999999999996
# Episode 4727: Total Reward = 2.0999999999999996
# Episode 4728: Total Reward = 2.0999999999999996
# Episode 4729: Total Reward = 2.8
# Episode 4730: Total Reward = 3.5
# Episode 4731: Total Reward = 3.15
# Episode 4732: Total Reward = 3.5
# Episode 4733: Total Reward = 1.75
# Episode 4734: Total Reward = 4.55
# Episode 4735: Total Reward = 3.8499999999999996
# Episode 4736: Total Reward = 2.4499999999999997
# Episode 4737: Total Reward = 4.8999999999999995
# Episode 4738: Total Reward = 1.75
# Episode 4739: Total Reward = 2.0999999999999996
# Episode 4740: Total Reward = 1.75
# Episode 4741: Total Reward = 2.8
# Episode 4742: Total Reward = 3.5
# Episode 4743: Total Reward = 1.75
# Episode 4744: Total Reward = 2.0999999999999996
# Episode 4745: Total Reward = 2.4499999999999997
# Episode 4746: Total Reward = 3.8499999999999996
# Episode 4747: Total Reward = -27.299999999999997
# Episode 4748: Total Reward = 4.55
# Episode 4749: Total Reward = -0.7
# Episode 4750: Total Reward = 2.8
# Episode 4751: Total Reward = 3.5
# Episode 4752: Total Reward = 3.8499999999999996
# Episode 4753: Total Reward = 1.75
# Episode 4754: Total Reward = 3.8499999999999996
# Episode 4755: Total Reward = 1.0499999999999998
# Episode 4756: Total Reward = 1.0499999999999998
# Episode 4757: Total Reward = 4.55
# Episode 4758: Total Reward = 1.4
# Episode 4759: Total Reward = 2.0999999999999996
# Episode 4760: Total Reward = 1.75
# Episode 4761: Total Reward = 3.15
# Episode 4762: Total Reward = 2.8
# Episode 4763: Total Reward = 3.8499999999999996
# Episode 4764: Total Reward = 3.5
# Episode 4765: Total Reward = 3.15
# Episode 4766: Total Reward = 2.0999999999999996
# Episode 4767: Total Reward = 2.0999999999999996
# Episode 4768: Total Reward = 1.75
# Episode 4769: Total Reward = 2.8
# Episode 4770: Total Reward = 2.0999999999999996
# Episode 4771: Total Reward = 2.4499999999999997
# Episode 4772: Total Reward = 3.15
# Episode 4773: Total Reward = 2.8
# Episode 4774: Total Reward = 2.8
# Episode 4775: Total Reward = 3.5
# Episode 4776: Total Reward = 2.8
# Episode 4777: Total Reward = 1.75
# Episode 4778: Total Reward = 2.0999999999999996
# Episode 4779: Total Reward = 3.8499999999999996
# Episode 4780: Total Reward = 1.75
# Episode 4781: Total Reward = 3.5
# Episode 4782: Total Reward = 2.0999999999999996
# Episode 4783: Total Reward = 3.15
# Episode 4784: Total Reward = 2.0999999999999996
# Episode 4785: Total Reward = 2.4499999999999997
# Episode 4786: Total Reward = 2.8
# Episode 4787: Total Reward = 3.5
# Episode 4788: Total Reward = 2.8
# Episode 4789: Total Reward = 4.199999999999999
# Episode 4790: Total Reward = 1.75
# Episode 4791: Total Reward = 2.0999999999999996
# Episode 4792: Total Reward = 1.75
# Episode 4793: Total Reward = 3.15
# Episode 4794: Total Reward = 2.0999999999999996
# Episode 4795: Total Reward = 2.0999999999999996
# Episode 4796: Total Reward = 1.75
# Episode 4797: Total Reward = 4.55
# Episode 4798: Total Reward = 1.75
# Episode 4799: Total Reward = 3.15
# Episode 4800: Total Reward = 1.75
# Episode 4801: Total Reward = 4.199999999999999
# Episode 4802: Total Reward = 3.15
# Episode 4803: Total Reward = 3.15
# Episode 4804: Total Reward = 2.8
# Episode 4805: Total Reward = 3.5
# Episode 4806: Total Reward = 2.0999999999999996
# Episode 4807: Total Reward = 3.8499999999999996
# Episode 4808: Total Reward = 2.0999999999999996
# Episode 4809: Total Reward = 3.15
# Episode 4810: Total Reward = -15.399999999999999
# Episode 4811: Total Reward = 3.5
# Episode 4812: Total Reward = 2.0999999999999996
# Episode 4813: Total Reward = -6.6499999999999995
# Episode 4814: Total Reward = 3.15
# Episode 4815: Total Reward = 2.8
# Episode 4816: Total Reward = 4.55
# Episode 4817: Total Reward = 1.4
# Episode 4818: Total Reward = 3.15
# Episode 4819: Total Reward = 0.35
# Episode 4820: Total Reward = 0.0
# Episode 4821: Total Reward = 3.15
# Episode 4822: Total Reward = 1.75
# Episode 4823: Total Reward = 3.15
# Episode 4824: Total Reward = 3.5
# Episode 4825: Total Reward = 3.5
# Episode 4826: Total Reward = 1.75
# Episode 4827: Total Reward = 3.8499999999999996
# Episode 4828: Total Reward = 2.0999999999999996
# Episode 4829: Total Reward = 2.0999999999999996
# Episode 4830: Total Reward = -15.749999999999998
# Episode 4831: Total Reward = 2.0999999999999996
# Episode 4832: Total Reward = 2.8
# Episode 4833: Total Reward = 3.5
# Episode 4834: Total Reward = 2.0999999999999996
# Episode 4835: Total Reward = 3.15
# Episode 4836: Total Reward = 1.75
# Episode 4837: Total Reward = 1.0499999999999998
# Episode 4838: Total Reward = 2.0999999999999996
# Episode 4839: Total Reward = 1.4
# Episode 4840: Total Reward = 2.4499999999999997
# Episode 4841: Total Reward = 3.5
# Episode 4842: Total Reward = 2.0999999999999996
# Episode 4843: Total Reward = 2.8
# Episode 4844: Total Reward = 4.199999999999999
# Episode 4845: Total Reward = 2.0999999999999996
# Episode 4846: Total Reward = 1.75
# Episode 4847: Total Reward = 3.5
# Episode 4848: Total Reward = 2.0999999999999996
# Episode 4849: Total Reward = 2.4499999999999997
# Episode 4850: Total Reward = 3.15
# Episode 4851: Total Reward = -0.35
# Episode 4852: Total Reward = 1.4
# Episode 4853: Total Reward = 2.0999999999999996
# Episode 4854: Total Reward = 1.4
# Episode 4855: Total Reward = 2.8
# Episode 4856: Total Reward = 2.4499999999999997
# Episode 4857: Total Reward = 3.5
# Episode 4858: Total Reward = 2.4499999999999997
# Episode 4859: Total Reward = 2.0999999999999996
# Episode 4860: Total Reward = 2.0999999999999996
# Episode 4861: Total Reward = 4.55
# Episode 4862: Total Reward = 1.4
# Episode 4863: Total Reward = 2.0999999999999996
# Episode 4864: Total Reward = 1.75
# Episode 4865: Total Reward = 1.75
# Episode 4866: Total Reward = 3.15
# Episode 4867: Total Reward = 3.8499999999999996
# Episode 4868: Total Reward = 3.15
# Episode 4869: Total Reward = 1.75
# Episode 4870: Total Reward = 3.8499999999999996
# Episode 4871: Total Reward = -25.9
# Episode 4872: Total Reward = 2.4499999999999997
# Episode 4873: Total Reward = 2.8
# Episode 4874: Total Reward = 1.75
# Episode 4875: Total Reward = 2.4499999999999997
# Episode 4876: Total Reward = 2.4499999999999997
# Episode 4877: Total Reward = 2.8
# Episode 4878: Total Reward = 2.8
# Episode 4879: Total Reward = 1.75
# Episode 4880: Total Reward = 1.4
# Episode 4881: Total Reward = 3.15
# Episode 4882: Total Reward = 2.8
# Episode 4883: Total Reward = -21.349999999999998
# Episode 4884: Total Reward = 1.0499999999999998
# Episode 4885: Total Reward = 3.8499999999999996
# Episode 4886: Total Reward = 2.0999999999999996
# Episode 4887: Total Reward = 2.4499999999999997
# Episode 4888: Total Reward = 1.4
# Episode 4889: Total Reward = 2.0999999999999996
# Episode 4890: Total Reward = 3.15
# Episode 4891: Total Reward = 2.4499999999999997
# Episode 4892: Total Reward = 2.0999999999999996
# Episode 4893: Total Reward = 4.199999999999999
# Episode 4894: Total Reward = 3.15
# Episode 4895: Total Reward = 3.15
# Episode 4896: Total Reward = 4.8999999999999995
# Episode 4897: Total Reward = 2.0999999999999996
# Episode 4898: Total Reward = 2.0999999999999996
# Episode 4899: Total Reward = 2.8
# Episode 4900: Total Reward = 3.8499999999999996
# Episode 4901: Total Reward = 1.0499999999999998
# Episode 4902: Total Reward = 2.0999999999999996
# Episode 4903: Total Reward = 2.8
# Episode 4904: Total Reward = 3.8499999999999996
# Episode 4905: Total Reward = 2.4499999999999997
# Episode 4906: Total Reward = 2.4499999999999997
# Episode 4907: Total Reward = 4.55
# Episode 4908: Total Reward = 3.5
# Episode 4909: Total Reward = -0.7
# Episode 4910: Total Reward = 3.8499999999999996
# Episode 4911: Total Reward = 1.75
# Episode 4912: Total Reward = 3.15
# Episode 4913: Total Reward = 1.0499999999999998
# Episode 4914: Total Reward = 3.5
# Episode 4915: Total Reward = 1.75
# Episode 4916: Total Reward = 2.4499999999999997
# Episode 4917: Total Reward = 4.8999999999999995
# Episode 4918: Total Reward = 1.0499999999999998
# Episode 4919: Total Reward = 1.75
# Episode 4920: Total Reward = 2.0999999999999996
# Episode 4921: Total Reward = 3.8499999999999996
# Episode 4922: Total Reward = 3.5
# Episode 4923: Total Reward = 2.0999999999999996
# Episode 4924: Total Reward = 3.8499999999999996
# Episode 4925: Total Reward = 3.8499999999999996
# Episode 4926: Total Reward = 1.4
# Episode 4927: Total Reward = 1.75
# Episode 4928: Total Reward = 2.4499999999999997
# Episode 4929: Total Reward = 1.75
# Episode 4930: Total Reward = -14.35
# Episode 4931: Total Reward = 2.8
# Episode 4932: Total Reward = 3.8499999999999996
# Episode 4933: Total Reward = 2.8
# Episode 4934: Total Reward = 3.15
# Episode 4935: Total Reward = 2.4499999999999997
# Episode 4936: Total Reward = 2.8
# Episode 4937: Total Reward = 2.4499999999999997
# Episode 4938: Total Reward = 3.5
# Episode 4939: Total Reward = 3.5
# Episode 4940: Total Reward = 0.0
# Episode 4941: Total Reward = 3.15
# Episode 4942: Total Reward = 1.75
# Episode 4943: Total Reward = 3.8499999999999996
# Episode 4944: Total Reward = 3.5
# Episode 4945: Total Reward = 3.5
# Episode 4946: Total Reward = 1.4
# Episode 4947: Total Reward = 3.8499999999999996
# Episode 4948: Total Reward = 2.8
# Episode 4949: Total Reward = 2.8
# Episode 4950: Total Reward = 4.55
# Episode 4951: Total Reward = 2.4499999999999997
# Episode 4952: Total Reward = 1.75
# Episode 4953: Total Reward = 3.5
# Episode 4954: Total Reward = 1.4
# Episode 4955: Total Reward = 2.8
# Episode 4956: Total Reward = 2.8
# Episode 4957: Total Reward = -0.35
# Episode 4958: Total Reward = 1.75
# Episode 4959: Total Reward = 3.15
# Episode 4960: Total Reward = 2.4499999999999997
# Episode 4961: Total Reward = 2.4499999999999997
# Episode 4962: Total Reward = 2.4499999999999997
# Episode 4963: Total Reward = 2.8
# Episode 4964: Total Reward = 2.0999999999999996
# Episode 4965: Total Reward = 2.0999999999999996
# Episode 4966: Total Reward = 2.8
# Episode 4967: Total Reward = 2.4499999999999997
# Episode 4968: Total Reward = 4.199999999999999
# Episode 4969: Total Reward = 4.199999999999999
# Episode 4970: Total Reward = -2.0999999999999996
# Episode 4971: Total Reward = 1.75
# Episode 4972: Total Reward = 1.0499999999999998
# Episode 4973: Total Reward = 3.5
# Episode 4974: Total Reward = 1.75
# Episode 4975: Total Reward = 1.4
# Episode 4976: Total Reward = 3.5
# Episode 4977: Total Reward = -7.699999999999999
# Episode 4978: Total Reward = 1.0499999999999998
# Episode 4979: Total Reward = 3.15
# Episode 4980: Total Reward = 1.4
# Episode 4981: Total Reward = 3.15
# Episode 4982: Total Reward = 3.15
# Episode 4983: Total Reward = 2.4499999999999997
# Episode 4984: Total Reward = 2.8
# Episode 4985: Total Reward = 3.8499999999999996
# Episode 4986: Total Reward = 4.8999999999999995
# Episode 4987: Total Reward = 3.5
# Episode 4988: Total Reward = 2.8
# Episode 4989: Total Reward = 1.75
# Episode 4990: Total Reward = 2.8
# Episode 4991: Total Reward = 2.8
# Episode 4992: Total Reward = 3.8499999999999996
# Episode 4993: Total Reward = 1.4
# Episode 4994: Total Reward = 2.0999999999999996
# Episode 4995: Total Reward = 1.4
# Episode 4996: Total Reward = 2.0999999999999996
# Episode 4997: Total Reward = 1.75
# Episode 4998: Total Reward = 2.8
# Episode 4999: Total Reward = 2.8
# Episode 5000: Total Reward = 4.55

# %%
smdp.plot_Q()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 smdp.plot_Q()
#
# Cell In[9], line 159, in SMDP.plot_Q(self)
#     157 # Create a 5x5 grid for grid and frequncy
#     158     grid = np.reshape(loc_r_g, (5, 5))
# --> 159     freq = np.reshape(loc_r_g_f, (5, 5))
#     161 # Display the grid with numbers
#     162     plt.imshow(freq, cmap='viridis', interpolation='nearest')
#
# File <__array_function__ internals>:180, in reshape(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:298, in reshape(a, newshape, order)
#     198 @array_function_dispatch(_reshape_dispatcher)
#     199 def reshape(a, newshape, order='C'):
#     200     """
#     201     Gives a new shape to an array without changing its data.
#     202
#    (...)
#     296            [5, 6]])
#     297     """
# --> 298     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# ValueError: cannot reshape array of size 4 into shape (5,5)

# %% [markdown]
# INTRA OPTION

# %%
q_intra = np.zeros((500,10))
qf = np.zeros((500,10))
qof = np.zeros((4,25,4))

# %%
class INTRAOPT:
    def __init__(self):
        self.avg_reward = []
        self.total_reward = []

    def Qlearn(self):
        epsilon = 0.1
        for episode in range(5000):
            running = 0
            state, _ = env.reset()
            done = False
            ep_reward = 0
            steps = 0

            while not done :
                steps += 1
                state = env.s
                action = choose_action(state,q_intra,epsilon)
                if action < 6:
                    next_state, reward, done, _, _ = env.step(action)
                    ep_reward += reward
                    q_intra[state,action] = q_intra[state, action] + ALPHA * (reward + GAMMA * np.max(q_intra[next_state, :])- q_intra[state, action])
                    qf[state,action] += 1
                    state = next_state
                
                reward_bar = 0
                if action > 5 :
                    count = 0
                    
                    optdone = False
                    current_state = state
                    state = encode(get_state(state)[0:2]) 

                    while (optdone == False) :
                        if action == 6:
                            optact, optdone = Red(Q_opt[0],state,epsilon) 
                            next_state, reward, done, _, _ = env.step(optact)
                            next = encode(get_state(next_state)[0:2])
                            #Q_opt[0][state,optact] = Q_opt[0][state, optact] + ALPHA * (reward + GAMMA * np.max(Q_opt[0][next, :])- Q_opt[0][state, optact])
                            qof[0][state,optact] += 1

                        if action == 7:
                            optact, optdone = Green(Q_opt[1],state,epsilon)
                            next_state, reward, done, _, _ = env.step(optact)
                            next = encode(get_state(next_state)[0:2])
                            #Q_opt[1][state,optact] = Q_opt[1][state, optact] + ALPHA * (reward + GAMMA * np.max(Q_opt[1][next, :])- Q_opt[1][state, optact])
                            qof[1][state,optact] += 1

                        if action == 8:
                            optact, optdone = Blue(Q_opt[2],state,epsilon)
                            next_state, reward, done, _, _ = env.step(optact)
                            next = encode(get_state(next_state)[0:2])
                            #Q_opt[2][state,optact] = Q_opt[2][state, optact] + ALPHA * (reward + GAMMA * np.max(Q_opt[2][next, :])- Q_opt[2][state, optact])
                            qof[2][state,optact] += 1

                        if action == 9:

                            optact, optdone = Yellow(Q_opt[3],state,epsilon)
                            next_state, reward, done, _, _ = env.step(optact)
                            next = encode(get_state(next_state)[0:2])
                            #Q_opt[3][state,optact] = Q_opt[3][state, optact] + ALPHA * (reward + GAMMA * np.max(Q_opt[3][next])- Q_opt[3][state, optact])
                            qof[3][state,optact] += 1

                        reward_bar =  reward_bar + (GAMMA**count)*reward
                        ep_reward += reward
                        count += 1
                        state = next
                        statey = env.s
                        q_intra[statey, action] += ALPHA * (reward_bar - q_intra[statey, action] + (GAMMA**count) * np.max(q_intra[statey, :]))
                        
                        
                if epsilon > 0.01:
                    epsilon = epsilon*np.exp(-0.01)
            running = 0.35 * ep_reward + (1 - 0.35) * running
            self.avg_reward.append(running)
            self.total_reward.append(ep_reward)
            print(f"Episode {episode + 1}: Total Reward = {running}")
        return self.avg_reward, self.total_reward
    
    def plot(self):
        plt.plot(self.avg_reward,label="Moving Average")
        plt.grid()
        plt.plot(self.total_reward,label="Total Rewards",alpha=1, color='orange')
        plt.xlabel('Episode')
        plt.ylabel('Averaged Episodic Returns')
        plt.title("Averaged Episodic Returns")
        plt.legend()
        plt.savefig('SMDP.png')
        plt.show()

    def render_run(self):
        special_env = gym.make('Taxi-v3',render_mode='human')
        done = False
        eps = 0.01
        state, _ = special_env.reset()
        while not done:
            action = choose_action(state,q,eps)
            next_state, reward, done, _, _ = special_env.step(action)
            if done:
                break

    def plot_Q(self):
        ACTIONS = {0: "South",1: "Up",2: "East",3: "West",4: "Pick",5: "Drop",6: "R",7: "G",8: "B", 9: "Y"}
        # decode each state 
        # ((taxi_row * 5 + taxi_col) * 5 + passenger_location) * 4 + destination
        action = np.argmax(q,axis=1)
        action_f = np.argmax(qof,axis=1)

        dest_r = action[::4]
        dest_g = action[1::4]
        dest_b = action[2::4]
        dest_y = action[3::4]

        dest_r_f = action_f[::4]
        dest_g_f = action_f[1::4]
        dest_b_f = action_f[2::4]
        dest_y_f = action_f[3::4]

        loc_r_r = dest_r[::5]
        loc_r_g = dest_g[::5]
        loc_r_b = dest_b[::5]
        loc_r_y = dest_y[::5]

        loc_r_r_f = dest_r_f[::5]
        loc_r_g_f = dest_g_f[::5]
        loc_r_b_f = dest_b_f[::5]
        loc_r_y_f = dest_y_f[::5]

        loc_g_r = dest_r[1::5]
        loc_g_g = dest_g[1::5]
        loc_g_b = dest_b[1::5]
        loc_g_y = dest_y[1::5]

        loc_g_r_f = dest_r_f[1::5]
        loc_g_g_f = dest_g_f[1::5]
        loc_g_b_f = dest_b_f[1::5]
        loc_g_y_f = dest_y_f[1::5]

        loc_b_r = dest_r[2::5]
        loc_b_g = dest_g[2::5]
        loc_b_b = dest_b[2::5]
        loc_b_y = dest_y[2::5]

        loc_b_r_f = dest_r_f[2::5]
        loc_b_g_f = dest_g_f[2::5]
        loc_b_b_f = dest_b_f[2::5]
        loc_b_y_f = dest_y_f[2::5]

        loc_y_r = dest_r[3::5]
        loc_y_g = dest_g[3::5]
        loc_y_b = dest_b[3::5]
        loc_y_y = dest_y[3::5]

        loc_y_r_f = dest_r_f[3::5]
        loc_y_g_f = dest_g_f[3::5]
        loc_y_b_f = dest_b_f[3::5]
        loc_y_y_f = dest_y_f[3::5]

    # Create a 5x5 grid for grid and frequncy
        grid = np.reshape(loc_r_g, (5, 5))
        freq = np.reshape(loc_r_g_f, (5, 5))

    # Display the grid with numbers
        plt.imshow(freq, cmap='viridis', interpolation='nearest')
        for i in range(5):
            for j in range(5):
                text = ACTIONS[grid[i, j]]
                plt.text(j, i, text, ha='center', va='center', color='black')

    # Add labels and title
        plt.colorbar()
        plt.xlabel('Column')
        plt.ylabel('Row')
        plt.show()

# %%
agent2 = INTRAOPT()
agent2.Qlearn()
agent2.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 agent2 = INTRAOPT()
# ----> 2 agent2.Qlearn()
#       3 agent2.plot()
#
# Cell In[17], line 43, in INTRAOPT.Qlearn(self)
#      40     qof[0][state,optact] += 1
#      42 if action == 7:
# ---> 43     optact, optdone = Green(Q_opt[1],state,epsilon)
#      44     next_state, reward, done, _, _ = env.step(optact)
#      45     next = encode(get_state(next_state)[0:2])
#
# Cell In[7], line 12, in Green(q_g, state, eps)
#      10 def Green(q_g,state,eps):
#      11     optdone = False
# ---> 12     optact = choose_action(state,q_g,eps)
#      13     state = decode(state)
#      14     if state[0] == G[0] and state[1] == G[1]:
#
# Cell In[6], line 9, in choose_action(state, qs, eps)
#       6 action = np.argmax(qs[state])
#       8 if np.random.rand() < eps:
# ----> 9     action = np.random.randint(0,length-1)
#      10     return action
#      11 return action
#
# KeyboardInterrupt:
